# %% [markdown]
# # Combinatorics
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Philippe_Flajolet) ] `1948-2011` Flajolet, Philippe
# * [ [w](https://en.wikipedia.org/wiki/Adam_Marcus_(mathematician)) ] `1979-----` Marcus, Adam
# * [ [w](https://en.wikipedia.org/wiki/Pierre_Remond_de_Montmort) ] `1678-1719` Montmort, Pierre de
# * [ [w](https://en.wikipedia.org/wiki/George_P%C3%B3lya) ] `1887-1985` Pólya, George
# * [ [w](https://en.wikipedia.org/wiki/Gian-Carlo_Rota) ] `1932-1999` Rota, Giancarlo
# * [ [w](https://en.wikipedia.org/wiki/Hermann_Schubert) ] `1848-1911` Schubert, Hermann
# * [ [w](https://en.wikipedia.org/wiki/Robert_Sedgewick_(computer_scientist)) ] `1946-----` Sedgewick, Robert
# * [ [w](https://en.wikipedia.org/wiki/Zhu_Shijie) ] `1249-1314` Shijie, Zhu
# * [ [w](https://en.wikipedia.org/wiki/Richard_P._Stanley) ] `1944-----` Stanley, Richard
# * [ [w](https://en.wikipedia.org/wiki/G%C3%A1bor_Tardos) ] `1964-----` Tardos, Gábor
# * [ [w](https://en.wikipedia.org/wiki/Alexandre-Th%C3%A9ophile_Vandermonde) ] `1735-1796` Vandermonde, Alexandre-Théophile
# * [ [w](https://en.wikipedia.org/wiki/Herbert_Wilf) ] `1931-2012` Wilf, Herbert
# * [ [w](https://en.wikipedia.org/wiki/Alfred_Young_(mathematician)) ] `1873-1940` Young, Alfred

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Algebraic_combinatorics) ] Algebraic Combinatorics
# * [ [w](https://en.wikipedia.org/wiki/Algebraic_enumeration) ] Algebraic Enumeration
# * [ [w](https://en.wikipedia.org/wiki/Analytic_combinatorics) ] Analytic Combinatorics
# * [ [w](https://en.wikipedia.org/wiki/Bijective_proof) ] Bijective Proof
# * [ [w](https://en.wikipedia.org/wiki/Burnside%27s_lemma) ] Burnside's Lemma
# * [ [w](https://en.wikipedia.org/wiki/Cardinality) ] Cardinality
# * [ [w](https://en.wikipedia.org/wiki/Catalan_number) ] Catalan Number
# * [ [w](https://en.wikipedia.org/wiki/Combination) ] Combination
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_class) ] Combinatorial Class
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_explosion) ] Combinatorial Explosion
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_game_theory) ] Combinatorial Game Theory
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_proof) ] Combinatorial Proof
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_species) ] Combinatorial Species
# * [ [w](https://en.wikipedia.org/wiki/Combinatorics) ] Combinatorics
# * [ [w](https://en.wikipedia.org/wiki/Countable_set) ] Countability
# * [ [w](https://en.wikipedia.org/wiki/Counting) ] Counting
# * [ [w](https://en.wikipedia.org/wiki/Derangement) ] Derangement
# * [ [w](https://en.wikipedia.org/wiki/Double_counting_(proof_technique)) ] Double Counting
# * [ [w](https://en.wikipedia.org/wiki/Rule_of_division_(combinatorics)) ] Division Rule
# * [ [w](https://en.wikipedia.org/wiki/Double_counting_(proof_technique)) ] Double Counting
# * [ [w](https://en.wikipedia.org/wiki/Enumerative_combinatorics) ] Enumerative Combinatorics
# * [ [w](https://en.wikipedia.org/wiki/Exponential_formula) ] Exponential Formula
# * [ [w](https://en.wikipedia.org/wiki/Falling_and_rising_factorials) ] Falling Factorial
# * [ [w](https://en.wikipedia.org/wiki/Generating_function) ] Generating Function
# * [ [w](https://en.wikipedia.org/wiki/Inclusion%E2%80%93exclusion_principle) ] Inclusion-Exclusion Principle
# * [ [w](https://en.wikipedia.org/wiki/Integer_partition) ] Integer Partition
# * [ [w](https://en.wikipedia.org/wiki/Method_of_distinguished_element) ] Method of Distinguished Element
# * [ [w](https://en.wikipedia.org/wiki/Multiset) ] Multiset
# * [ [w](https://en.wikipedia.org/wiki/Order_polynomial) ] Order Polynomial
# * [ [w](https://en.wikipedia.org/wiki/Partition_of_a_set) ] Partition
# * [ [w](https://en.wikipedia.org/wiki/Pascal%27s_rule) ] Pascal's Rule
# * [ [w](https://en.wikipedia.org/wiki/Pascal%27s_triangle) ] Pascal's Triangle
# * [ [w](https://en.wikipedia.org/wiki/Permutation) ] Permutation
# * [ [w](https://en.wikipedia.org/wiki/Permutation_class) ] Permutation Class [ [enumerations](https://en.wikipedia.org/wiki/Enumerations_of_specific_permutation_classes) ]
# * [ [w](https://en.wikipedia.org/wiki/Permutation_matrix) ] Permutation Matrix
# * [ [w](https://en.wikipedia.org/wiki/Parity_of_a_permutation) ] Permutation Parity
# * [ [w](https://en.wikipedia.org/wiki/Permutation_pattern) ] Permutation Pattern
# * [ [w](https://en.wikipedia.org/wiki/Pigeonhole_principle) ] Pigeonhole Principle
# * [ [w](https://en.wikipedia.org/wiki/P%C3%B3lya_enumeration_theorem) ] Pólya Enumeration Theorem
# * [ [w](https://en.wikipedia.org/wiki/Rule_of_product) ] Product Rule
# * [ [w](https://en.wikipedia.org/wiki/Q-analog) ] q-Analog
# * [ [w](https://en.wikipedia.org/wiki/Q-Vandermonde_identity) ] q-Vandermonde Identity
# * [ [w](https://en.wikipedia.org/wiki/Recurrence_relation) ] Recurrence Relation
# * [ [w](https://en.wikipedia.org/wiki/Schubert_calculus) ] Schubert Calculus
# * [ [w](https://en.wikipedia.org/wiki/Sequence) ] Sequence
# * [ [w](https://en.wikipedia.org/wiki/Stack-sortable_permutation) ] Stack-Sortable Permutation
# * [ [w](https://en.wikipedia.org/wiki/Stanley%E2%80%93Wilf_conjecture) ] Stanley-Wilf Conjecture
# * [ [w](https://en.wikipedia.org/wiki/Stanley%27s_reciprocity_theorem) ] Stanley's Reciprocity Theorem
# * [ [w](https://en.wikipedia.org/wiki/Stanley_decomposition) ] Stanley Decomposition
# * [ [w](https://en.wikipedia.org/wiki/Subsequence) ] Subsequence
# * [ [w](https://en.wikipedia.org/wiki/Addition_principle) ] Sum Rule
# * [ [w](https://en.wikipedia.org/wiki/Symbolic_method_(combinatorics)) ] Symbolic Method
# * [ [w](https://en.wikipedia.org/wiki/Twelvefold_way) ] Twelvefold Way
# * [ [w](https://en.wikipedia.org/wiki/Uncountable_set) ] Uncountability
# * [ [w](https://en.wikipedia.org/wiki/Vandermonde%27s_identity) ] Vandermonde's Identity
# * [ [w](https://en.wikipedia.org/wiki/Vandermonde_matrix) ] Vandermonde Matrix
# * [ [w](https://en.wikipedia.org/wiki/Wilf_equivalence) ] Wilf Equivalence
# * [ [w](https://en.wikipedia.org/wiki/Young_tableau) ] Young Tableau

# %% [markdown]
# ---
# ---
# ---
