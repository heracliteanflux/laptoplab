# %% [markdown]
# # Nicolaus Copernicus
# `1473-1543 (70)` [ [w](https://en.wikipedia.org/wiki/Nicolaus_Copernicus) ][ [SEP](https://plato.stanford.edu/entries/copernicus/) ]
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
