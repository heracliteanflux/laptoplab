# %% [markdown]
# # 2.1 Use adjectives for description

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# apartment      gōng yù      公寓🏠
# bedroom        wò   shì     卧室
# living room    kè   tīng    客厅🛋️
#
# small          xiǎo         小
#
# only           zhǐ          只
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# Is your bed comfortable?          你的床舒服吗？nǐ de chuáng shūfú/fu ma?
# This is his new tv.               这是他的新电视。zhè shì tā de xīn diànshì
# This is our new tv.               这是我们的新电视。zhè shì wǒmen de xīn diànshì
# Wow, your bedroom is big.         哇，你的卧室很大。wā nǐ de wòshì hěn dà
# Wow, your new tv is beautiful.    哇，你的新电视很漂亮。wā, nǐ de xīn diànshì hěn piàoliàng/liang
# ```

# %% [markdown]
# ---
