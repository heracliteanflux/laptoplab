# %% [markdown]
# # Decision Theory
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Jeremy_Bentham) ] `1748-1832` Bentham, Jeremy
# * [ [w](https://en.wikipedia.org/wiki/John_Stuart_Mill) ] `1806-1873` Mill, John Stuart
# * [ [w](https://en.wikipedia.org/wiki/Oskar_Morgenstern) ] `1902-1977` Morgenstern, Oskar
# * [ [w](https://en.wikipedia.org/wiki/Herbert_A._Simon) ] `1916-2001` Simon, Herbert
# * [ [w](https://en.wikipedia.org/wiki/Adam_Smith) ] `1723-1790` Smith, Adam
# * [ [w](https://en.wikipedia.org/wiki/John_von_Neumann) ] `1903-1957` Von Neumann, John

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Allais_paradox) ] Allais Paradox
# * [ [w](https://en.wikipedia.org/wiki/Bounded_rationality) ] Bounded Rationality
# * [ [w](https://en.wikipedia.org/wiki/Causal_decision_theory) ] Causal Decision Theory (CDT)
# * [ [w](https://en.wikipedia.org/wiki/Cumulative_prospect_theory) ] Cumulative Prospect Theory (CPT)
# * [ [w](https://en.wikipedia.org/wiki/Decision-making) ] Decision-Making
# * [ [w](https://en.wikipedia.org/wiki/Decision_analysis) ] Decision Analysis (DA)
# * [ [w](https://en.wikipedia.org/wiki/Decision_theory) ] Decision Theory
# * [ [w](https://en.wikipedia.org/wiki/Evidential_decision_theory) ] Evidential Decision Theory (EDT)
# * [ [w](https://en.wikipedia.org/wiki/Expected_utility_hypothesis) ] Expected Utility Hypothesis
# * [ [w](https://en.wikipedia.org/wiki/Generalized_expected_utility) ] Generalized Expected Utility
# * [ [w](https://en.wikipedia.org/wiki/Heuristic) ] Heuristics
# * [ [w](https://en.wikipedia.org/wiki/Loss_aversion) ] Loss Aversion
# * [ [w](https://en.wikipedia.org/wiki/Newcomb%27s_paradox) ] Newcomb's Paradox
# * [ [w](https://en.wikipedia.org/wiki/Optimal_decision) ] Optimal Decision
# * [ [w](https://en.wikipedia.org/wiki/Preference_(economics)) ] Preference
# * [ [w](https://en.wikipedia.org/wiki/Prospect_theory) ] Prospect Theory
# * [ [w](https://en.wikipedia.org/wiki/Rank-dependent_expected_utility) ] Rank-Dependent Expected Utility
# * [ [w](https://en.wikipedia.org/wiki/Rational_choice_theory) ] Rational Choice Theory
# * [ [w](https://en.wikipedia.org/wiki/Regret_(decision_theory)) ] Regret
# * [ [w](https://en.wikipedia.org/wiki/Risk) ] Risk
# * [ [w](https://en.wikipedia.org/wiki/Risk-seeking) ] Risk-Seeking
# * [ [w](https://en.wikipedia.org/wiki/Risk_appetite) ] Risk Appetite
# * [ [w](https://en.wikipedia.org/wiki/Risk_aversion) ] Risk Aversion
# * [ [w](https://en.wikipedia.org/wiki/Risk_management) ] Risk Management
# * [ [w](https://en.wikipedia.org/wiki/Subjective_expected_utility) ] Subjective Expected Utility
# * [ [w](https://en.wikipedia.org/wiki/Uncertainty) ] Uncertainty
# * [ [w](https://en.wikipedia.org/wiki/Utilitarianism) ] Utilitarianism
# * [ [w](https://en.wikipedia.org/wiki/Utility) ] Utility
# * [ [w](https://en.wikipedia.org/wiki/Utility_maximization_problem) ] Utility Maximization
# * [ [w](https://en.wikipedia.org/wiki/Von_Neumann–Morgenstern_utility_theorem) ] Von Neumann-Morgenstern Utility Theorem

# %% [markdown]
# ---
# ---
# ---
