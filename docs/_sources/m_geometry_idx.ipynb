# %% [markdown]
# # Geometry
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Sections
# ```{tableofcontents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Archimedes) ] `0287-0212 BCE` Archimedes of Syracuse
#   * [ [w](https://en.wikipedia.org/wiki/Measurement_of_a_Circle) ] `250 BCE` _Measurement of a Circle_ Κύκλου μέτρησις
# * [ [w](https://en.wikipedia.org/wiki/Charles_Julien_Brianchon) ] `1783-1864` Brianchon, Charles Julien
# * [ [w](https://en.wikipedia.org/wiki/Henri_Brocard) ] `1845-1922` Brocard, Henri
# * [ [w](https://en.wikipedia.org/wiki/Giovanni_Ceva) ] `1647-1734` Ceva, Giovanni
# * [ [w](https://en.wikipedia.org/wiki/Gaston_Albert_Gohierre_de_Longchamps) ] `1842-1906` De Longchamps, Gaston Albert Gohierre
# * [ [w](https://en.wikipedia.org/wiki/Euclid) ] `0300 BCE` Euclid
#   *  [ [w](https://en.wikipedia.org/wiki/Euclid%27s_Elements) ] _Elements_
# * [ [w](https://en.wikipedia.org/wiki/Eudoxus_of_Cnidus) ] `0408-0355 BCE` Eudoxus of Cnidus
# * [ [w](https://en.wikipedia.org/wiki/Harry_Clinton_Gossard) ] `1884-1954` Gossard, Harry Clinton
# * [ [w](https://en.wikipedia.org/wiki/Thomas_Heath_(classicist)) ] `1861-1940` Heath, T. L.
# * [ [w](https://en.wikipedia.org/wiki/Friedrich_Wilhelm_August_Ludwig_Kiepert) ] `1846-1934` Kiepert, Ludvig
# * [ [w](https://en.wikipedia.org/wiki/Clark_Kimberling) ] `1942-----` Kimberling, Clark
# * [ [w](https://en.wikipedia.org/wiki/%C3%89mile_Lemoine) ] `1840-1912` Lemoine, Émile
# * [ [w](https://en.wikipedia.org/wiki/Frank_Morley) ] `1860-1937` Morley, Frank
# * [ [w](https://en.wikipedia.org/wiki/Pappus_of_Alexandria) ] `0290-0350` Pappus of Alexandria
# * [ [w](https://en.wikipedia.org/wiki/John_Playfair) ] `1748-1819` Playfair, John
# * [ [w](https://en.wikipedia.org/wiki/Pythagoras) ] `0570-0495 BCE` Pythagoras of Samos
# * [ [w](https://en.wikipedia.org/wiki/Edward_Routh) ] `1831-1907` Routh, Edward
# * [ [w](https://en.wikipedia.org/wiki/Kurt_Schiffler) ] `1896-1986` Schiffler, Kurt
# * [ [w](https://en.wikipedia.org/wiki/Jakob_Steiner) ] `1796-1863` Steiner, Jakob
# * [ [w](https://en.wikipedia.org/wiki/Christian_Heinrich_von_Nagel) ] `1803-1882` Von Nagel, Christian Heinrich

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Biangular_coordinates) ] Biangular Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Bipolar_coordinates) ] Bipolar Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Two-center_bipolar_coordinates) ] Bipolar Coordinates, Two-Center
# * [ [w](https://en.wikipedia.org/wiki/Elliptic_coordinate_system) ] Elliptic Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Polar_coordinate_system) ] Polar Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Spherical_coordinate_system) ] Spherical Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Two-center_bipolar_coordinates) ] Two-Center Bipolar Coordinates

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/3D_projection) ] 3D Projection
# * [ [w](https://en.wikipedia.org/wiki/Acute_and_obtuse_triangles) ] Acute Triangle
# * [ [w](https://en.wikipedia.org/wiki/Altitude_(triangle)) ] Altitude
# * [ [w](https://en.wikipedia.org/wiki/Angle) ] Angle
# * [ [w](https://en.wikipedia.org/wiki/Central_angle) ] Angle, Central
# * [ [w](https://en.wikipedia.org/wiki/Internal_and_external_angles) ] Angle, External
# * [ [w](https://en.wikipedia.org/wiki/Hyperbolic_angle) ] Angle, Hyperbolic
# * [ [w](https://en.wikipedia.org/wiki/Inscribed_angle) ] Angle, Inscribed
# * [ [w](https://en.wikipedia.org/wiki/Internal_and_external_angles) ] Angle, Internal
# * [ [w](https://en.wikipedia.org/wiki/Right_angle) ] Angle, Right
# * [ [w](https://en.wikipedia.org/wiki/Subtended_angle) ] Angle, Subtended
# * [ [w](https://en.wikipedia.org/wiki/Angle_bisector_theorem) ] Angle Bisector Theorem
# * [ [w](https://en.wikipedia.org/wiki/Angle_trisection) ] Angle Trisection
# * [ [w](https://en.wikipedia.org/wiki/Cross-ratio) ] Anharmonic Ratio (Cross-Ratio, Double Ratio)
# * [ [w](https://en.wikipedia.org/wiki/Antiparallelogram) ] Antiparallelogram
# * [ [w](https://en.wikipedia.org/wiki/Antiprism) ] Antiprism
# * [ [w](https://en.wikipedia.org/wiki/Pentagonal_antiprism) ] Antiprism, Pentagonal
# * [ [w](https://en.wikipedia.org/wiki/Apeirogon) ] Apeirogon
# * [ [w](https://en.wikipedia.org/wiki/Infinite_skew_polygon) ] Apeirogon, Skew
# * [ [w](https://en.wikipedia.org/wiki/Apex_(geometry)) ] Apex
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Apoapsis
# * [ [w](https://en.wikipedia.org/wiki/Apollonian_circles) ] Apollonian Circle
# * [ [w](https://en.wikipedia.org/wiki/Problem_of_Apollonius) ] Apollonius' Problem
# * [ [w](https://en.wikipedia.org/wiki/Apothem) ] Apothem
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Apsis
# * [ [w](https://en.wikipedia.org/wiki/Circular_arc) ] Arc, Circular
# * [ [w](https://en.wikipedia.org/wiki/Arc_length) ] Arc Length
# * [ [w](https://en.wikipedia.org/wiki/Archimedean_solid) ] Archimedean Solid
# * [ [w](https://en.wikipedia.org/wiki/Area) ] Area
# * [ [w](https://en.wikipedia.org/wiki/Axial_symmetry) ] Axial Symmetry
# * [ [w](https://en.wikipedia.org/wiki/Axiality_(geometry)) ] Axiality
# * [ [w](https://en.wikipedia.org/wiki/Perspective_(geometry)) ] Axis of Perspectivity
# * [ [w](https://en.wikipedia.org/wiki/Ball_(mathematics)) ] Ball
# * [ [w](https://en.wikipedia.org/wiki/Base_(geometry)) ] Base
# * [ [w](https://en.wikipedia.org/wiki/Bipyramid) ] Bipyramid (Dipyramid, Double Pyramid)
# * [ [w](https://en.wikipedia.org/wiki/Pentagonal_bipyramid) ] Bipyramid, Pentagonal
# * [ [w](https://en.wikipedia.org/wiki/Bisection) ] Bisection
# * [ [w](https://en.wikipedia.org/wiki/Brianchon%27s_theorem) ] Brianchon's Theorem
# * [ [w](https://en.wikipedia.org/wiki/Brocard_circle) ] Brocard Circle
# * [ [w](https://en.wikipedia.org/wiki/Brocard_points) ] Brocard Point
# * [ [w](https://en.wikipedia.org/wiki/Brocard_triangle) ] Brocard Triangle
# * [ [w](https://en.wikipedia.org/wiki/Catalan_solid) ] Catalan Solid
# * [ [w](https://en.wikipedia.org/wiki/Cathetus) ] Cathetus
# * [ [w](https://en.wikipedia.org/wiki/Centre_(geometry)) ] Center
# * [ [w](https://en.wikipedia.org/wiki/Homothetic_center) ] Center, Homothetic
# * [ [w](https://en.wikipedia.org/wiki/Morley_centers) ] Center, Morley
# * [ [w](https://en.wikipedia.org/wiki/Nine-point_center) ] Center, Nine-Point
# * [ [w](https://en.wikipedia.org/wiki/Power_center_(geometry)) ] Center, Power
# * [ [w](https://en.wikipedia.org/wiki/Spieker_center) ] Center, Spieker
# * [ [w](https://en.wikipedia.org/wiki/Triangle_center) ] Center, Triangle
# * [ [w](https://en.wikipedia.org/wiki/Perspective_(geometry)) ] Center of Perspectivity
# * [ [w](https://en.wikipedia.org/wiki/Homothetic_center) ] Center of Similitude (Homothetic Center)
# * [ [w](https://en.wikipedia.org/wiki/Central_angle) ] Central Angle
# * [ [w](https://en.wikipedia.org/wiki/Central_line_(geometry)) ] Central Line
# * [ [w](https://en.wikipedia.org/wiki/Centroid) ] Centroid
# * [ [w](https://en.wikipedia.org/wiki/Ceva%27s_theorem) ] Ceva's Theorem
# * [ [w](https://en.wikipedia.org/wiki/Cevian) ] Cevian
# * [ [w](https://en.wikipedia.org/wiki/Chiral_polytope) ] Chiral Polytope
# * [ [w](https://en.wikipedia.org/wiki/Chirality_(mathematics)) ] Chirality
# * [ [w](https://en.wikipedia.org/wiki/Chord_(geometry)) ] Chord
# * [ [w](https://en.wikipedia.org/wiki/Circle) ] Circle
# * [ [w](https://en.wikipedia.org/wiki/Apollonian_circles) ] Circle, Apollonian
# * [ [w](https://en.wikipedia.org/wiki/Brocard_circle) ] Circle, Brocard
# * [ [w](https://en.wikipedia.org/wiki/Circumscribed_circle) ] Circle, Circumscribed
# * [ [w](https://en.wikipedia.org/wiki/Incircle_and_excircles) ] Circle, Escribed
# * [ [w](https://en.wikipedia.org/wiki/Incircle_and_excircles) ] Circle, Inscribed
# * [ [w](https://en.wikipedia.org/wiki/Nine-point_circle) ] Circle, Nine-Point
# * [ [w](https://en.wikipedia.org/wiki/Spieker_circle) ] Circle, Spieker
# * [ [w](https://en.wikipedia.org/wiki/Circular_arc) ] Circular Arc
# * [ [w](https://en.wikipedia.org/wiki/Circular_segment) ] Circular Segment
# * [ [w](https://en.wikipedia.org/wiki/Circular_triangle) ] Circular Triangle
# * [ [w](https://en.wikipedia.org/wiki/Circumcircle) ] Circumcenter
# * [ [w](https://en.wikipedia.org/wiki/Circumconic_and_inconic) ] Circumconic
# * [ [w](https://en.wikipedia.org/wiki/Circumference) ] Circumference
# * [ [w](https://en.wikipedia.org/wiki/Circumcircle) ] Circumradius
# * [ [w](https://en.wikipedia.org/wiki/Circumscribed_circle) ] Circumscribed Circle
# * [ [w](https://en.wikipedia.org/wiki/Tangential_polygon) ] Circumscribed Polygon (Tangential Polygon)
# * [ [w](https://en.wikipedia.org/wiki/Circumscribed_sphere) ] Circumscribed Sphere
# * [ [w](https://en.wikipedia.org/wiki/Cleaver_(geometry)) ] Cleaver
# * [ [w](https://en.wikipedia.org/wiki/Collinearity) ] Collinearity
# * [ [w](https://en.wikipedia.org/wiki/Compass_(drawing_tool)) ] Compass
# * [ [w](https://en.wikipedia.org/wiki/Compass_equivalence_theorem) ] Compass Equivalence Theorem
# * [ [w](https://en.wikipedia.org/wiki/Complex_line) ] Complex Line
# * [ [w](https://en.wikipedia.org/wiki/Complex_plane) ] Complex Plane
# * [ [w](https://en.wikipedia.org/wiki/Cone) ] Cone
# * [ [w](https://en.wikipedia.org/wiki/Concentric_objects) ] Concentricity
# * [ [w](https://en.wikipedia.org/wiki/Concurrent_lines) ] Concurrent Line
# * [ [w](https://en.wikipedia.org/wiki/Concyclic_points) ] Concyclic Point
# * [ [w](https://en.wikipedia.org/wiki/Congruence_(geometry)) ] Congruence
# * [ [w](https://en.wikipedia.org/wiki/Kiepert_conics) ] Conic, Kiepert
# * [ [w](https://en.wikipedia.org/wiki/Steiner_conic) ] Conic, Steiner
# * [ [w](https://en.wikipedia.org/wiki/Constructible_polygon) ] Constructible Polygon
# * [ [w](https://en.wikipedia.org/wiki/Convex_hull) ] Convex Hull
# * [ [w](https://en.wikipedia.org/wiki/Convex_polygon) ] Convex Polygon
# * [ [w](https://en.wikipedia.org/wiki/Conway_polyhedron_notation) ] Conway Polyhedron Notation
# * [ [w](https://en.wikipedia.org/wiki/Real_coordinate_space) ] Coordinate Space, Real
# * [ [w](https://en.wikipedia.org/wiki/Trilinear_coordinates) ] Coordinates, Trilinear
# * [ [w](https://en.wikipedia.org/wiki/Coplanarity) ] Coplanarity
# * [ [w](https://en.wikipedia.org/wiki/Cross-ratio) ] Cross-Ratio (Anharmonic Ratio, Double Ratio)
# * [ [w](https://en.wikipedia.org/wiki/Cube) ] Cube
# * [ [w](https://en.wikipedia.org/wiki/Cubic_honeycomb) ] Cubic Honeycomb
# * [ [w](https://en.wikipedia.org/wiki/Cuboid) ] Cuboid
# * [ [w](https://en.wikipedia.org/wiki/Rectangular_cuboid) ] Cuboid, Rectangular
# * [ [w](https://en.wikipedia.org/wiki/Curve) ] Curve
# * [ [w](https://en.wikipedia.org/wiki/Intersection_curve) ] Curve, Intersection
# * [ [w](https://en.wikipedia.org/wiki/Inverse_curve) ] Curve, Inverse
# * [ [w](https://en.wikipedia.org/wiki/Parallel_curve) ] Curve, Parallel
# * [ [w](https://en.wikipedia.org/wiki/Curvilinear_perspective) ] Curvilinear Perspective
# * [ [w](https://en.wikipedia.org/wiki/Cylinder) ] Cylinder
# * [ [w](https://en.wikipedia.org/wiki/Right_circular_cylinder) ] Cylinder, Right Circular
# * [ [w](https://en.wikipedia.org/wiki/De_Longchamps_point) ] De Longchamps Point
# * [ [w](https://en.wikipedia.org/wiki/Deltahedron) ] Deltahedron
# * [ [w](https://en.wikipedia.org/wiki/Diagonal) ] Diagonal
# * [ [w](https://en.wikipedia.org/wiki/Diameter) ] Diameter
# * [ [w](https://en.wikipedia.org/wiki/Dihedron) ] Dihedron
# * [ [w](https://en.wikipedia.org/wiki/Bipyramid) ] Dipyramid (Bipyramid, Double Pyramid)
# * [ [w](https://en.wikipedia.org/wiki/Directrix) ] Directrix
# * [ [w](https://en.wikipedia.org/wiki/Discrete_geometry) ] Discrete Geometry
# * [ [w](https://en.wikipedia.org/wiki/Disk_(mathematics)) ] Disk
# * [ [w](https://en.wikipedia.org/wiki/Circular_segment) ] Disk Segment
# * [ [w](https://en.wikipedia.org/wiki/Distance_from_a_point_to_a_line) ] distance from a point to a line
# * [ [w](https://en.wikipedia.org/wiki/Rhombic_dodecahedron) ] Dodecahedron, Rhombic
# * [ [w](https://en.wikipedia.org/wiki/Bipyramid) ] Double Pyramid (Bipyramid, Dipyramid)
# * [ [w](https://en.wikipedia.org/wiki/Cross-ratio) ] Double Ratio (Anharmonic Ratio, Cross-Ratio)
# * [ [w](https://en.wikipedia.org/wiki/Doubling_the_cube) ] doubling the cube
# * [ [w](https://en.wikipedia.org/wiki/Dual_polyhedron) ] Dual Polyhedron
# * [ [w](https://en.wikipedia.org/wiki/Edge_(geometry)) ] Edge
# * [ [w](https://en.wikipedia.org/wiki/Isotoxal_figure) ] Edge-Transitivity (Isotoxality)
# * [ [w](https://en.wikipedia.org/wiki/Ellipse) ] Ellipse
# * [ [w](https://en.wikipedia.org/wiki/Steiner_ellipse) ] Ellipse, Steiner
# * [ [w](https://en.wikipedia.org/wiki/Elongated_square_gyrobicupola) ] Elongated Square Gyrobicopula
# * [ [w](https://en.wikipedia.org/wiki/Equiangular_polygon) ] Equiangular Polygon
# * [ [w](https://en.wikipedia.org/wiki/Equidistant) ] Equidistance
# * [ [w](https://en.wikipedia.org/wiki/Equilateral_polygon) ] Equilateral Polygon
# * [ [w](https://en.wikipedia.org/wiki/Equilateral_triangle) ] Equilateral Triangle
# * [ [w](https://en.wikipedia.org/wiki/Incircle_and_excircles) ] Escribed Circle (Excircle)
# * [ [w](https://en.wikipedia.org/wiki/Euclidean_geometry) ] Euclidean Geometry
# * [ [w](https://en.wikipedia.org/wiki/Euler_line) ] Euler Line
# * [ [w](https://en.wikipedia.org/wiki/Euler% 27s_theorem_in_geometry)] Euler's Theorem, in geometry
# * [ [w](https://en.wikipedia.org/wiki/Incircle_and_excircles) ] Excircle (Escribed Circle)
# * [ [w](https://en.wikipedia.org/wiki/Exeter_point) ] Exeter Point
# * [ [w](https://en.wikipedia.org/wiki/Internal_and_external_angles) ] External Angle
# * [ [w](https://en.wikipedia.org/wiki/Extouch_triangle) ] Extouch Triangle
# * [ [w](https://en.wikipedia.org/wiki/Face_(geometry)) ] Face
# * [ [w](https://en.wikipedia.org/wiki/Faceting) ] Faceting
# * [ [w](https://en.wikipedia.org/wiki/Frustum) ] Frustum
# * [ [w](https://en.wikipedia.org/wiki/Galois_geometry) ] Galois Geometry
# * [ [w](https://en.wikipedia.org/wiki/Generatrix) ] Generatrix
# * [ [w](https://en.wikipedia.org/wiki/Geodesic) ] Geodesic
# * [ [w](https://en.wikipedia.org/wiki/Geometry) ] Geometry
# * [ [w](https://en.wikipedia.org/wiki/Computational_geometry) ] Geometry, Computational
# * [ [w](https://en.wikipedia.org/wiki/Descriptive_geometry) ] Geometry, Descriptive
# * [ w ] Geometry, Differential
# * [ [w](https://en.wikipedia.org/wiki/Diophantine_geometry) ] Geometry, Diophantine
# * [ [w](https://en.wikipedia.org/wiki/Discrete_geometry) ] Geometry, Discrete
# * [ [w](https://en.wikipedia.org/wiki/Euclidean_geometry) ] Geometry, Euclidean
# * [ [w](https://en.wikipedia.org/wiki/Galois_geometry) ] Geometry, Galois
# * [ [w](https://en.wikipedia.org/wiki/History_of_geometry) ] Geometry, history
# * [ w ] Geometry, Hyperbolic
# * [ [w](https://en.wikipedia.org/wiki/Incidence_geometry) ] Geometry, Incidence
# * [ [w](https://en.wikipedia.org/wiki/Inversive_geometry) ] Geometry, Inversive
# * [ [w](https://en.wikipedia.org/wiki/Modern_triangle_geometry) ] Geometry, Modern Triangle
# * [ [w](https://en.wikipedia.org/wiki/Non-Euclidean_geometry) ] Geometry, Non Euclidean
# * [ w ] Geometry, Projective
# * [ w ] Geometry, Riemannian
# * [ [w](https://en.wikipedia.org/wiki/Solid_geometry) ] Geometry, Solid
# * [ w ] Geometry, Spherical
# * [ [w](https://en.wikipedia.org/wiki/Symplectic_geometry) ] Geometry, Symplectic
# * [ [w](https://en.wikipedia.org/wiki/Synthetic_geometry) ] Geometry, Synthetic
# * [ [w](https://en.wikipedia.org/wiki/Glissette) ] Glissette
# * [ [w](https://en.wikipedia.org/wiki/Gossard_perspector) ] Gossard Perspector
# * [ [w](https://en.wikipedia.org/wiki/Lemoine_point) ] Grebe Point (Lemoine Point, Symmedian Point)
# * [ [w](https://en.wikipedia.org/wiki/Half-space_(geometry)) ] Half-Space
# * [ [w](https://en.wikipedia.org/wiki/Homothetic_center) ] Homothetic Center (Center of Similitude)
# * [ [w](https://en.wikipedia.org/wiki/Hosohedron) ] Hosohedron
# * [ [w](https://en.wikipedia.org/wiki/Hyperbola) ] Hyperbola
# * [ [w](https://en.wikipedia.org/wiki/Hyperbolic_angle) ] Hyperbolic Angle
# * [ [w](https://en.wikipedia.org/wiki/Hyperbolic_motion) ] Hyperbolic Motion
# * [ [w](https://en.wikipedia.org/wiki/Hyperplane) ] Hyperplane
# * [ [w](https://en.wikipedia.org/wiki/Supporting_hyperplane) ] Hyperplane, Supporting
# * [ [w](https://en.wikipedia.org/wiki/N-sphere) ] Hypersphere ($n$-Sphere)
# * [ [w](https://en.wikipedia.org/wiki/Hypersurface) ] Hypersurface
# * [ [w](https://en.wikipedia.org/wiki/Hypotenuse) ] Hypotenuse
# * [ [w](https://en.wikipedia.org/wiki/Icosahedron) ] Icosahedron
# * [ [w](https://en.wikipedia.org/wiki/Incenter) ] Incenter
# * [ [w](https://en.wikipedia.org/wiki/Incidence_geometry) ] Incidence Geometry
# * [ [w](https://en.wikipedia.org/wiki/Incircle_and_excircles) ] Incircle (Inscribed Circle)
# * [ [w](https://en.wikipedia.org/wiki/Circumconic_and_inconic) ] Inconic
# * [ [w](https://en.wikipedia.org/wiki/Inellipse) ] Inellipse
# * [ [w](https://en.wikipedia.org/wiki/Mandart_inellipse) ] Inellipse, Mandart
# * [ [w](https://en.wikipedia.org/wiki/Steiner_inellipse) ] Inellipse, Steiner
# * [ [w](https://en.wikipedia.org/wiki/Internal_and_external_angles) ] Internal Angle
# * [ [w](https://en.wikipedia.org/wiki/Inscribed_angle) ] Inscribed Angle
# * [ [w](https://en.wikipedia.org/wiki/Incircle_and_excircles) ] Inscribed Circle (Incircle)
# * [ [w](https://en.wikipedia.org/wiki/Intersection_(geometry)) ] Intersection
# * [ [w](https://en.wikipedia.org/wiki/Intersection_curve) ] Intersection Curve
# * [ [w](https://en.wikipedia.org/wiki/Inverse_curve) ] Inverse Curve
# * [ [w](https://en.wikipedia.org/wiki/Inversive_geometry) ] Inversive Geometry
# * [ [w](https://en.wikipedia.org/wiki/Isogonal_figure) ] Isogonality (Vertex-Transitivity)
# * [ [w](https://en.wikipedia.org/wiki/Isotoxal_figure) ] Isotoxality (Edge-Transitivity)
# * [ [w](https://en.wikipedia.org/wiki/Isosceles_triangle) ] Isosceles Triangle
# * [ [w](https://en.wikipedia.org/wiki/Johnson_solid) ] Johnson Solid
# * [ [w](https://en.wikipedia.org/wiki/Kiepert_conics) ] Kiepert Conic
# * [ [w](https://en.wikipedia.org/wiki/Lemoine_point) ] Lemoine Point (Grebe Point, Symmedian Point)
# * [ [w](https://en.wikipedia.org/wiki/Lemoine%27s_problem) ] Lemoine's Problem
# * [ [w](https://en.wikipedia.org/wiki/Lens_(geometry)) ] Lens
# * [ [w](https://en.wikipedia.org/wiki/Line_(geometry)) ] Line
# * [ [w](https://en.wikipedia.org/wiki/Central_line_(geometry)) ] Line, Central
# * [ [w](https://en.wikipedia.org/wiki/Complex_line) ] Line, Complex
# * [ [w](https://en.wikipedia.org/wiki/Concurrent_lines) ] Line, Concurrent
# * [ [w](https://en.wikipedia.org/wiki/Euler_line) ] Line, Euler
# * [ [w](https://en.wikipedia.org/wiki/Simson_line) ] Line, Simson
# * [ [w](https://en.wikipedia.org/wiki/Skew_lines) ] Line, Skew
# * [ [w](https://en.wikipedia.org/wiki/Supporting_line) ] Line, Supporting
# * [ [w](https://en.wikipedia.org/wiki/Line_element) ] Line Element
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Line of Apsides
# * [ [w](https://en.wikipedia.org/wiki/Line_segment) ] Line Segment
# * [ [w](https://en.wikipedia.org/wiki/Locus_(mathematics)) ] Locus
# * [ [w](https://en.wikipedia.org/wiki/Lune_of_Hippocrates) ] Lune of Hippocrates
# * [ [w](https://en.wikipedia.org/wiki/Mandart_inellipse) ] Mandart Inellipse
# * [ [w](https://en.wikipedia.org/wiki/Medial_triangle) ] Medial Triangle (Midpoint Triangle)
# * [ [w](https://en.wikipedia.org/wiki/Median_(geometry)) ] Median
# * [ [w](https://en.wikipedia.org/wiki/Midpoint) ] Midpoint
# * [ [w](https://en.wikipedia.org/wiki/Medial_triangle) ] Midpoint Triangle (Medial Triangle)
# * [ [w](https://en.wikipedia.org/wiki/Mittenpunkt) ] Mittenpunkt
# * [ [w](https://en.wikipedia.org/wiki/Modern_triangle_geometry) ] Modern Triangle Geometry
# * [ [w](https://en.wikipedia.org/wiki/Morley_centers) ] Morley Center
# * [ [w](https://en.wikipedia.org/wiki/Morley%27s_trisector_theorem) ] Moreley's Trisector Theorem
# * [ [w](https://en.wikipedia.org/wiki/Myriagon) ] Myriagon
# * [ [w](https://en.wikipedia.org/wiki/N-sphere) ] $n$-Sphere (Hypersphere)
# * [ [w](https://en.wikipedia.org/wiki/Nagel_point) ] Nagel Point
# * [ [w](https://en.wikipedia.org/wiki/Neusis_construction) ] Neusis
# * [ [w](https://en.wikipedia.org/wiki/Nine-point_center) ] Nine-Point Center
# * [ [w](https://en.wikipedia.org/wiki/Nine-point_circle) ] Nine-Point Circle
# * [ [w](https://en.wikipedia.org/wiki/Non-Euclidean_geometry) ] Non Euclidean Geometry
# * [ [w](https://en.wikipedia.org/wiki/Normal_(geometry)) ] Normal
# * [ [w](https://en.wikipedia.org/wiki/Acute_and_obtuse_triangles) ] Obtuse Triangle
# * [ [w](https://en.wikipedia.org/wiki/Orthocenter) ] Orthocenter
# * [ [w](https://en.wikipedia.org/wiki/Orthocentric_system) ] Orthocentric System
# * [ [w](https://en.wikipedia.org/wiki/Orthogonality) ] Orthogonality
# * [ [w](https://en.wikipedia.org/wiki/Oval) ] Oval
# * [ [w](https://en.wikipedia.org/wiki/Pappus%27s_hexagon_theorem) ] Pappus' Hexagon Theorem
# * [ [w](https://en.wikipedia.org/wiki/Parabola) ] Parabola
# * [ [w](https://en.wikipedia.org/wiki/Parallel_curve) ] Parallel Curve
# * [ [w](https://en.wikipedia.org/wiki/Distance_between_two_parallel_lines) ] Parallel Line, distance
# * [ [w](https://en.wikipedia.org/wiki/Parallel_postulate) ] Parallel Postulate
# * [ [w](https://en.wikipedia.org/wiki/Parallelepiped) ] Parallelepiped
# * [ [w](https://en.wikipedia.org/wiki/Parallel_(geometry)) ] Parallelism
# * [ [w](https://en.wikipedia.org/wiki/Parallelogon) ] Parallelogon
# * [ [w](https://en.wikipedia.org/wiki/Parallelogram) ] Parallelogram
# * [ [w](https://en.wikipedia.org/wiki/Parallelohedron) ] Parallelohedron
# * [ [w](https://en.wikipedia.org/wiki/Pencil_(geometry)) ] Pencil
# * [ [w](https://en.wikipedia.org/wiki/Pentagonal_antiprism) ] Pentagonal Antiprism
# * [ [w](https://en.wikipedia.org/wiki/Pentagonal_bipyramid) ] Pentagonal Bipyramid
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Periapsis
# * [ [w](https://en.wikipedia.org/wiki/Perimeter) ] Perimeter
# * [ [w](https://en.wikipedia.org/wiki/Perspective_(graphical)) ] Perspective
# * [ [w](https://en.wikipedia.org/wiki/Curvilinear_perspective) ] Perspective, Curvilinear
# * [ [w](https://en.wikipedia.org/wiki/Perspectivity) ] Perspectivity
# * [ [w](https://en.wikipedia.org/wiki/Petersen%E2%80%93Morley_theorem) ] Petersen-Morley Theorem
# * [ [w](https://en.wikipedia.org/wiki/Plane_(mathematics)) ] Plane
# * [ [w](https://en.wikipedia.org/wiki/Complex_plane) ] Plane, Complex
# * [ [w](https://en.wikipedia.org/wiki/Playfair%27s_axiom) ] Playfair's Axiom
# * [ [w](https://en.wikipedia.org/wiki/Point_(geometry)) ] Point
# * [ [w](https://en.wikipedia.org/wiki/Brocard_points) ] Point, Brocard
# * [ [w](https://en.wikipedia.org/wiki/Concyclic_points) ] Point, Concyclic
# * [ [w](https://en.wikipedia.org/wiki/De_Longchamps_point) ] Point, De Longchamps
# * [ [w](https://en.wikipedia.org/wiki/Exeter_point) ] Point, Exeter
# * [ [w](https://en.wikipedia.org/wiki/Lemoine_point) ] Point, Grebe (Lemoine, Symmedian)
# * [ [w](https://en.wikipedia.org/wiki/Lemoine_point) ] Point, Lemoine (Grebe, Symmedian)
# * [ [w](https://en.wikipedia.org/wiki/Nagel_point) ] Point, Nagel
# * [ [w](https://en.wikipedia.org/wiki/Schiffler_point) ] Point, Schiffler
# * [ [w](https://en.wikipedia.org/wiki/Steiner_point_(triangle)) ] Point, Steiner
# * [ [w](https://en.wikipedia.org/wiki/Lemoine_point) ] Point, Symmedian (Grebe, Lemoine)
# * [ [w](https://en.wikipedia.org/wiki/Trisected_perimeter_point) ] Point, Trisected Perimeter
# * [ [w](https://en.wikipedia.org/wiki/Point_reflection) ] Point Reflection
# * [ [w](https://en.wikipedia.org/wiki/Trilinear_polarity) ] Polarity, Trilinear
# * [ [w](https://en.wikipedia.org/wiki/Polygon) ] Polygon
# * [ [w](https://en.wikipedia.org/wiki/Tangential_polygon) ] Polygon, Circumscribed (Tangential)
# * [ [w](https://en.wikipedia.org/wiki/Constructible_polygon) ] Polygon, Constructible
# * [ [w](https://en.wikipedia.org/wiki/Convex_polygon) ] Polygon, Convex
# * [ [w](https://en.wikipedia.org/wiki/Equiangular_polygon) ] Polygon, Equiangular
# * [ [w](https://en.wikipedia.org/wiki/Equilateral_polygon) ] Polygon, Equilateral
# * [ [w](https://en.wikipedia.org/wiki/Regular_polygon) ] Polygon, Regular
# * [ [w](https://en.wikipedia.org/wiki/Simple_polygon) ] Polygon, Simple
# * [ [w](https://en.wikipedia.org/wiki/Skew_polygon) ] Polygon, Skew
# * [ [w](https://en.wikipedia.org/wiki/Star_polygon) ] Polygon, Star
# * [ [w](https://en.wikipedia.org/wiki/Tangential_polygon) ] Polygon, Tangential (Circumscribed)
# * [ [w](https://en.wikipedia.org/wiki/Polygonal_chain) ] Polygonal Chain
# * [ [w](https://en.wikipedia.org/wiki/Polyhedron) ] Polyhedron
# * [ [w](https://en.wikipedia.org/wiki/Dual_polyhedron) ] Polyhedron, Dual
# * [ [w](https://en.wikipedia.org/wiki/Quasiregular_polyhedron) ] Polyhedron, Quasiregular
# * [ [w](https://en.wikipedia.org/wiki/Semiregular_polyhedron) ] Polyhedron, Semiregular
# * [ [w](https://en.wikipedia.org/wiki/Snub_polyhedron) ] Polyhedron, Snub
# * [ [w](https://en.wikipedia.org/wiki/Spherical_polyhedron) ] Polyhedron, Spherical
# * [ [w](https://en.wikipedia.org/wiki/Polytope) ] Polytope
# * [ [w](https://en.wikipedia.org/wiki/Chiral_polytope) ] Polytope, Chiral
# * [ [w](https://en.wikipedia.org/wiki/Regular_polytope) ] Polytope, Regular
# * [ [w](https://en.wikipedia.org/wiki/Pons_asinorum) ] Pons Asinorum
# * [ [w](https://en.wikipedia.org/wiki/Power_center_(geometry)) ] Power Center
# * [ [w](https://en.wikipedia.org/wiki/Prism_(geometry)) ] Prism
# * [ [w](https://en.wikipedia.org/wiki/Prismatoid) ] Prismatoid
# * [ [w](https://en.wikipedia.org/wiki/Triple_product) ] Product, Triple
# * [ [w](https://en.wikipedia.org/wiki/3D_projection) ] Projection, 3D
# * [ [w](https://en.wikipedia.org/wiki/Pyramid_(geometry)) ] Pyramid
# * [ [w](https://en.wikipedia.org/wiki/Bipyramid) ] Pyramid, Double (Bipyramid, Dipyramid)
# * [ [w](https://en.wikipedia.org/wiki/Pythagorean_theorem) ] Pythagorean Theorem
# * [ [w](https://en.wikipedia.org/wiki/Quadrilateral) ] Quadrilateral
# * [ [w](https://en.wikipedia.org/wiki/Quasiregular_polyhedron) ] Quasiregular Polyhedron
# * [ [w](https://en.wikipedia.org/wiki/Rotational_symmetry) ] Radial Symmetry (Rotational Symmetry)
# * [ [w](https://en.wikipedia.org/wiki/Radian) ] Radian
# * [ [w](https://en.wikipedia.org/wiki/Radius) ] Radius
# * [ [w](https://en.wikipedia.org/wiki/Cross-ratio) ] Ratio, Anharmonic (Cross, Double)
# * [ [w](https://en.wikipedia.org/wiki/Cross-ratio) ] Ratio, Cross (Anharmonic, Double)
# * [ [w](https://en.wikipedia.org/wiki/Cross-ratio) ] Ratio, Double (Anharmonic, Cross)
# * [ [w](https://en.wikipedia.org/wiki/Real_coordinate_space) ] Real Coordinate Space
# * [ [w](https://en.wikipedia.org/wiki/Rectangle) ] Rectangle
# * [ [w](https://en.wikipedia.org/wiki/Rectangular_cuboid) ] Rectangular, Cuboid
# * [ [w](https://en.wikipedia.org/wiki/Reflection_(mathematics)) ] Reflection
# * [ [w](https://en.wikipedia.org/wiki/Reflection_symmetry) ] Reflection Symmetry
# * [ [w](https://en.wikipedia.org/wiki/Point_reflection) ] Reflection, Point
# * [ [w](https://en.wikipedia.org/wiki/Regular_polygon) ] Regular Polygon
# * [ [w](https://en.wikipedia.org/wiki/Regular_polytope) ] Regular Polytope
# * [ [w](https://en.wikipedia.org/wiki/Rhombic_dodecahedron) ] Rhombic Dodecahedron
# * [ [w](https://en.wikipedia.org/wiki/Rhombohedron) ] Rhombohedron
# * [ [w](https://en.wikipedia.org/wiki/Riemann_sphere) ] Riemann Sphere
# * [ [w](https://en.wikipedia.org/wiki/Right_angle) ] Right Angle
# * [ [w](https://en.wikipedia.org/wiki/Right_circular_cylinder) ] Right Circular Cylinder
# * [ [w](https://en.wikipedia.org/wiki/Right_triangle) ] Right Triangle
# * [ [w](https://en.wikipedia.org/wiki/Special_right_triangle) ] Right Triangle, Special
# * [ [w](https://en.wikipedia.org/wiki/Rotational_symmetry) ] Rotational Symmetry (Radial Symmetry)
# * [ [w](https://en.wikipedia.org/wiki/Routh%27s_theorem) ] Routh's Theorem
# * [ [w](https://en.wikipedia.org/wiki/Straightedge_and_compass_construction) ] Ruler-and-Compass Construction
# * [ [w](https://en.wikipedia.org/wiki/Sagitta_(geometry)) ] Sagitta
# * [ [w](https://en.wikipedia.org/wiki/Triangle#Type_of_triangles) ] Scalene Triangle
# * [ [w](https://en.wikipedia.org/wiki/Scaling_(geometry)) ] Scaling
# * [ [w](https://en.wikipedia.org/wiki/Schiffler_point) ] Schiffler Point
# * [ [w](https://en.wikipedia.org/wiki/Secant_line) ] Secant
# * [ [w](https://en.wikipedia.org/wiki/Circular_segment) ] Segment, Circular (Disk)
# * [ [w](https://en.wikipedia.org/wiki/Circular_segment) ] Segment, Disk (Circular)
# * [ [w](https://en.wikipedia.org/wiki/Line_segment) ] Segment, Line
# * [ [w](https://en.wikipedia.org/wiki/Spherical_segment) ] Segment, Spherical
# * [ [w](https://en.wikipedia.org/wiki/Semicircle) ] Semicircle
# * [ [w](https://en.wikipedia.org/wiki/Semiperimeter) ] Semiperimeter
# * [ [w](https://en.wikipedia.org/wiki/Semiregular_polyhedron) ] Semiregular Polyhedron
# * [ [w](https://en.wikipedia.org/wiki/Similarity_(geometry)) ] Similarity
# * [ [w](https://en.wikipedia.org/wiki/Simple_polygon) ] Simple Polygon
# * [ [w](https://en.wikipedia.org/wiki/Simson_line) ] Simson Line
# * [ [w](https://en.wikipedia.org/wiki/Infinite_skew_polygon) ] Skew Apeirogon
# * [ [w](https://en.wikipedia.org/wiki/Skew_lines) ] Skew Line
# * [ [w](https://en.wikipedia.org/wiki/Skew_polygon) ] Skew Polygon
# * [ [w](https://en.wikipedia.org/wiki/Snub_polyhedron) ] Snub Polyhedron
# * [ [w](https://en.wikipedia.org/wiki/Archimedean_solid) ] Solid, Archimedean
# * [ [w](https://en.wikipedia.org/wiki/Catalan_solid) ] Solid, Catalan
# * [ [w](https://en.wikipedia.org/wiki/Johnson_solid) ] Solid, Johnson
# * [ [w](https://en.wikipedia.org/wiki/Solid_geometry) ] Solid Geometry
# * [ [w](https://en.wikipedia.org/wiki/Real_coordinate_space) ] Space, Real Coordinate
# * [ [w](https://en.wikipedia.org/wiki/Special_right_triangle) ] Special Right Triangle
# * [ [w](https://en.wikipedia.org/wiki/Sphere) ] Sphere
# * [ [w](https://en.wikipedia.org/wiki/Circumscribed_sphere) ] Sphere, Circumscribed
# * [ [w](https://en.wikipedia.org/wiki/Riemann_sphere) ] Sphere, Riemann
# * [ [w](https://en.wikipedia.org/wiki/Spherical_cap) ] Spherical Cap
# * [ [w](https://en.wikipedia.org/wiki/Spherical_polyhedron) ] Spherical Polyhedron
# * [ [w](https://en.wikipedia.org/wiki/Spherical_segment) ] Spherical Segment
# * [ [w](https://en.wikipedia.org/wiki/Spieker_center) ] Spieker Center
# * [ [w](https://en.wikipedia.org/wiki/Spieker_circle) ] Spieker Circle
# * [ [w](https://en.wikipedia.org/wiki/Spiral) ] Spiral
# * [ [w](https://en.wikipedia.org/wiki/Spirolateral) ] Spirolateral
# * [ [w](https://en.wikipedia.org/wiki/Splitter_(geometry)) ] Splitter
# * [ [w](https://en.wikipedia.org/wiki/Squaring_the_circle) ] squaring the circle
# * [ [w](https://en.wikipedia.org/wiki/Star_polygon) ] Star Polygon
# * [ [w](https://en.wikipedia.org/wiki/Steiner_conic) ] Steiner Conic
# * [ [w](https://en.wikipedia.org/wiki/Steiner_ellipse) ] Steiner Ellipse
# * [ [w](https://en.wikipedia.org/wiki/Steiner_inellipse) ] Steiner Inellipse
# * [ [w](https://en.wikipedia.org/wiki/Steiner_point_(triangle)) ] Steiner Point
# * [ [w](https://en.wikipedia.org/wiki/Stellation) ] Stellation
# * [ [w](https://en.wikipedia.org/wiki/Straightedge) ] Straightedge
# * [ [w](https://en.wikipedia.org/wiki/Subtended_angle) ] Subtended Angle
# * [ [w](https://en.wikipedia.org/wiki/Supporting_hyperplane) ] Supporting Hyperplane
# * [ [w](https://en.wikipedia.org/wiki/Supporting_line) ] Supporting Line
# * [ [w](https://en.wikipedia.org/wiki/Surface_(mathematics)) ] Surface
# * [ [w](https://en.wikipedia.org/wiki/Symmedian) ] Symmedian
# * [ [w](https://en.wikipedia.org/wiki/Lemoine_point) ] Symmedian Point (Grebe Point, Lemoine Point)
# * [ [w](https://en.wikipedia.org/wiki/Axial_symmetry) ] Symmetry, Axial
# * [ [w](https://en.wikipedia.org/wiki/Rotational_symmetry) ] Symmetry, Radial (Rotational)
# * [ [w](https://en.wikipedia.org/wiki/Reflection_symmetry) ] Symmetry, Reflection
# * [ [w](https://en.wikipedia.org/wiki/Rotational_symmetry) ] Symmetry, Rotational (Radial)
# * [ [w](https://en.wikipedia.org/wiki/Translational_symmetry) ] Symmetry, Translational
# * [ [w](https://en.wikipedia.org/wiki/Tangent) ] Tangent
# * [ [w](https://en.wikipedia.org/wiki/Tangential_polygon) ] Tangential Polygon (Circumscribed Polygon)
# * [ [w](https://en.wikipedia.org/wiki/Tangential_triangle) ] Tangential Triangle
# * [ [w](https://en.wikipedia.org/wiki/Tessellation) ] Tessellation
# * [ [w](https://en.wikipedia.org/wiki/Tetrakis_hexahedron) ] Tetrakis Hexahedron
# * [ [w](https://en.wikipedia.org/wiki/Thales%27s_theorem) ] Thales' Theorem
# * [ [w](https://en.wikipedia.org/wiki/Tomahawk_(geometry)) ] Tomahawk
# * [ [w](https://en.wikipedia.org/wiki/Translational_symmetry) ] Translational Symmetry
# * [ [w](https://en.wikipedia.org/wiki/Trapezohedron) ] Trapezohedron
# * [ [w](https://en.wikipedia.org/wiki/Trigonal_trapezohedron) ] Trapezohedron, Trigonal
# * [ [w](https://en.wikipedia.org/wiki/Trapezoid) ] Trapezoid
# * [ [w](https://en.wikipedia.org/wiki/Triangle) ] Triangle
# * [ [w](https://en.wikipedia.org/wiki/Acute_and_obtuse_triangles) ] Triangle, Acute
# * [ [w](https://en.wikipedia.org/wiki/Brocard_triangle) ] Triangle, Brocard
# * [ [w](https://en.wikipedia.org/wiki/Circular_triangle) ] Triangle, Circular
# * [ [w](https://en.wikipedia.org/wiki/Equilateral_triangle) ] Triangle, Equilateral
# * [ [w](https://en.wikipedia.org/wiki/Extouch_triangle) ] Triangle, Extouch
# * [ [w](https://en.wikipedia.org/wiki/Isosceles_triangle) ] Triangle, Isosceles
# * [ [w](https://en.wikipedia.org/wiki/Medial_triangle) ] Triangle, Medial (Midpoint)
# * [ [w](https://en.wikipedia.org/wiki/Medial_triangle) ] Triangle, Midpoint (Medial)
# * [ [w](https://en.wikipedia.org/wiki/Acute_and_obtuse_triangles) ] Triangle, Obtuse
# * [ [w](https://en.wikipedia.org/wiki/Right_triangle) ] Triangle, Right
# * [ [w](https://en.wikipedia.org/wiki/Triangle#Type_of_triangles) ] Triangle, Scalene
# * [ [w](https://en.wikipedia.org/wiki/Special_right_triangle) ] Triangle, Special Right
# * [ [w](https://en.wikipedia.org/wiki/Tangential_triangle) ] Triangle, Tangential
# * [ [w](https://en.wikipedia.org/wiki/Triangle_center) ] Triangle Center
# * [ [w](https://en.wikipedia.org/wiki/List_of_triangle_inequalities) ] Triangle Inequalities
# * [ [w](https://en.wikipedia.org/wiki/Trigonal_trapezohedron) ] Trigonal Trapezohedron
# * [ [w](https://en.wikipedia.org/wiki/Trilinear_coordinates) ] Trilinear Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Trilinear_polarity) ] Trilinear Polarity
# * [ [w](https://en.wikipedia.org/wiki/Triple_product) ] Triple Product
# * [ [w](https://en.wikipedia.org/wiki/Trisected_perimeter_point) ] Trisected Perimeter Point
# * [ [w](https://en.wikipedia.org/wiki/Angle_trisection) ] Trisection, Angle
# * [ [w](https://en.wikipedia.org/wiki/Unital_(geometry)) ] Unital
# * [ [w](https://en.wikipedia.org/wiki/Upper_bound_theorem) ] Upper Bound Theorem
# * [ [w](https://en.wikipedia.org/wiki/Vesica_piscis) ] Vesica Piscis
# * [ [w](https://en.wikipedia.org/wiki/Vertex_(geometry)) ] Vertex
# * [ [w](https://en.wikipedia.org/wiki/Isogonal_figure) ] Vertex-Transitivity (Isogonality)
# * [ [w](https://en.wikipedia.org/wiki/Viviani%27s_theorem) ] Viviani's Theorem
# * [ [w](https://en.wikipedia.org/wiki/Volume) ] Volume
# * [ [w](https://en.wikipedia.org/wiki/Zonogon) ] Zonogon
# * [ [w](https://en.wikipedia.org/wiki/Zonohedron) ] Zonohedron

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# [[W](https://en.wikipedia.org/wiki/Polygon)] Polygon
# * [[W](https://en.wikipedia.org/wiki/Triangle)] Trigon (Triangle)
#   * [[W](https://en.wikipedia.org/wiki/Acute_and_obtuse_triangles)] Acute Triangle
#   * [[W](https://en.wikipedia.org/wiki/Equilateral_triangle)] Equilateral Triangle
#   * [[W](https://en.wikipedia.org/wiki/Isosceles_triangle)] Isosceles Triangle
#     * [[W](https://en.wikipedia.org/wiki/Golden_triangle_(mathematics))] Golden Triangle
#   * [[W](https://en.wikipedia.org/wiki/Acute_and_obtuse_triangles)] Obtuse Triangle
#   * [[W](https://en.wikipedia.org/wiki/Right_triangle)] Right Triangle
#     * [[W](https://en.wikipedia.org/wiki/Special_right_triangle)] Special Right Triangle
#   * [W] Scalene Triangle
# * [[W](https://en.wikipedia.org/wiki/Quadrilateral)] Tetragon (Quadrilateral)
#   * [[W](https://en.wikipedia.org/wiki/Parallelogram)] Parallelogram
#     * [[W](https://en.wikipedia.org/wiki/Rhomboid)] Rhomboid
#     * [[W](https://en.wikipedia.org/wiki/Rectangle)] Rectangle
#     * [[W](https://en.wikipedia.org/wiki/Square)] Square
#     * [[W](https://en.wikipedia.org/wiki/Rhombus)] Rhombus
#     * [[W](https://en.wikipedia.org/wiki/Trapezoid)] Trapezoid
# * [[W](https://en.wikipedia.org/wiki/Pentagon)] Pentagon
# * [[W](https://en.wikipedia.org/wiki/Hexagon)] Hexagon
# * [[W](https://en.wikipedia.org/wiki/Heptagon)] Heptagon
# * [[W](https://en.wikipedia.org/wiki/Octagon)] Octagon
# * [[W](https://en.wikipedia.org/wiki/Nonagon)] Nonagon
# * [[W](https://en.wikipedia.org/wiki/Decagon)] Decagon
# * [[W](https://en.wikipedia.org/wiki/Hendecagon)] Hendecagon
# * [[W](https://en.wikipedia.org/wiki/Dodecagon)] Dodecagon
# * [[W](https://en.wikipedia.org/wiki/Apeirogon)] Apeirogon
#
# [[W](https://en.wikipedia.org/wiki/Equilateral_polygon)] Equilateral Polygon
# * [[W](https://en.wikipedia.org/wiki/Equilateral_pentagon)] Equilateral Pentagon
# * [[W](https://en.wikipedia.org/wiki/Equilateral_triangle)] Equilateral Triangle
#
# [[W](https://en.wikipedia.org/wiki/Star_polygon)] Star Polygon
# * [[W](https://en.wikipedia.org/wiki/Pentagram)] Pentagram
# * [[W](https://en.wikipedia.org/wiki/Hexagram)] Hexagram
# * [[W](https://en.wikipedia.org/wiki/Heptagram)] Heptagram
# * [[W](https://en.wikipedia.org/wiki/Octagram)] Octagram
# * [[W](https://en.wikipedia.org/wiki/Enneagram_(geometry))] Nonagram
# * [[W](https://en.wikipedia.org/wiki/Decagram_(geometry))] Decagram
# * [[W](https://en.wikipedia.org/wiki/Hendecagram)] Hendecagram
# * [[W](https://en.wikipedia.org/wiki/Dodecagram)] Dodecagram

# %% [markdown]
# [[W](https://en.wikipedia.org/wiki/Solid_geometry)] Solid Geometry
# * [[W](https://en.wikipedia.org/wiki/Ball_(mathematics))] Ball
# * [[W](https://en.wikipedia.org/wiki/Cone)] Cone
# * [[W](https://en.wikipedia.org/wiki/Cylinder)] Cylinder
#   * [[W](https://en.wikipedia.org/wiki/Right_circular_cylinder)] Right Circular Cylinder
# * [[W](https://en.wikipedia.org/wiki/Polyhedron)] Polyhedron
#   * [[W](https://en.wikipedia.org/wiki/Cuboid)] Cuboid
#     * Cube (Square Cuboid)
#     * Rectangular Cuboid
#   * [[W](https://en.wikipedia.org/wiki/Pyramid_(geometry))] Pyramid
#     * [[W](https://en.wikipedia.org/wiki/Square_pyramid)] Square Pyramid
#
# [[W](https://en.wikipedia.org/wiki/Quadric)] Quadric Surface
# * [[W](https://en.wikipedia.org/wiki/Ellipsoid)] Ellipsoid
#   * [[W](https://en.wikipedia.org/wiki/Spheroid)] Ellipsoid of Revolution (Spheroid)
#     * Oblate Spheroid
#     * Prolate Spheroid
#   * [[W](https://en.wikipedia.org/wiki/Sphere)] Sphere
# * [[W](https://en.wikipedia.org/wiki/Paraboloid)] Paraboloid
# * [[W](https://en.wikipedia.org/wiki/Hyperboloid)] Hyperboloid
#   * One-Sheet Hyperboloid (Hyperbolic Hyperboloid)
#   * Two-Sheet Hyperboloid (Elliptic Hyperboloid)
#
# [[W](https://en.wikipedia.org/wiki/Superquadrics)] Superquadrics
#
# [[W](https://en.wikipedia.org/wiki/Platonic_solid)] Platonic Solid
# * [[W](https://en.wikipedia.org/wiki/Cube)] Cube (Square Cuboid)
# * [[W](https://en.wikipedia.org/wiki/Octahedron)] Octahedron
# * [[W](https://en.wikipedia.org/wiki/Regular_dodecahedron)] Regular Dodecahedron
# * [[W](https://en.wikipedia.org/wiki/Regular_icosahedron)] Regular Icosahedron
# * [[W](https://en.wikipedia.org/wiki/Tetrahedron)] Tetrahedron (Triangular Pyramid)
#
# [[W](https://en.wikipedia.org/wiki/Archimedean_solid)] Archimedean Solid
# * [[W](https://en.wikipedia.org/wiki/Cuboctahedron)] Cuboctahedron
# * [[W](https://en.wikipedia.org/wiki/Icosidodecahedron)] Icosidodecahedron
# * [[W](https://en.wikipedia.org/wiki/Rhombicosidodecahedron)] Rhombicosidodecahedron
# * [[W](https://en.wikipedia.org/wiki/Rhombicuboctahedron)] Rhombicuboctahedron
# * [[W](https://en.wikipedia.org/wiki/Snub_cube)] Snub Cube
# * [[W](https://en.wikipedia.org/wiki/Snub_dodecahedron)] Snub Dodecahedron
# * [[W](https://en.wikipedia.org/wiki/Truncated_cube)] Truncated Cube
# * [[W](https://en.wikipedia.org/wiki/Truncated_cuboctahedron)] Truncated Cuboctahedron
# * [[W](https://en.wikipedia.org/wiki/Truncated_dodecahedron)] Truncated Dodecahedron
# * [[W](https://en.wikipedia.org/wiki/Truncated_icosahedron)] Truncated Icosahedron
# * [[W](https://en.wikipedia.org/wiki/Truncated_icosidodecahedron)] Truncated Icosidodecahedron
# * [[W](https://en.wikipedia.org/wiki/Truncated_octahedron)] Truncated Octahedron
# * [[W](https://en.wikipedia.org/wiki/Truncated_tetrahedron)] Truncated Tetrahedron
#
# [[W](https://en.wikipedia.org/wiki/Catalan_solid)] Catalan Solid
# * [[W](https://en.wikipedia.org/wiki/Rhombic_triacontahedron)] Rhombic Triacontahedron
#
# nd
# * [[W](https://en.wikipedia.org/wiki/Apeirotope)] Apeirotope
# * [W] Hyperplane
# * [W] Hypersurface
# * [[W](https://en.wikipedia.org/wiki/Polytope)] Polytope
# * [[W](https://en.wikipedia.org/wiki/Simplex)] Simplex

# %% [markdown]
# ---
# ---
# ---
