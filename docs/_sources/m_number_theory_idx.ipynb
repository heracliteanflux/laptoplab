# %% [markdown]
# # Number
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Sections
# ```{tableofcontents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# https://www.eng.auburn.edu/~nelson/courses/elec5200_6200/ELEC5200_6200%20Chapter%203%20Float.pdf

# %% [markdown]
# * [ [y](https://www.youtube.com/watch?v=JYaJDb6XN18) ] `02-09-2016` Brandon Olver. "Using the Euclidean algorithm to find solutions to linear Diophantine equations - Ex 1".

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Accuracy_and_precision) ] Accuracy and Precision
# * [ [w](https://en.wikipedia.org/wiki/Pythagorean_addition) ] Addition, Pythagorean
# * [ [w](https://en.wikipedia.org/wiki/Algorism) ] Algorism
# * [ [w](https://en.wikipedia.org/wiki/Approximation_error) ] Approximation Error
# * [ [w](https://en.wikipedia.org/wiki/Arbitrary-precision_arithmetic) ] Arbitrary-Precision Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic_underflow) ] Arithmetic Underflow
# * [ [w](https://en.wikipedia.org/wiki/Balanced_ternary) ] Balanced Ternary
# * [ [w](https://en.wikipedia.org/wiki/Radix) ] Base
# * [ [w](https://en.wikipedia.org/wiki/Block_floating_point) ] Block Floating-Point
# * [ [w](https://en.wikipedia.org/wiki/Coprocessor) ] Coprocessor
# * [ [w](https://en.wikipedia.org/wiki/Decimal_floating_point) ] Decimal Floating-Point Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Decimal_representation) ] Decimal Representation
# * [ [w](https://en.wikipedia.org/wiki/Decimal_separator) ] Decimal Separator
# * [ [w](https://en.wikipedia.org/wiki/Divisor_sum_identities) ] Divisor Sum Identities
# * [ [w](https://en.wikipedia.org/wiki/Dynamic_range) ] Dynamic Range
# * [ [w](https://en.wikipedia.org/wiki/Exponent_bias) ] Exponent Bias
# * [ [w](https://en.wikipedia.org/wiki/Extended_precision) ] Extended Precision
# * [ [w](https://en.wikipedia.org/wiki/False_precision) ] False Precision
# * [ [w](https://en.wikipedia.org/wiki/Fixed-point_arithmetic) ] Fixed-Point Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Floating-point_arithmetic) ] Floating-Point Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Floating-point_error_mitigation) ] Floating-Point Error Mitigation
# * [ [w](https://en.wikipedia.org/wiki/Floating_point_operations_per_second) ] Floating-Point Operations Per Second (FLOPS)
# * [ [w](https://en.wikipedia.org/wiki/Floating-point_unit) ] Floating-Point Unit (FLU)
# * [ [w](https://en.wikipedia.org/wiki/Guard_digit) ] Guard Digit
# * [ [w](https://en.wikipedia.org/wiki/Half-precision_floating-point_format) ] Half-Precision Floating-Point
# * [ [w](https://en.wikipedia.org/wiki/IEEE_754) ] IEEE 754
# * [ [w](https://en.wikipedia.org/wiki/Interval_arithmetic) ] Interval Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Logarithmic_number_system) ] Logarithmic Number System
# * [ [w](https://en.wikipedia.org/wiki/Machine_epsilon) ] Machine Epsilon
# * [ [w](https://en.wikipedia.org/wiki/Significand) ] Mantissa
# * [ [w](https://en.wikipedia.org/wiki/Modular_exponentiation) ] Modular Exponentiation
# * [ [w](https://en.wikipedia.org/wiki/Non-standard_positional_numeral_systems) ] Nonstandard Positional Numeral System
# * [ [w](https://en.wikipedia.org/wiki/Normal_number_(computing)) ] Normal Number
# * [ [w](https://en.wikipedia.org/wiki/Normalized_number) ] Normalized Number [ [numeral systems](https://en.wikipedia.org/wiki/List_of_numeral_systems) ]
# * [ [w](https://en.wikipedia.org/wiki/Numeral_system) ] Numeral System
# * [ [w](https://en.wikipedia.org/wiki/Octuple-precision_floating-point_format) ] Octuple-Precision Floating-Point
# * [ [w](https://en.wikipedia.org/wiki/Offset_binary) ] Offset Binary
# * [ [w](https://en.wikipedia.org/wiki/Optimal_radix_choice) ] Optimal Radix Choice
# * [ [w](https://en.wikipedia.org/wiki/Positional_notation) ] Positional Numeral System
# * [ [w](https://en.wikipedia.org/wiki/Precision_(computer_science)) ] Precision
# * [ [w](https://en.wikipedia.org/wiki/Propagation_of_uncertainty) ] Propagation of Uncertainty
# * [ [w](https://en.wikipedia.org/wiki/Pythagorean_addition) ] Pythagorean Addition
# * [ [w](https://en.wikipedia.org/wiki/Quadruple-precision_floating-point_format) ] Quadruple-Precision Floating-Point
# * [ [w](https://en.wikipedia.org/wiki/Radix) ] Radix
# * [ [w](https://en.wikipedia.org/wiki/Repeating_decimal) ] Repeating Decimal
# * [ [w](https://en.wikipedia.org/wiki/Roman_numerals) ] Roman Numerals
# * [ [w](https://en.wikipedia.org/wiki/Rounding) ] Rounding
# * [ [w](https://en.wikipedia.org/wiki/Round-off_error) ] Roundoff Error
# * [ [w](https://en.wikipedia.org/wiki/Scientific_notation) ] Scientific Notation
# * [ [w](https://en.wikipedia.org/wiki/Sign-value_notation) ] Sign-Value Notation
# * [ [w](https://en.wikipedia.org/wiki/Signed_number_representations) ] Signed Number Representations
# * [ [w](https://en.wikipedia.org/wiki/Signed-digit_representation) ] Signed-Digit Representation
# * [ [w](https://en.wikipedia.org/wiki/Significand) ] Significand
# * [ [w](https://en.wikipedia.org/wiki/Significant_figures) ] Significant Figures
# * [ [w](https://en.wikipedia.org/wiki/Single-precision_floating-point_format) ] Single-Precision Floating-Point
# * [ [w](https://en.wikipedia.org/wiki/Square_root_algorithms) ] Square Root Algorithm
# * [ [w](https://en.wikipedia.org/wiki/Subnormal_number) ] Subnormal Number
# * [ [w](https://en.wikipedia.org/wiki/Ternary_numeral_system) ] Ternary Numeral System
# * [ [w](https://en.wikipedia.org/wiki/Unit_in_the_last_place) ] Unit in the Last Place

# %% [markdown]
# ---
# ---
# ---
