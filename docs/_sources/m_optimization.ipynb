# %% [markdown]
# # Mathematical Optimization
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# https://en.wikipedia.org/wiki/Category:Optimization_algorithms_and_methods
#
# https://en.wikipedia.org/wiki/Category:Mathematical_optimization_software
#
# https://en.wikipedia.org/wiki/List_of_optimization_software

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Texts

# %% [markdown]
# `2006` V. Jeyakumar & Alexander M. Rubinov. _Continuous Optimization: Current Trends and Modern Applications._ Springer Science & Business Media.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Richard_E._Bellman) ] `1920-1984` Bellman, Richard
# * [ [w](https://en.wikipedia.org/wiki/G%C3%A9rard_Cornu%C3%A9jols) ] `1950-----` Cornuéjois, Gérard
# * [ [w](https://en.wikipedia.org/wiki/Ralph_E._Gomory) ] `1929-----` Gomory, Ralph
# * [ [w](https://en.wikipedia.org/wiki/Leonid_Kantorovich) ] `1912-1986` Kantorovich, Leonid
# * [ [w](https://en.wikipedia.org/wiki/Joseph-Louis_Lagrange) ] `1736-1813` Lagrange, Joseph-Louis
# * [ [w](https://en.wikipedia.org/wiki/John_von_Neumann) ] `1903-1957` Von Neumann, John
# * [ [w](https://en.wikipedia.org/wiki/Victor_Zalgaller) ] `1920-2020` Zalgaller, Victor

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Hungarian_algorithm) ] Algorithm, Hungarian
# * [ [w](https://en.wikipedia.org/wiki/Algorithmic_mechanism_design) ] Algorithmic Mechanism Design
# * [ [w](https://en.wikipedia.org/wiki/Arg_max) ] arg max
# * [ [w](https://en.wikipedia.org/wiki/Arg_max) ] arg min
# * [ [w](https://en.wikipedia.org/wiki/Benders_decomposition) ] Bender's Decomposition
# * [ [w](https://en.wikipedia.org/wiki/Branch_and_bound) ] Branch and Bound
# * [ [w](https://en.wikipedia.org/wiki/Branch_and_cut) ] Branch and Cut
# * [ [w](https://en.wikipedia.org/wiki/Broyden%E2%80%93Fletcher%E2%80%93Goldfarb%E2%80%93Shanno_algorithm) ] Broyden-Fletcher-Goldfarb-Shanno (BFGS) Algorithm
# * [ [w](https://en.wikipedia.org/wiki/Charging_argument) ] Charging Argument
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_optimization) ] Combinatorial Optimization
# * [ [w](https://en.wikipedia.org/wiki/Configuration_linear_program) ] Configuration Linear Program
# * [ [w](https://en.wikipedia.org/wiki/Constraint_(mathematics)) ] Constraint
# * [ [w](https://en.wikipedia.org/wiki/Continuous_optimization) ] Continuous Optimization
# * [ [w](https://en.wikipedia.org/wiki/Loss_function) ] Cost Function (Loss Function, Objective Function)
# * [ [w](https://en.wikipedia.org/wiki/Contour_line) ] Contour Line
# * [ [w](https://en.wikipedia.org/wiki/Cutting_stock_problem) ] Cutting Stock Problem
# * [ [w](https://en.wikipedia.org/wiki/Cutting-plane_method) ] Cutting-Plane Method
# * [ [w](https://en.wikipedia.org/wiki/Design_optimization) ] Design Optimization
# * [ [w](https://en.wikipedia.org/wiki/Deterministic_global_optimization) ] Deterministic Global Optimization
# * [ [w](https://en.wikipedia.org/wiki/Discrete_optimization) ] Discrete Optimization
# * [ [w](https://en.wikipedia.org/wiki/Duality_(optimization)) ] Duality
# * [ [w](https://en.wikipedia.org/wiki/Ekeland%27s_variational_principle) ] Ekeland's Variational Principle
# * [ [w](https://en.wikipedia.org/wiki/Maximum_and_minimum) ] Extrema
# * [ [w](https://en.wikipedia.org/wiki/Hungarian_algorithm) ] Hungarian Algorithm
# * [ [w](https://en.wikipedia.org/wiki/Karush%E2%80%93Kuhn%E2%80%93Tucker_conditions) ] Karush-Kuhn-Tucker (KKT) Conditions
# * [ [w](https://en.wikipedia.org/wiki/Knapsack_problem) ] Knapsack Problem
# * [ [w](https://en.wikipedia.org/wiki/Lagrange_multiplier) ] Lagrange Multiplier
# * [ [w](https://en.wikipedia.org/wiki/Lagrangian_relaxation) ] Lagrangian Relaxation
# * [ [w](https://en.wikipedia.org/wiki/Contour_line) ] Line, Contour
# * [ [w](https://en.wikipedia.org/wiki/Line_search) ] Line Search
# * [ [w](https://en.wikipedia.org/wiki/Loss_function) ] Loss Function (Cost Function, Objective Function)
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_optimization) ] Mathematical Optimization
# * [ [w](https://en.wikipedia.org/wiki/Maximum_and_minimum) ] Maxima
# * [ [w](https://en.wikipedia.org/wiki/Maximum_theorem) ] Maximum Theorem
# * [ [w](https://en.wikipedia.org/wiki/Cutting-plane_method) ] Method, Cutting-Plane
# * [ [w](https://en.wikipedia.org/wiki/Subgradient_method) ] Method, Subgradient
# * [ [w](https://en.wikipedia.org/wiki/Maximum_and_minimum) ] Minima
# * [ [w](https://en.wikipedia.org/wiki/Loss_function) ] Objective Function (Loss Function, Cost Function)
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_optimization) ] Optimization, Combinatorial
# * [ [w](https://en.wikipedia.org/wiki/Continuous_optimization) ] Optimization, Continuous
# * [ [w](https://en.wikipedia.org/wiki/Deterministic_global_optimization) ] Optimization, Deterministic Global
# * [ [w](https://en.wikipedia.org/wiki/Design_optimization) ] Optimization, Design
# * [ [w](https://en.wikipedia.org/wiki/Discrete_optimization) ] Optimization, Discrete
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_optimization) ] Optimization, Mathematical
# * [ [w](https://en.wikipedia.org/wiki/Process_optimization) ] Optimization, Process
# * [ [w](https://en.wikipedia.org/wiki/Simulation-based_optimization) ] Optimization, Simulation-Based
# * [ [w](https://en.wikipedia.org/wiki/Optimization_problem) ] Optimization Problem
# * [ [w](https://en.wikipedia.org/wiki/Pattern_search_(optimization)) ] Pattern Search
# * [ [w](https://en.wikipedia.org/wiki/Cutting_stock_problem) ] Problem, Cutting Stock
# * [ [w](https://en.wikipedia.org/wiki/Knapsack_problem) ] Problem, Knapsack
# * [ [w](https://en.wikipedia.org/wiki/Optimization_problem) ] Problem, Optimization
# * [ [w](https://en.wikipedia.org/wiki/Vehicle_routing_problem) ] Problem, Vehicle Routing
# * [ [w](https://en.wikipedia.org/wiki/Process_optimization) ] Process Optimization
# * [ [w](https://en.wikipedia.org/wiki/Profit_maximization) ] Profit Maximization
# * [ [w](https://en.wikipedia.org/wiki/Saddle_point) ] Saddle Point
# * [ [w](https://en.wikipedia.org/wiki/Satisficing) ] Satisficing
# * [ [w](https://en.wikipedia.org/wiki/Line_search) ] Search, Line
# * [ [w](https://en.wikipedia.org/wiki/Pattern_search_(optimization)) ] Search, Pattern
# * [ [w](https://en.wikipedia.org/wiki/Tabu_search) ] Search, Tabu
# * [ [w](https://en.wikipedia.org/wiki/Simulation-based_optimization) ] Simulation-Based Optimization
# * [ [w](https://en.wikipedia.org/wiki/Subderivative) ] Subderivative
# * [ [w](https://en.wikipedia.org/wiki/Subgradient_method) ] Subgradient Method
# * [ [w](https://en.wikipedia.org/wiki/Tabu_search) ] Tabu Search
# * [ [w](https://en.wikipedia.org/wiki/Test_functions_for_optimization) ] test functions for optimization
# * [ [w](https://en.wikipedia.org/wiki/Trust_region) ] Trust Region
# * [ [w](https://en.wikipedia.org/wiki/Value_function) ] Value Function
# * [ [w](https://en.wikipedia.org/wiki/Vehicle_routing_problem) ] Vehicle Routing Problem

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Constraint_programming) ] Constraint Programming
# * [ [w](https://en.wikipedia.org/wiki/Dynamic_programming) ] Dynamic Programming
# * [ [w](https://en.wikipedia.org/wiki/Goal_programming) ] Goal Programming
# * [ [w](https://en.wikipedia.org/wiki/Integer_programming) ] Integer Programming
# * [ [w](https://en.wikipedia.org/wiki/Linear_programming) ] Linear Programming
# * [ [w](https://en.wikipedia.org/wiki/Constraint_programming) ] Programming, Constraint
# * [ [w](https://en.wikipedia.org/wiki/Dynamic_programming) ] Programming, Dynamic
# * [ [w](https://en.wikipedia.org/wiki/Goal_programming) ] Programming, Goal
# * [ [w](https://en.wikipedia.org/wiki/Integer_programming) ] Programming, Integer
# * [ [w](https://en.wikipedia.org/wiki/Linear_programming) ] Programming, Linear
# * [ [w](https://en.wikipedia.org/wiki/Semi-infinite_programming) ] Programming, Semi Infinite (SIP)
# * [ [w](https://en.wikipedia.org/wiki/Quadratic_programming) ] Programming, Quadratic
# * [ [w](https://en.wikipedia.org/wiki/Sequential_quadratic_programming) ] Programming, Sequential Quadratic
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_programming) ] Programming, Stochastic
# * [ [w](https://en.wikipedia.org/wiki/Quadratic_programming) ] Quadratic Programming
# * [ [w](https://en.wikipedia.org/wiki/Sequential_quadratic_programming) ] Quadratic Programming, Sequential
# * [ [w](https://en.wikipedia.org/wiki/Semi-infinite_programming) ] Semi Infinite Programming (SIP)
# * [ [w](https://en.wikipedia.org/wiki/Sequential_quadratic_programming) ] Sequential Quadratic Programming
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_programming) ] Stochastic Programming

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Operations_research) ] Operations Research
# * [ [w](https://en.wikipedia.org/wiki/Makespan) ] Makespan

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Descent_direction) ] Descent Direction
# * [ [w](https://en.wikipedia.org/wiki/Gradient_descent) ] Gradient Descent

# %% [markdown]
# scheduling
# * [ [w](https://en.wikipedia.org/wiki/Crew_scheduling) ] Crew Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Driver_scheduling_problem) ] Driver Scheduling Problem
# * [ [w](https://en.wikipedia.org/wiki/Earliest_deadline_first_scheduling) ] Earliest Deadline First
# * [ [w](https://en.wikipedia.org/wiki/Fernandez%27s_method) ] Fernandez' Method
# * [ [w](https://en.wikipedia.org/wiki/Identical-machines_scheduling) ] Identical-Machines Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Interval_scheduling) ] Interval Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Optimal_job_scheduling) ] Job Scheduling, Optimal
# * [ [w](https://en.wikipedia.org/wiki/Truthful_job_scheduling) ] Job Scheduling, Truthful
# * [ [w](https://en.wikipedia.org/wiki/Job-shop_scheduling) ] Job-Shop Scheduling
# * [ [w](https://en.wikipedia.org/wiki/List_scheduling) ] List Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Longest-processing-time-first_scheduling) ] Longest-Processing-Time-First Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Optimal_job_scheduling) ] Optimal Job Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Preferential_bidding_system) ] Preferential Bidding System
# * [ [w](https://en.wikipedia.org/wiki/Driver_scheduling_problem) ] Problem, Driver Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Scheduling_(computing)) ] Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Crew_scheduling) ] Scheduling, Crew
# * [ [w](https://en.wikipedia.org/wiki/Identical-machines_scheduling) ] Scheduling, Identical-Machines
# * [ [w](https://en.wikipedia.org/wiki/Interval_scheduling) ] Scheduling, Interval
# * [ [w](https://en.wikipedia.org/wiki/Job-shop_scheduling) ] Scheduling, Job-Shop
# * [ [w](https://en.wikipedia.org/wiki/List_scheduling) ] Scheduling, List
# * [ [w](https://en.wikipedia.org/wiki/Longest-processing-time-first_scheduling) ] Scheduling, Longest-Processing-Time-First
# * [ [w](https://en.wikipedia.org/wiki/Single-machine_scheduling) ] Scheduling, Single-Machine (Single-Resource)
# * [ [w](https://en.wikipedia.org/wiki/Single-machine_scheduling) ] Scheduling, Single-Resource (Single-Machine)
# * [ [w](https://en.wikipedia.org/wiki/Uniform-machines_scheduling) ] Scheduling, Uniform-Machines
# * [ [w](https://en.wikipedia.org/wiki/Single-machine_scheduling) ] Single-Machine Scheduling (Single-Resource Scheduling)
# * [ [w](https://en.wikipedia.org/wiki/Single-machine_scheduling) ] Single-Resource Scheduling (Single-Machine Scheduling)
# * [ [w](https://en.wikipedia.org/wiki/Tardiness_(scheduling)) ] Tardiness
# * [ [w](https://en.wikipedia.org/wiki/Truthful_job_scheduling) ] Truthful Job Scheduling
# * [ [w](https://en.wikipedia.org/wiki/Uniform-machines_scheduling) ] Uniform-Machines Scheduling

# %% [markdown]
# bin packing
# * [ [w](https://en.wikipedia.org/wiki/First-fit-decreasing_bin_packing) ] Bin Packing, First-Fit-Decreasing
# * [ [w](https://en.wikipedia.org/wiki/High-multiplicity_bin_packing) ] Bin Packing, High-Multiplicity
# * [ [w](https://en.wikipedia.org/wiki/Next-fit_bin_packing) ] Bin Packing, Next-Fit
# * [ [w](https://en.wikipedia.org/wiki/Bin_packing_problem) ] Bin Packing Problem
# * [ [w](https://en.wikipedia.org/wiki/First-fit-decreasing_bin_packing) ] First-Fit-Decreasing Bin Packing
# * [ [w](https://en.wikipedia.org/wiki/High-multiplicity_bin_packing) ] High-Multiplicity Bin Packing
# * [ [w](https://en.wikipedia.org/wiki/Next-fit_bin_packing) ] Next-Fit Bin Packing
# * [ [w](https://en.wikipedia.org/wiki/Bin_packing_problem) ] Problem, Bin Packing

# %% [markdown]
# partitioning
# * [ [w](https://en.wikipedia.org/wiki/Multifit_algorithm) ] Algorithm, Multifit
# * [ [w](https://en.wikipedia.org/wiki/Critical_path_method) ] Critical Path Method
# * [ [w](https://en.wikipedia.org/wiki/Greedy_number_partitioning) ] Greedy Number Partitioning
# * [ [w](https://en.wikipedia.org/wiki/Multifit_algorithm) ] Multifit Algorithm
# * [ [w](https://en.wikipedia.org/wiki/Multiway_number_partitioning) ] Multiway Number Partitioning
# * [ [w](https://en.wikipedia.org/wiki/Partition_problem) ] Partition Problem
# * [ [w](https://en.wikipedia.org/wiki/Partition_problem) ] Problem, Partition
# * [ [w](https://en.wikipedia.org/wiki/Subset_sum_problem) ] Problem, Subset Sum
# * [ [w](https://en.wikipedia.org/wiki/Subset_sum_problem) ] Subset Sum Problem

# %% [markdown]
# fair division
# * [ [w](https://en.wikipedia.org/wiki/Divide_and_choose) ] Divide and Choose
# * [ [w](https://en.wikipedia.org/wiki/Envy-freeness) ] Envy-Freeness
# * [ [w](https://en.wikipedia.org/wiki/Fair_division) ] Fair Division
# * [ [w](https://en.wikipedia.org/wiki/Fair_item_allocation) ] Fair Item Allocation
# * [ [w](https://en.wikipedia.org/wiki/Maximin_share) ] Maximin Share
# * [ [w](https://en.wikipedia.org/wiki/Preference_(economics)) ] Preference

# %% [markdown]
# ---
# ---
# ---
