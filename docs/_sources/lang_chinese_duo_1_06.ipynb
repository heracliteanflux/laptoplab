# %% [markdown]
# # 1.6 - Talk about places you visit

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# book                         shū            书📖
# bookstore                    shū   diàn     书店
# food; meal; dish             cài            菜
# Korean language (written)    hán   wén      韩文🇰🇷
# restaurant                   fàn   guǎn     饭馆
# snack                        líng  shí      零食
# supermarket                  chāo  shì      超市
#
# infrequently; not often      bù    cháng    不常
# frequently; often            cháng cháng    常常
#
# to buy                       mǎi            买
# to eat                       chī            吃🍽️
# to go                        qù             去
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# 你喜欢英文书店，对不对？nǐ xǐhuān yīngwén shūdiàn, duìbúduì? You like English bookstores, right?
# 他不喜欢中国菜。tā bù xǐhuān zhōngguó cài He doesn't like Chinese food.
# 他常常去日本超市。tā chángcháng qù rìběn chāoshì He often goes to the Japanese supermarket.
# 我常常去超市。wǒ chángcháng qù chāoshì I go to the supermarket often.
# 我喜欢中国超市。wǒ xǐhuān zhōngguó chāoshì I like Chinese supermarkets.
# ```

# %% [markdown]
# ---
