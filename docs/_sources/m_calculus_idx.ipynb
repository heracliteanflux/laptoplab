# %% [markdown]
# # Calculus
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Mean_value_theorem) ] Mean Value Theorem
# * [ [w](https://en.wikipedia.org/wiki/Rolle%27s_theorem) ] Rolle's Theorem

# %% [markdown]
# ---
# ---
# ---
