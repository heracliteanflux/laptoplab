# %% [markdown]
# # Thomas Hobbes
# `1588-1679 (91)` [ [w](https://en.wikipedia.org/wiki/Thomas_Hobbes) ][ [SEP](https://plato.stanford.edu/entries/hobbes/) ]
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Texts

# %% [markdown]
# ```txt
# 1651  Leviathon   https://en.wikipedia.org/wiki/Leviathan_(Hobbes_book)
# 1655  De Corpore  https://en.wikipedia.org/wiki/De_Corpore
# ```

# %% [markdown]
# ---
# ---
# ---
