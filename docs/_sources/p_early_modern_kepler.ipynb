# %% [markdown]
# # Johannes Kepler
# `1571-1630 (58)` [ [w](https://en.wikipedia.org/wiki/Johannes_Kepler) ][ [SEP](https://plato.stanford.edu/entries/kepler/) ]
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
