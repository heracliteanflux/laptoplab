# %% [markdown]
# # 3.1 - Navigate the city

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# address                    dì    zhǐ          地址
# boat                       chuán              船🚢
# bus                        dà    bā           大巴🚌
# cash                       xiàn  jīn          现金💰
# Chengdu                    chéng dū           成都
# flight                     háng  bān          航班✈️
# high-speed train           gāo   tiě          高铁🚄
# how                        zěn   me           怎么
# island                     dǎo                岛
# islet (little island)      xiǎo  dǎo          小岛🏝️
# panda                      xióng māo          熊猫🐼
# password                   mì    mǎ           密码
# postcard                   míng  xìn  piàn    明信片🎑
# receipt                    xiǎo  piào         小票🧾 (three receipts 三张小票 sān zhāng xiǎo piào)
# Shenzhen                   shēn  zhèn         深圳
# stamp                      yóu   piào         邮票 (five stamps 五张邮票 wǔ zhāng yóu piào)
# t-shirt                    T     xù           T恤
# then                       nà                 那
# transportation; traffic    jiāo  tōng         交通🚴
#
# crowded                    yōng  jǐ           拥挤
#
# this time                  zhè   cì           这次
#
# there is/are/was/were      yǒu                有
# to be canceled             qǔ    xiāo         取消
# to book a flight           dìng  háng bān     订航班✈️
# to pay                     fù    qián         付钱
# to send                    jì                 寄
#
#
#
# 那你怎么回家？nà nǐ zěnme huí jiā Then how do you return home?
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# 巴黎的交通。
# 北京的交通怎么样？
# 成都不远。
# 大巴几点出发？
# 二十只熊猫。
# 记得寄明信片。
# 记得写地址。
# 快来成都。
# 李天美不想坐大巴。
# 那个岛很大。
# 那个岛离这里远吗？
# 你的航班取消了吗？
# 你为什么喜欢熊猫？
# 你应该坐船去那个岛。
# 你怎么去看熊猫？
# 请问，我怎么去市中心？
# 谁付钱？
# 深圳的地铁很方便。
# 他一共买了三件T恤。
# 我的小票。
# 我忘了带现金。
# 我想看熊猫。
# 我想上网买这件T恤。
# 我想走路去博物馆。
# 我怎么付钱？
# 我怎么寄明信片？
# 我们的航班取消了。
# 我们订了新航班。
# 我们走路去看熊猫吧。
# 有航班。
# 香港的交通很方便。
# 现在这条街很拥挤。
# 信用卡密码。
# 熊猫太可爱了。
# 账号密码。
# 这件T恤多少钱？
# 这是谁的地址？
# 这是我的航班号。
# 坐大巴很快。
# ```

# %% [markdown]
# ```txt
# bālí de jiāotōng Paris transportation.
# běijīng de jiāotōng zěnmeyàng? How is Beijing's transportation?
# chéngdū bù yuǎn Chengdu isn't far.
# dàbā jǐdiǎn chūfā? What time does the bus depart?
# èr shí zhǐ xióngmāo Twenty pandas.
# jìde jì míngxìnpiàn Remember to send a postcard.
# jìde xiě dìzhǐ Remember to write the address.
# kuài lái chéngdū Come to Chengdu quickly.
# lǐtiānměi bù xiǎng zuò dàbā Li Tianmei doesn't want to take the bus.
# nàge dǎo hěn dà That island is big.
# nàge dǎo lí zhèlǐ yuǎn ma? Is that island far from here?
# nǐ de hángbān qǔxiāole ma? Was your flight canceled?
# nǐ wèishénme xǐhuān xióngmāo? Why do you like pandas?
# nǐ yīnggāi zuò chuán qù nàge dǎo You should take a boat to go to that island.
# nǐ zěnme qù kàn xióngmāo? How do you go see the pandas?
# qǐngwèn, wǒ zěnme qù shìzhōngxīn? Excuse me, how do I go downtown?
# tā yígòng mǎile sānjiàn Txù He bought three t-shirts altogether.
# shéi fù qián? Who pays?
# shēnzhèn de dìtiě hěn fāngbiàn Shenzhen's subway is convenient.
# wǒ de xiǎopiào My receipt.
# wǒ wàngle dài xiànjīn I forgot to bring cash.
# wǒ xiǎng kàn xióngmāo I want to see the pandas.
# wǒ xiǎng shàngwǎng mǎi zhèjiàn Txù I want to go online to buy this t-shirt.
# wǒ xiǎng zǒulù qù bówùguǎn I want to take a walk to go to the museum.
# wǒ zěnme fùqián? How do I pay?
# wǒ zěnme jì míngxìnpiàn? How do I send a postcard?
# wǒmen de hángbān qǔxiāole Our flight was canceled.
# wǒmen dìngle xīn hángbān We booked a new flight.
# wǒmen zǒulù qù kàn xióngmāo bā Let's take a walk to go see the pandas.
# xiānggǎng de jiāotōng hěn fāngbiàn Hong Kong's transportation is convenient.
# xiànzài zhètiáo jiē hěn yōngjǐ This street is crowded now.
# xìnyòngkǎ mìmǎ Credit card password.
# xióngmāo tài kěài le Pandas are adorable.
# yǒu hángbān There is a flight.
# zhànghào mìmǎ Account password.
# zhèjiàn Txù duōshǎoqián? How much is this t-shirt?
# zhè shì shéi de dìzhǐ? Whose address is this?
# zhè shì wǒ de hángbān hào This is my flight number.
# zuò dàbā hěn kuài Taking the bus is fast.
# ```

# %% [markdown]
# ---
