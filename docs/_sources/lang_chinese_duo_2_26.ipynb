# %% [markdown]
# # 2.26 - Discuss rental details

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# air conditioner                              kōng  tiáo           空调
# balcony/porch                                yáng  tái            阳台
# color                                        yán   sè             颜色
# convenience store                            biàn  lì    diàn     便利店🏪
# drawing/painting/picture                     huà   r              画儿 (a painting 一张画儿 yì zhāng huà r)
# garden                                       huā   yuán           花园
# main entrance / gate                         dà    mén            大门🚪
# of course / certainly / definitely / sure    dāng  rán            当然👍
# on the wall                                  qiáng shàng          墙上
# mirror                                       jìng  zi             镜子🪞
# neighborhood                                 xiǎo  qū             小区
# sir                                          xiān  shēng/sheng    先生🧑‍🏫
# wall                                         qiáng                墙🧱
# wardrobe                                     yī    guì            衣柜
#
# inside                                       lǐ                   里
# outside                                      wài                  外
# on                                           shàng                上
#
# old (place)                                  lǎo                  老
# safe                                         ān    quán           安全🔐
#
# to (ex)change/replace/swap/convert           huàn                 换
# to look (at)                                 kàn                  看👀
# to rent                                      zū                   租
#
# yì zhāng chuáng 一张床 a bed
# yì zhāng zhuōzi 一张桌子 a table
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# 便利店很重要。(biànlìdiàn hěn zhòngyào) Convenience stores are important.
# 便利店里没有很多饮料。(biànlìdiàn lǐ méi yǒu hěnduō yǐnliào) The convenience store doesn't have many drinks.
# 窗户上有一些画儿吗？(chuānghu shàng yǒu yìxiē huàr ma?) Are there some paintings on the window?
# 厨房里有什么？(chúfáng lǐ yǒu shénme?) What's in the kitchen?
# 厨房里有洗碗机。(chúfáng lǐ yǒu xǐwǎnjī) There's a dishwasher in the kitchen.
# 厨房里有一些窗户吗？(chúfáng lǐ yǒu yìxiē chuānghu ma?) Are there some windows in the kitchen?
# 厨房里有桌子。(chúfáng lǐ yǒu zhuōzi) There's a table in the kitchen.
# 大门很新。(dàmén hěn xīn) The main entrance is new.
# 当然，你可以带家具。(dāngrán, nǐ kěyǐ dài jiājù) Of course, you can bring the furniture.
# 当然，你可以买新家具。(dāngrán, nǐ kěyǐ mǎi xīn jiājù) Of course, you can buy new furniture.
# 当然，卧室很大。(dāngrán, wòshì hěn dà) Of course, the bedroom is big.
# 公寓里有大阳台。(gōngyù lǐ yǒu dà yángtái) There's a big balcony in the apartment.
# 花园很大。(huāyuán hěn dà) The garden is big.
# 花园里没有很多花。(huāyuán lǐ méi yǒu hěnduō huā) There aren't many flowers in the garden.
# 看，客厅里有一个健身房。(kàn, kètīng lǐ yǒu yígè jiànshēnfáng) Look, there's a gym in the living room.
# 看这个阳台，非常大。(kàn zhège yángtái, fēicháng dà) Look at this balcony, it's extremely big.
# 客厅里有电视吗？(kètīng lǐ yǒu diànshì ma?) Is there a tv in the living room?
# 客厅里有两个沙发。(kètīng lǐ yǒu liǎngge shāfā) There are two sofas in the living room.
# 客厅里有一个沙发。(kètīng lǐ yǒu yígè shāfā) There is a sofa in the living room.
# 空调吵不吵？(kōngtiáo chǎo bù chǎo?) Is the air conditioner noisy?
# 那个阳台比这个阳台小。(nàge yángtái bǐ zhège yángtái xiǎo) That porch is smaller than this porch.
# 那个阳台很小。(nàge yángtái hěn xiǎo) That balcony is small.
# 那是什么颜色。(nà shì shénme yánsè?) What color is that?
# 你们要租房子还是公寓？(nǐmen yào zū fángzi háishì gōngyù?) Are y'all going to rent a house or an apartment?
# 墙很干净。(qiáng hěn gānjìng) The wall is clean.
# 墙上有很多画儿。(qiáng shàng yǒu hěnduō huàr) There are lots of pictures on the wall.
# 墙上有一些纪念品吗？(qiáng shàng yǒu yìxiē jìniànpǐn ma?) Are there some souvenirs on the wall?
# 书房里有桌子吗？(shūfáng lǐ yǒu zhuōzi ma?) Is there a table in the study?
# 哇，卧室的镜子很大。(wā, wòshì de jìngzi zhēn dà) Wow, the bedroom mirror is big.
# 卧室的镜子很漂亮。(wòshì de jìngzi hěn piàoliang) The bedroom mirror is pretty.
# 卧室里也有空调吗？(wòshì lǐ yě yǒu kōngtiáo ma?) Is there also an air conditioner in the bedroom?
# 卧室里有什么？(wòshì lǐ yǒu shénme?) What's in the bedroom?
# 卧室里有衣柜吗？(wòshì lǐ yǒu yīguì ma?) Is there a wardrobe in the bedroom?
# 我可以换衣柜的颜色吗？(wǒ kěyǐ huàn yīguì de yánsè ma?) Can I change the wardrobe's color?
# 我想换一张床。(wǒ xiǎng huàn yìzhāng chuáng) I want to replace a bed.
# 我想换桌子。(wǒ xiǎng huàn zhuōzi) I want to replace the table.
# 我想租房子。(wǒ xiǎng zū fángzi) I want to rent a house.
# 我想租一个房间。(wǒ xiǎng zū yígè fángjiān) I want to rent a room.
# 我喜欢大镜子。(wǒ xǐhuan dà jìngzi) I like big mirrors.
# 我需要便利店。(wǒ xūyào biànlìdiàn) I need a convenience store.
# 我最讨厌这个颜色。(wǒ zuì tǎoyàn zhège yánsè) I hate this color the most.
# 我们租一个房子吧。(wǒmen zū yígè fángzi bā) Let's rent a house.
# 先生，公交站远吗？(xiānsheng, gōngjiāozhàn yuǎn ma?) Sir, is the bus stop far?
# 先生，你喜欢哪个公寓？(xiānsheng, nǐ xǐhuan nǎge gōngyù?) Sir, which apartment do you like?
# 先生，这里晚上吵吗？(xiānsheng, zhèlǐ wǎnshàng chǎo ma?) Sir, is it noisy here in the evening?
# 小姐，看。(xiǎojie, kàn) Miss, look.
# 小区里没有很多公园。(xiǎoqū lǐ méi yǒu hěnduō gōngyuán) There aren't many parks in the neighborhood.
# 小区里有停车场吗？(xiǎoqū lǐ yǒu tíngchēchǎng ma?) Does the neighborhood have a parking lot?
# 小区外没有咖啡馆。(xiǎoqū wài méi yǒu kāfēiguǎn) There isn't a cafe outside the neighborhood.
# 小区外有地铁站吗？(xiǎoqū wài yǒu dìtiězhàn ma?) Is there a subway station outside the neighborhood?
# 洗手间里有镜子。(xǐshǒujiān lǐ yǒu jìngzi) There's a mirror in the bathroom.
# 这个便利店真大。(zhège biànlìdiàn zhēn dà) This convenience store is really big.
# 这个厨房里有一个大冰箱。(zhège chúfáng lǐ yǒu yígè dà bīngxiāng) There's a big refrigerator in this kitchen.
# 这个地方安全吗？(zhège dìfāng ānquán ma?) Is this place safe?
# 这个公寓里有空调吗？(zhège gōngyù lǐ yǒu kōngtiáo ma?) Is there an air conditioner in this apartment?
# 这个公寓里有三个卧室。(zhège gōngyù lǐ yǒu sānge wòshì) There are three bedrooms in this apartment.
# 这个花园太漂亮了。(zhège huāyuán tài piàoliang le) This garden is so beautiful.
# 这个花园真漂亮。(zhège huāyuán zhēn piàoliang) This garden is really beautiful.
# 这个健身房挺老的。(zhège jiànshēnfáng tǐng lǎo de) This gym is quite old.
# 这个镜子太小了。(zhège jìngzi tài xiǎo le) This mirror is too small.
# 这个小区安全吗？(zhège xiǎoqū ānquán ma?) Is this neighborhood safe?
# 这个小区很安静。(zhège xiǎoqū hěn ānjìng) This neighborhood is quiet.
# 这个小区很安全。(zhège xiǎoqū hěn ānquán) This neighborhood is safe.
# 这个小区里有一个公交站。(zhège xiǎoqū lǐ yǒu yígè gōngjiāozhàn) There's a bus stop in this neighborhood.
# 这个小区没有很多入口。(zhège xiǎoqū méi yǒu hěnduō rùkǒu) This neighborhood doesn't have many entrances.
# 这个小区外有饭馆吗？(zhège xiǎoqū wài yǒu fànguǎn ma?) Is there a restuarant outside this neighborhood?
# 这个衣柜有点儿小。(zhège yīguì yǒudiànr xiǎo) This wardrobe's a bit small.
# 这里安全吗？(zhè lǐ ān quán ma?) Is it safe here?
# 这里挺安全的。(zhè lǐ tǐng ānquán de) It's quite safe here.
# 这是一个老小区。(zhè shì yígè lǎoxiǎoqū) This is an old neighborhood.
# 这些公寓都是老公寓。(zhèxiē gōngyù dōu shì lǎo gōngyù) These apartments are all old apartments.
# 这些墙有点儿脏。(zhèxiē qiáng yǒudiǎnr zāng) These walls are a bit dirty.
# 这张桌子太旧了。(zhèzhāng zhuōzi tài jiù le) This table is too old.
# 租公寓很方便。(zū gōngyù hěn fāngbiàn) Renting an apartment is convenient.
# ```

# %% [markdown]
# ---
