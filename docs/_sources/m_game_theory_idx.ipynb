# %% [markdown]
# # Game Theory
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Elwyn_Berlekamp) ] `1940-2019` Berlekamp, Elwyn
# * [ [w](https://en.wikipedia.org/wiki/John_Horton_Conway) ] `1937-2020` Conway, John
# * [ [w](https://en.wikipedia.org/wiki/Christos_Papadimitriou) ] `---------` Papadimitriou, Christos

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Algorithmic_game_theory) ] Algorithmic Game Theory
# * [ [w](https://en.wikipedia.org/wiki/Alpha%E2%80%93beta_pruning) ] Alpha-Beta Pruning
# * [ [w](https://en.wikipedia.org/wiki/Auction) ] Auction
# * [ [w](https://en.wikipedia.org/wiki/Backward_induction) ] Backward Induction
# * [ [w](https://en.wikipedia.org/wiki/Bayesian_game) ] Bayesian Game
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_auction) ] Combinatorial Auction
# * [ [w](https://en.wikipedia.org/wiki/Combinatorial_game_theory) ] Combinatorial Game Theory
# * [ [w](https://en.wikipedia.org/wiki/Common_knowledge_(logic)) ] Common Knowledge
# * [ [w](https://en.wikipedia.org/wiki/Complete_information) ] Complete Information
# * [ [w](https://en.wikipedia.org/wiki/Connection_game) ] Connection Game
# * [ [w](https://en.wikipedia.org/wiki/Continuous_game) ] Continuous Game
# * [ [w](https://en.wikipedia.org/wiki/Cooling_and_heating_(combinatorial_game_theory)) ] Cooling and Heating
# * [ [w](https://en.wikipedia.org/wiki/Cooperative_game_theory) ] Cooperative Game
# * [ [w](https://en.wikipedia.org/wiki/Economic_equilibrium) ] Economic Equilibrium
# * [ [w](https://en.wikipedia.org/wiki/Expectiminimax) ] Expectiminimax
# * [ [w](https://en.wikipedia.org/wiki/Extensive-form_game) ] Extensive-Form Game
# * [ [w](https://en.wikipedia.org/wiki/Focal_point_(game_theory)) ] Focal Poin
# * [ [w](https://en.wikipedia.org/wiki/Game_classification) ] Game Classification
# * [ [w](https://en.wikipedia.org/wiki/Game_complexity) ] Game Complexity
# * [ [w](https://en.wikipedia.org/wiki/Game_theory) ] Game Theory
# * [ [w](https://en.wikipedia.org/wiki/Game_tree) ] Game Tree
# * [ [w](https://en.wikipedia.org/wiki/Impartial_game) ] Impartial Game
# * [ [w](https://en.wikipedia.org/wiki/Incentive_compatibility) ] Incentive Compatibility
# * [ [w](https://en.wikipedia.org/wiki/Information_set_(game_theory)) ] Information Set
# * [ [w](https://en.wikipedia.org/wiki/Mechanism_design) ] Mechanism Design
# * [ [w](https://en.wikipedia.org/wiki/Minimax) ] Minimax
# * [ [w](https://en.wikipedia.org/wiki/Nash_equilibrium) ] Nash Equilibrium
# * [ [w](https://en.wikipedia.org/wiki/Non-cooperative_game_theory) ] Non Cooperative Gam
# * [ [w](https://en.wikipedia.org/wiki/Normal-form_game) ] Normal-Form Game
# * [ [w](https://en.wikipedia.org/wiki/Partisan_game) ] Partisan Game
# * [ [w](https://en.wikipedia.org/wiki/Perfect_competition) ] Perfect Competition
# * [ [w](https://en.wikipedia.org/wiki/Perfect_information) ] Perfect Information
# * [ [w](https://en.wikipedia.org/wiki/Positional_game) ] Positional Information
# * [ [w](https://en.wikipedia.org/wiki/Repeated_game) ] Repeated Game
# * [ [w](https://en.wikipedia.org/wiki/Retrograde_analysis) ] Retrograde Analysis
# * [ [w](https://en.wikipedia.org/wiki/Sequential_auction) ] Sequential Auction
# * [ [w](https://en.wikipedia.org/wiki/Sequential_game) ] Sequential Game
# * [ [w](https://en.wikipedia.org/wiki/Simultaneous_game) ] Simultaneous Game
# * [ [w](https://en.wikipedia.org/wiki/Solution_concept) ] Solution Concept
# * [ [w](https://en.wikipedia.org/wiki/Sprague%E2%80%93Grundy_theorem) ] Sprague-Grundy Theorem
# * [ [w](https://en.wikipedia.org/wiki/Star_(game_theory)) ] Star
# * [ [w](https://en.wikipedia.org/wiki/Strategy_(game_theory)) ] Strategy
# * [ [w](https://en.wikipedia.org/wiki/Strategy-stealing_argument) ] Strategy-Stealing Argument
# * [ [w](https://en.wikipedia.org/wiki/Subgame) ] Subgame
# * [ [w](https://en.wikipedia.org/wiki/Subgame_perfect_equilibrium) ] Subgame Perfect Equilibrium
# * [ [w](https://en.wikipedia.org/wiki/Topological_game) ] Topological Game
# * [ [w](https://en.wikipedia.org/wiki/Zero_game) ] Zero Game
# * [ [w](https://en.wikipedia.org/wiki/Zero-sum_game) ] Zero-Sum Game

# %% [markdown]
# ---
# ---
# ---
