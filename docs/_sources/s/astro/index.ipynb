# %% [markdown]
# # Astronomy & Astrophysics

# %% [markdown]
# Space Science & More

# %% [markdown]
# ---

# %% [markdown]
# ## Table of Contents
# ```{contents}
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# [ [y](https://www.youtube.com/watch?v=uniGQrGLEoI) ] `11-21-2019`. Domain of Science. "Every Thing in Space".

# %% [markdown]
# Dot Physics
# * [ [y](https://www.youtube.com/watch?v=v7svyPnIeGA) ] `01-02-2024`. "Modeling a flat and spinning solar system using Python".
# * [ [y](https://www.youtube.com/watch?v=_xFMa4bxez4) ] `12-11-2023`. "Using a Bunch of Balls to Model the Ideal Gas Law in Python".

# %% [markdown]
# * [ [y](https://www.youtube.com/watch?v=jGSOWQ3vqGI) ] `12-04-2023`. C. J. Neumann. "Lecture, Vertical Circular Motion (Honors)".
# * [ [y](https://www.youtube.com/watch?v=0vvj4-hnFNw) ] `11-26-2023`. INTEGRAL PHYSICS. "Calculate Period & Center of Mass in Binary Star Systems | Newtons Law of Gravity & Kepler's 3rd Law".
# * [ [y](https://www.youtube.com/watch?v=i0cp3iQXSk8) ] `11-22-2023`. Morphocular. "Finding Velocity On a Sphere Using a 3D Euler's Formula".

# %% [markdown]
# * [Y] Academic Lesson
#   * [[Y](https://www.youtube.com/watch?v=3lTQqEehEhI) ] Academic Lesson. (14 Sep 2020). "Modern Physics || Modern Physics Full Lecture Course". YouTube.
# * [Y] Institute for Advanced Study
#   * [[Y](https://www.youtube.com/watch?v=yH3Vyejy9qo) ] Institute for Advanced Study. (14 Mar 2023). "The Three-Body Problem: A Chaotic Tale from Newton to Symplectic Geometry and Space Exploration - Agustin Moreno". YouTube.
# * [Y] Let's Find Out
#   * [[Y](https://www.youtube.com/watch?v=lEOu14yx6KQ) ] Let's Find Out. (16 Jul 2021). "Size, Distance, and Time in the Universe | Soft-Spoken ASMR (3.5 Hours)". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=4CqdV8BEbko) ] Let's Find Out. (01 Dec 2020). "The History of Binary Stars (1836 Astronomy Book) Geography of the Heavens: Pt 2 | ASMR soft spoken". YouTube.
# * [Y] MIT Open Courseware
#   * [[Y](https://www.youtube.com/watch?v=WR88_Vzfcx4) ] MIT OpenCourseware. (05 Jul 2017). "Compton Scattering". YouTube.
# * [Y] Mr P Solver
#   * [[Y](https://www.youtube.com/watch?v=oYnfDcU33i4) ] Mr P Solver. (21 Oct 2022). "Generating The Rings of Power Theme in Python [2D Random Walk]". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=YzuaiD2e5oI) ] Mr P Solver. (30 May 2022). "Linear Combination of Atomic Orbitals (LCAO) in Python". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=9yxvdoXbbc0) ] Mr P Solver. (09 May 2022). "The Finite Square Well: *Two* Methods Every Physicist Should Know". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=MtG9cueB548) ] Mr P Solver. (04 Apr 2022). "How To Solve and Animate a 3D Double Pendulum in Python". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=BJUasLU9rCY) ] Mr P Solver. (17 Feb 2022). "Compton Scattering in Python (Klein-Nishima Equation)". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=65kl4eE9ovI) ] Mr P Solver. (07 Dec 2021). "Billiard Balls and the Boltzmann Distribution in Python". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=onSJhNsGLgI) ] Mr P Solver. (20 Sep 2021). "Photon Beam Attenuation in Python". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=8ZZDNd4eyVI) ] Mr P Solver. (07 Sep 2021). "The Double Pendulum in PYTHON". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=b9S_L1AaJNw) ] Mr P Solver. (23 Aug 2021). "Projectile Motion (WITH AIR FRICTION)". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=wYH1QqolUyw) ] Mr P Solver. (22 Jul 2021). "Math Symbol Tier List". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=otRtUiCcCh4) ] Mr P Solver. (22 Apr 2021). "3 Body Simulation in Python: Rare Orbits". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=8DrR_tpfg0Q) ] Mr P Solver. (11 Apr 2021). "Numerical Heat Equation: Cooking a Turkey in Python | Python Metaphysics #9". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=dKCAVteveYc) ] Mr P Solver. (08 Apr 2021). "Laplace's Equation with Arbitrary Boundary Conditions in PYTHON". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=SZdZeT93C1s) ] Mr P Solver. (05 Apr 2021). "The Double-SPRINGED Pendulum in PYTHON". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=DF1SnjXZcbM) ] Mr P Solver. (03 Apr 2021). "2D Schrodinger Equation Numerical Solution in PYTHON". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=ENNyltVTJaE) ] Mr P Solver. (31 Mar 2021). "Pendulum Motion in PYTHON". YouTube.
# * [Y] Physics Explained
#   * [[Y](https://www.youtube.com/watch?v=XiXwTXRYNBQ) ] Physics Explained. (10 Mar 2023). "Escape Velocity with VPython". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=r8uSooixXxc) ] Physics Explained. (07 Mar 2023). "How Can You Get Circular Orbits for the Three Body Problem?". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=MJrnUNwEe4g) ] Physics Explained. (15 Apr 2021). "Block on an Incline: Newtonian, Lagrangian, and Hamiltonian Solutions". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=8UtnDaGHpq0) ] Physics Explained. (18 Oct 2020). "Introduction to Lagrangian Mechanics". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=0kL4tUl4qxU) ] Physics Explained. (23 Sep 2020). "What is the acceleration of an object moving in a circle, and what can you do with it?". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=YHHVkUrg4_M) ] Physics Explained. (19 Aug 2020). "What is the Three Body Problem and How Do You Solve It?". YouTube.
#   * [[Y](https://www.youtube.com/watch?v=rGy7nsC8O_Y) ] Physics Explained. (10 Apr 2020). "What is Compton Scattering". YouTube.
# * [Y] Physics with Elliot
#   * [[Y](https://www.youtube.com/watch?v=0DHNGtsmmH8) ] Physics with Elliot. (14 Sep 2021). "Lagrangian and Hamiltonian Mechanics in Under 20 Minutes: Physics Mini Lesson". YouTube.

# %% [markdown]
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/George_William_Hill) ] `1838-1914` Hill, George William

# %% [markdown]
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Absolute_magnitude) ] Absolute Magnitude
# * [ [w](https://en.wikipedia.org/wiki/Absorption_(electromagnetic_radiation)) ] Absorption
# * [ [w](https://en.wikipedia.org/wiki/Albedo) ] Albedo
# * [ [w](https://en.wikipedia.org/wiki/Algol) ] Algol
# * [ w ] Altair
# * [ [w](https://en.wikipedia.org/wiki/Amateur_astronomy) ] Amateur Astronomy
# * [ [w](https://en.wikipedia.org/wiki/Amplitude) ] Amplitude
# * [ [w](https://en.wikipedia.org/wiki/Analemma) ] Analemma
# * [ [w](https://en.wikipedia.org/wiki/Angular_diameter) ] Angular Diameter
# * [ [w](https://en.wikipedia.org/wiki/Angular_displacement) ] Angular Displacement
# * [ [w](https://en.wikipedia.org/wiki/Angular_distance) ] Angular Distance
# * [ [w](https://en.wikipedia.org/wiki/Angular_frequency) ] Angular Frequency
# * [ [w](https://en.wikipedia.org/wiki/Angular_velocity) ] Angular Velocity
# * [ [w](https://en.wikipedia.org/wiki/Anisotropy) ] Anisotropy
# * [ [w](https://en.wikipedia.org/wiki/Antares) ] Antares
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Aphelion
# * [ [w](https://en.wikipedia.org/wiki/Apparent_magnitude) ] Apparent Magnitude
# * [ [w](https://en.wikipedia.org/wiki/Apparent_retrograde_motion) ] Apparent Retrograde Motion
# * [ [w](https://en.wikipedia.org/wiki/Appulse) ] Appulse
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Apsis
# * [ [w](https://en.wikipedia.org/wiki/Minute_and_second_of_arc) ] Arcminute
# * [ [w](https://en.wikipedia.org/wiki/Minute_and_second_of_arc) ] Arcsecond
# * [ [w](https://en.wikipedia.org/wiki/Arcturus) ] Arcturus
# * [ [w](https://en.wikipedia.org/wiki/Astrometry) ] Astrometry
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_coordinate_systems) ] Astronomical Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_object) ] Astronomical Object
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_symbols) ] astronomical symbols
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_unit) ] Astronomical Unit
# * [ [w](https://en.wikipedia.org/wiki/September_equinox) ] Autumnal Equinox
# * [ [w](https://en.wikipedia.org/wiki/Axial_precession) ] Axial Precession
# * [ [w](https://en.wikipedia.org/wiki/Azimuth) ] Azimuth
# * [ [w](https://en.wikipedia.org/wiki/Beta_decay) ] Beta Decay
# * [ [w](https://en.wikipedia.org/wiki/Betelgeuse) ] Betelgeuse
# * [ [w](https://en.wikipedia.org/wiki/Big_Bang_nucleosynthesis) ] Big Bang Nucleosynthesis
# * [ [w](https://en.wikipedia.org/wiki/Binary_star) ] Binary Star
# * [ [w](https://en.wikipedia.org/wiki/Black_body) ] Black Body
# * [ [w](https://en.wikipedia.org/wiki/Black_hole) ] Black Hole
# * [ [w](https://en.wikipedia.org/wiki/Blue_giant) ] Blue Giant
# * [ [w](https://en.wikipedia.org/wiki/Bond_albedo) ] Bond Albedo
# * [ [w](https://en.wikipedia.org/wiki/Boson) ] Boson
# * [ [w](https://en.wikipedia.org/wiki/Celestial_equator) ] Celestial Equator
# * [ [w](https://en.wikipedia.org/wiki/Celestial_mechanics) ] Celestial Mechanics
# * [ [w](https://en.wikipedia.org/wiki/Celestial_pole) ] Celestial Pole
# * [ [w](https://en.wikipedia.org/wiki/Celestial_sphere) ] Celestial Sphere
# * [ [w](https://en.wikipedia.org/wiki/Circular_orbit) ] Circular Orbit
# * [ [w](https://en.wikipedia.org/wiki/Circumpolar_star) ] Circumpolar Star
# * [ [w](https://en.wikipedia.org/wiki/CNO_cycle) ] CNO Cycle
# * [ [w](https://en.wikipedia.org/wiki/Color_index) ] Color Index
# * [ [w](https://en.wikipedia.org/wiki/Conjunction_(astronomy)) ] Conjunction
# * [ [w](https://en.wikipedia.org/wiki/Coordinated_Universal_Time) ] Coordinated Universal Time (UTC)
# * [ [w](https://en.wikipedia.org/wiki/Cosmic_distance_ladder) ] Cosmic Distance Ladder
# * [ [w](https://en.wikipedia.org/wiki/Cosmic_ray) ] Cosmic Ray
# * [ [w](https://en.wikipedia.org/wiki/Culmination) ] Culmination
# * [ [w](https://en.wikipedia.org/wiki/Declination) ] Declination
# * [ [w](https://en.wikipedia.org/wiki/Deferent_and_epicycle) ] Deferent
# * [ [w](https://en.wikipedia.org/wiki/Deep-sky_object) ] Deep Sky Object
# * [ w ] Deneb
# * [ [w](https://en.wikipedia.org/wiki/Deuterium) ] Deuterium
# * [ [w](https://en.wikipedia.org/wiki/Distance_modulus) ] Distance Modulus
# * [ [w](https://en.wikipedia.org/wiki/Earth%27s_circumference) ] Earth Circumference
# * [ [w](https://en.wikipedia.org/wiki/Earth_mass) ] Earth Mass
# * [ [w](https://en.wikipedia.org/wiki/Earth_radius) ] Earth Radius
# * [ [w](https://en.wikipedia.org/wiki/Ecliptic) ] Ecliptic
# * [ [w](https://en.wikipedia.org/wiki/Ecliptic_coordinate_system) ] Ecliptic Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Effective_temperature) ] Effective Temperature
# * [ [w](https://en.wikipedia.org/wiki/Elliptic_orbit) ] Elliptic Orbit
# * [ [w](https://en.wikipedia.org/wiki/Elongation_(astronomy)) ] Elongation
# * [ [w](https://en.wikipedia.org/wiki/Emissivity) ] Emissivity
# * [ [w](https://en.wikipedia.org/wiki/Ephemeris) ] Ephemeris
# * [ [w](https://en.wikipedia.org/wiki/Deferent_and_epicycle) ] Epicycle
# * [ [w](https://en.wikipedia.org/wiki/Epoch_(astronomy)) ] Epoch
# * [ [w](https://en.wikipedia.org/wiki/Equation_of_time) ] Equation of Time
# * [ [w](https://en.wikipedia.org/wiki/Equatorial_coordinate_system) ] Equatorial Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Equinox_(celestial_coordinates)) ] Equinox
# * [ [w](https://en.wikipedia.org/wiki/Event_horizon) ] Event Horizon
# * [ [w](https://en.wikipedia.org/wiki/Extinction_(astronomy)) ] Extinction
# * [ [w](https://en.wikipedia.org/wiki/Fermion) ] Fermion
# * [ [w](https://en.wikipedia.org/wiki/Fiducial_marker) ] Fiducial Point
# * [ [w](https://en.wikipedia.org/wiki/First_point_of_Aries) ] First Point of Aries
# * [ [w](https://en.wikipedia.org/wiki/Fixed_stars) ] Fixed Stars
# * [ [w](https://en.wikipedia.org/wiki/Fundamental_plane_(spherical_coordinates)) ] Fundamental Plane
# * [ [w](https://en.wikipedia.org/wiki/Galactic_coordinate_system) ] Galactic Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Galaxy) ] Galaxy
# * [ [w](https://en.wikipedia.org/wiki/Gamma_ray) ] Gamma Ray
# * [ [w](https://en.wikipedia.org/wiki/Geometric_albedo) ] Geometric Albedo
# * [ [w](https://en.wikipedia.org/wiki/Gravitational_collapse) ] Gravitational Collapse
# * [ [w](https://en.wikipedia.org/wiki/Great_circle) ] Great Circle
# * [ [w](https://en.wikipedia.org/wiki/Great-circle_distance) ] Great Circle Distance
# * [ [w](https://en.wikipedia.org/wiki/Greenwich_Mean_Time) ] Greenwich Mean Time (GMT)
# * [ [w](https://en.wikipedia.org/wiki/Hertzsprung%E2%80%93Russell_diagram) ] H-R Diagram
# * [ [w](https://en.wikipedia.org/wiki/Hawking_radiation) ] Hawking Radiation
# * [ [w](https://en.wikipedia.org/wiki/Isotopes_of_helium) ] Helium Isotopes
# * [ [w](https://en.wikipedia.org/wiki/Horizon) ] Horizon
# * [ [w](https://en.wikipedia.org/wiki/Horizontal_coordinate_system) ] Horizontal Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Hour_angle) ] Hour Angle
# * [ [w](https://en.wikipedia.org/wiki/Hour_circle) ] Hour Circle
# * [ [w](https://en.wikipedia.org/wiki/Inferior_and_superior_planets) ] Inferior Planet
# * [ [w](https://en.wikipedia.org/wiki/International_Date_Line) ] International Date Line
# * [ [w](https://en.wikipedia.org/wiki/Interstellar_medium) ] Interstellar Medium
# * [ [w](https://en.wikipedia.org/wiki/Jupiter) ] Jupiter
# * [ [w](https://en.wikipedia.org/wiki/Kepler_orbit) ] Kepler Orbit
# * [ [w](https://en.wikipedia.org/wiki/Law_of_cosines) ] Law of Cosines
# * [ [w](https://en.wikipedia.org/wiki/Law_of_sines) ] Law of Sines
# * [ [w](https://en.wikipedia.org/wiki/Lepton) ] Lepton
# * [ [w](https://en.wikipedia.org/wiki/Light-year) ] Light-Year
# * [ [w](https://en.wikipedia.org/wiki/Luminosity) ] Luminosity
# * [ [w](https://en.wikipedia.org/wiki/Lunar_phase) ] Lunar Phase
# * [ [w](https://en.wikipedia.org/wiki/Magnitude_(astronomy)) ] Magnitude
# * [ [w](https://en.wikipedia.org/wiki/Main_sequence) ] Main Sequence
# * [ [w](https://en.wikipedia.org/wiki/March_equinox) ] March Equinox
# * [ w ] Mars
# * [ [w](https://en.wikipedia.org/wiki/Timekeeping_on_Mars) ] Mars, timekeeping
# * [ [w](https://en.wikipedia.org/wiki/Maxwell%27s_equations) ] Maxwell's Equations
# * [ [w](https://en.wikipedia.org/wiki/Mercury_(planet)) ] Mercury
# * [ [w](https://en.wikipedia.org/wiki/Meridian_(astronomy)) ] Meridian
# * [ [w](https://en.wikipedia.org/wiki/Metallicity) ] Metallicity
# * [ [w](https://en.wikipedia.org/wiki/Moon) ] Moon
# * [ [w](https://en.wikipedia.org/wiki/Nadir) ] Nadir
# * [ w ] Neptune
# * [ [w](https://en.wikipedia.org/wiki/Neutron_star) ] Neutron Star
# * [ [w](https://en.wikipedia.org/wiki/Noon) ] Noon
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_nutation) ] Nutation
# * [ [w](https://en.wikipedia.org/wiki/Opposition_(astronomy)) ] Opposition
# * [ [w](https://en.wikipedia.org/wiki/Orbital_eccentricity) ] Orbital Eccentricity
# * [ [w](https://en.wikipedia.org/wiki/Orbital_elements) ] Orbital Elements
# * [ [w](https://en.wikipedia.org/wiki/Orbital_inclination) ] Orbital Inclination
# * [ [w](https://en.wikipedia.org/wiki/Orbital_mechanics) ] Orbital Mechanics
# * [ [w](https://en.wikipedia.org/wiki/Orbital_node) ] Orbital Node
# * [ [w](https://en.wikipedia.org/wiki/Orbital_period) ] Orbital Period
# * [ [w](https://en.wikipedia.org/wiki/Orbital_plane) ] Orbital Plane
# * [ [w](https://en.wikipedia.org/wiki/Orbital_speed) ] Orbital Speed
# * [ [w](https://en.wikipedia.org/wiki/Parallax) ] Parallax
# * [ [w](https://en.wikipedia.org/wiki/Parsec) ] Parsec
# * [ [w](https://en.wikipedia.org/wiki/Apsis) ] Perihelion
# * [ [w](https://en.wikipedia.org/wiki/Periodic_function) ] Periodic Function
# * [ [w](https://en.wikipedia.org/wiki/Phase_(waves)) ] Phase
# * [ [w](https://en.wikipedia.org/wiki/Phase_angle_(astronomy)) ] Phase Angle
# * [ [w](https://en.wikipedia.org/wiki/Photometry_(astronomy)) ] Photometry
# * [ [w](https://en.wikipedia.org/wiki/Photon) ] Photon
# * [ [w](https://en.wikipedia.org/wiki/Photosphere) ] Photosphere
# * [ [w](https://en.wikipedia.org/wiki/Planet) ] Planet
# * [ [w](https://en.wikipedia.org/wiki/Planetary_coordinate_system) ] Planetary Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Planetary_phase) ] Planetary Phase
# * [ w ] Pluto
# * [ w ] Polaris
# * [ [w](https://en.wikipedia.org/wiki/Spherical_astronomy) ] Positional Astronomy
# * [ [w](https://en.wikipedia.org/wiki/Positron) ] Positron
# * [ [w](https://en.wikipedia.org/wiki/Positron_emission) ] Positron Emission
# * [ [w](https://en.wikipedia.org/wiki/Prime_meridian) ] Prime Meridian
# * [ [w](https://en.wikipedia.org/wiki/Retrograde_and_prograde_motion) ] Prograde Motion
# * [ [w](https://en.wikipedia.org/wiki/Proton%E2%80%93proton_chain) ] Proton-Proton Chain
# * [ [w](https://en.wikipedia.org/wiki/Protostar) ] Protostar
# * [ [w](https://en.wikipedia.org/wiki/Proxima_Centauri) ] Proxima Centauri
# * [ [w](https://en.wikipedia.org/wiki/Quadrature_(astronomy)) ] Quadrature
# * [ [w](https://en.wikipedia.org/wiki/Radian) ] Radian
# * [ [w](https://en.wikipedia.org/wiki/Red_supergiant) ] Red Supergiant
# * [ [w](https://en.wikipedia.org/wiki/Retrograde_and_prograde_motion) ] Retrograde Motion
# * [ [w](https://en.wikipedia.org/wiki/Right_ascension) ] Right Ascension
# * [ [w](https://en.wikipedia.org/wiki/Roche_limit) ] Roche Limit
# * [ [w](https://en.wikipedia.org/wiki/Rotating_ellipsoidal_variable) ] Rotating Ellipsoidal Variable
# * [ w ] Saturn
# * [ [w](https://en.wikipedia.org/wiki/Sawtooth_wave) ] Sawtooth Wave
# * [ [w](https://en.wikipedia.org/wiki/September_equinox) ] September Equinox
# * [ [w](https://en.wikipedia.org/wiki/Shell_theorem) ] Shell Theorem
# * [ [w](https://en.wikipedia.org/wiki/Sidereal_time) ] Sidereal Time
# * [ [w](https://en.wikipedia.org/wiki/Sidereal_year) ] Sidereal Year
# * [ [w](https://en.wikipedia.org/wiki/Significant_figures) ] Significant Figures
# * [ [w](https://en.wikipedia.org/wiki/Small-angle_approximation) ] Small-Angle Approximation
# * [ [w](https://en.wikipedia.org/wiki/Solar_azimuth_angle) ] Solar Azimuth Angle
# * [ [w](https://en.wikipedia.org/wiki/Solar_System) ] Solar System
# * [ [w](https://en.wikipedia.org/wiki/Solar_time) ] Solar Time
# * [ [w](https://en.wikipedia.org/wiki/Tropical_year) ] Solar Year
# * [ [w](https://en.wikipedia.org/wiki/Solar_zenith_angle) ] Solar Zenith Angle
# * [ [w](https://en.wikipedia.org/wiki/Spectral_line) ] Spectral Line
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_spectroscopy) ] Spectroscopy
# * [ [w](https://en.wikipedia.org/wiki/Spherical_astronomy) ] Spherical Astronomy
# * [ [w](https://en.wikipedia.org/wiki/Spherical_lune) ] Spherical Lune
# * [ [w](https://en.wikipedia.org/wiki/Spherical_trigonometry) ] Spherical Trigonometry
# * [ [w](https://en.wikipedia.org/wiki/Spica) ] Spica
# * [ [w](https://en.wikipedia.org/wiki/Square_wave) ] Square Wave
# * [ [w](https://en.wikipedia.org/wiki/Star) ] Star
# * [ [w](https://en.wikipedia.org/wiki/Stellar_atmosphere) ] Stellar Atmosphere
# * [ [w](https://en.wikipedia.org/wiki/Stellar_classification) ] Stellar Classification
# * [ [w](https://en.wikipedia.org/wiki/Stellar_evolution) ] Stellar Evolution
# * [ [w](https://en.wikipedia.org/wiki/Stellar_nucleosynthesis) ] Stellar Nucleosynthesis
# * [ [w](https://en.wikipedia.org/wiki/Stellar_population) ] Stellar Population
# * [ [w](https://en.wikipedia.org/wiki/Stellar_structure) ] Stellar Structure
# * [ [w](https://en.wikipedia.org/wiki/Stellar_wind) ] Stellar Wind
# * [ [w](https://en.wikipedia.org/wiki/Summer_solstice) ] Summer Solstice
# * [ w ] Summer Triangle
# * [ [w](https://en.wikipedia.org/wiki/Sun) ] Sun
# * [ [w](https://en.wikipedia.org/wiki/Sunlight) ] Sunlight
# * [ [w](https://en.wikipedia.org/wiki/Sunrise) ] Sunrise
# * [ [w](https://en.wikipedia.org/wiki/Sunset) ] Sunset
# * [ [w](https://en.wikipedia.org/wiki/Supergiant) ] Supergiant
# * [ [w](https://en.wikipedia.org/wiki/Inferior_and_superior_planets) ] Superior Planet
# * [ [w](https://en.wikipedia.org/wiki/Supernova) ] Supernova
# * [ [w](https://en.wikipedia.org/wiki/Supernova_nucleosynthesis) ] Supernova Nucleosynthesis
# * [ [w](https://en.wikipedia.org/wiki/Synodic_day) ] Synodic Day
# * [ [w](https://en.wikipedia.org/wiki/Syzygy_(astronomy)) ] Syzygy
# * [ [w](https://en.wikipedia.org/wiki/Taylor_series) ] Taylor Series
# * [ [w](https://en.wikipedia.org/wiki/Three-body_problem) ] Three-Body Problem
# * [ [w](https://en.wikipedia.org/wiki/Tidal_circularization) ] Tidal Circularization
# * [ [w](https://en.wikipedia.org/wiki/Tidal_force) ] Tidal Force
# * [ [w](https://en.wikipedia.org/wiki/Tidal_locking) ] Tidal Locking
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_transit) ] Transit
# * [ [w](https://en.wikipedia.org/wiki/Triple-alpha_process) ] Triple Alpha Process
# * [ [w](https://en.wikipedia.org/wiki/Tropical_year) ] Tropical Year
# * [ [w](https://en.wikipedia.org/wiki/Two-body_problem) ] Two-Body Problem
# * [ [w](https://en.wikipedia.org/wiki/UBV_photometric_system) ] UBV Photometric System
# * [ w ] Uranus
# * [ [w](https://en.wikipedia.org/wiki/Variable_star) ] Variable Star
# * [ w ] Vega
# * [ [w](https://en.wikipedia.org/wiki/Venus) ] Venus
# * [ [w](https://en.wikipedia.org/wiki/March_equinox) ] Vernal Equinox
# * [ [w](https://en.wikipedia.org/wiki/Vis-viva_equation) ] Vis Viva Equation
# * [ [w](https://en.wikipedia.org/wiki/White_dwarf) ] White Dwarf
# * [ [w](https://en.wikipedia.org/wiki/Year) ] Year
# * [ [w](https://en.wikipedia.org/wiki/Zenith) ] Zenith

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Altazimuth_mount) ] Altazimuth Mount
# * [ [w](https://en.wikipedia.org/wiki/Ancient_Greek_astronomy) ] Ancient Greek Astronomy
# * [ [w](https://en.wikipedia.org/wiki/Angular_diameter) ] Angular Diameter
# * [ [w](https://en.wikipedia.org/wiki/Angular_displacement) ] Angular Displacement
# * [ [w](https://en.wikipedia.org/wiki/Angular_distance) ] Angular Distance
# * [ [w](https://en.wikipedia.org/wiki/180th_meridian) ] Antimeridian
# * [ [w](https://en.wikipedia.org/wiki/Arc_length) ] Arc Length
# * [ [w](https://en.wikipedia.org/wiki/Astronomical_coordinate_systems) ] Astronomical Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Azimuth) ] Azimuth
# * [ [w](https://en.wikipedia.org/wiki/Cardinal_direction) ] Cardinal Direction
# * [ [w](https://en.wikipedia.org/wiki/Celestial_equator) ] Celestial Equator
# * [ [w](https://en.wikipedia.org/wiki/Celestial_sphere) ] Celestial Sphere
# * [ [w](https://en.wikipedia.org/wiki/Centrifugal_force) ] Centrifugal Force
# * [ w ] Centripetal Acceleration
# * [ [w](https://en.wikipedia.org/wiki/Circle_of_latitude) ] Circle of Latitude
# * [ w ] Circumpolar Stars
# * [ [w](https://en.wikipedia.org/wiki/Cosmology) ] Cosmology
# * [ [w](https://en.wikipedia.org/wiki/Dynamics_(mechanics)) ] Dynamics
# * [ [w](https://en.wikipedia.org/wiki/Ecliptic) ] Ecliptic
# * [ [w](https://en.wikipedia.org/wiki/Equator) ] Equator
# * [ [w](https://en.wikipedia.org/wiki/Equinox) ] Equinox
# * [ [w](https://en.wikipedia.org/wiki/Firmament) ] Firmament
# * [ [w](https://en.wikipedia.org/wiki/Geodetic_coordinates) ] Geodetic Coordinates
# * [ [w](https://en.wikipedia.org/wiki/Geographic_coordinate_system) ] Geographic Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Geographical_pole) ] Geographic Pole
# * [ [w](https://en.wikipedia.org/wiki/Horizon) ] Horizon
# * [ [w](https://en.wikipedia.org/wiki/Horizontal_coordinate_system) ] Horizontal Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Vertical_and_horizontal) ] Horizontality
# * [ [w](https://en.wikipedia.org/wiki/Hour_angle) ] Hour Angle
# * [ [w](https://en.wikipedia.org/wiki/International_Date_Line) ] International Date Line
# * [ [w](https://en.wikipedia.org/wiki/Invariable_plane) ] Invariable Plane
# * [ [w](https://en.wikipedia.org/wiki/Kinematics) ] Kinematics
# * [ [w](https://en.wikipedia.org/wiki/Kinetics_(physics)) ] Kinetics
# * [ [w](https://en.wikipedia.org/wiki/Latitude) ] Latitude
# * [ [w](https://en.wikipedia.org/wiki/Line_of_sight) ] Line of Sight
# * [ [w](https://en.wikipedia.org/wiki/Longitude) ] Longitude
# * [ [w](https://en.wikipedia.org/wiki/Low_Earth_orbit) ] Low Earth Orbit
# * [ [w](https://en.wikipedia.org/wiki/Mass) ] Mass
# * [ [w](https://en.wikipedia.org/wiki/Matter) ] Matter
# * [ [w](https://en.wikipedia.org/wiki/Meridian_(geography)) ] Meridian
# * [ [w](https://en.wikipedia.org/wiki/Momentum) ] Momentum
# * [ [w](https://en.wikipedia.org/wiki/Nadir) ] Nadir
# * [ w ] North Celestial Pole
# * [ [w](https://en.wikipedia.org/wiki/North_Pole) ] North Pole
# * [ [w](https://en.wikipedia.org/wiki/Orbit) ] Orbit
# * [ [w](https://en.wikipedia.org/wiki/Orbital_inclination) ] Orbital Inclination
# * [ [w](https://en.wikipedia.org/wiki/Orbital_plane) ] Orbital Plane
# * [ [w](https://en.wikipedia.org/wiki/Orbital_pole) ] Orbital Pole
# * [ [w](https://en.wikipedia.org/wiki/Parallax) ] Parallax
# * [ w ][ [s](https://plato.stanford.edu/entries/cosmology/) ] Philosophy of Cosmology
# * [ [w](https://en.wikipedia.org/wiki/Philosophy_of_physics) ] Philosophy of Physics
# * [ [w](https://en.wikipedia.org/wiki/Philosophy_of_space_and_time) ] Philosophy of Space and Time
# * [ [w](https://en.wikipedia.org/wiki/Plane_of_reference) ] Plane of Reference
# * [ [w](https://en.wikipedia.org/wiki/Planetary_coordinate_system) ] Planetary Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Horror_vacui_(physics)) ] Plenism (Horror Vacui)
# * [ [w](https://en.wikipedia.org/wiki/Polaris) ] Polaris
# * [ [w](https://en.wikipedia.org/wiki/Pole_star) ] Pole Star
# * [ [w](https://en.wikipedia.org/wiki/Position_of_the_Sun) ] Position of the Sun
# * [ [w](https://en.wikipedia.org/wiki/Prime_meridian) ] Prime Meridian
# * [ w ] Radian
# * [ [w](https://en.wikipedia.org/wiki/Rotation_around_a_fixed_axis) ] Rotation around a fixed axis
# * [ [w](https://en.wikipedia.org/wiki/Shell_theorem) ] Shell Theorem
# * [ [w](https://en.wikipedia.org/wiki/Sky) ] Sky
# * [ [w](https://en.wikipedia.org/wiki/Solar_azimuth_angle) ] Solar Azimuth Angle
# * [ [w](https://en.wikipedia.org/wiki/Solar_zenith_angle) ] Solar Zenith Angle
# * [ [w](https://en.wikipedia.org/wiki/South_Pole) ] South Pole
# * [ [w](https://en.wikipedia.org/wiki/Spherical_coordinate_system) ] Spherical Coordinate System
# * [ [w](https://en.wikipedia.org/wiki/Spherical_trigonometry) ] Spherical Trigonometry
# * [ [w](https://en.wikipedia.org/wiki/Statics) ] Statics
# * [ [w](https://en.wikipedia.org/wiki/Stellar_parallax) ] Stellar Parallax
# * [ [w](https://en.wikipedia.org/wiki/Subsolar_point) ] Subsolar Point
# * [ [w](https://en.wikipedia.org/wiki/Sun_path) ] Sun Path
# * [ [w](https://en.wikipedia.org/wiki/Tachyon) ] Tachyon
# * [ [w](https://en.wikipedia.org/wiki/Telescope) ] Telescope
# * [ [w](https://en.wikipedia.org/wiki/True_north) ] True North
# * [ [w](https://en.wikipedia.org/wiki/Unit_vector) ] Unit Vector
# * [ [w](https://en.wikipedia.org/wiki/Vacuum) ] Vacuum
# * [ [w](https://en.wikipedia.org/wiki/Vertical_and_horizontal) ] Verticality
# * [ [w](https://en.wikipedia.org/wiki/Zenith) ] Zenith

# %% [markdown]
# ---
