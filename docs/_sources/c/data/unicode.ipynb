# %% [markdown]
# # Unicode

# %% [markdown]
# ---

# %% [markdown]
# ## Table of Contents
# ```{contents}
# ```

# %% [markdown]
# ---

# %% [markdown]
# Symbol   | HTML Entity | Unicode Code Point | Unicode Name
# ---------|-------------|--------------------|-------------
# &#x2190; | `&#8592;`, `&#x2190;`, `&larr;` | U+2190 | LEFTWARDS ARROW
# &#x2191; | `&#8593;`, `&#x2191;`, `&uarr;` | U+2191 | UPWARDS ARROW
# &#x2192; | `&#8594;`, `&#x2192;`, `&rarr;` | U+2192 | RIGHTWARDS ARROW
# &#x2193; | `&#8595;`, `&#x2193;`, `&darr;` | U+2193 | DOWNWARDS ARROW
# &#x21A9; | `&#8617;`, `&#x21A9;` | U+21A9 | LEFTWARDS ARROW WITH HOOK
# &#x21B5; | `&#8629;`, `&#x21B5;`, `&crarr;` | U+21B5 | DOWNWARDS ARROW WITH CORNER LEFTWARDS (carriage return symbol)
# &#x21B9; | `&#8633;`, `&#x21B9;` | U+21B9 | LEFTWARDS ARROW TO BAR OVER RIGHTWARDS ARROW TO BAR (tab with shift tab)
# &#x21C6; | `&#86??;`, `&#x21C6;` | U+21C6 | LEFTWARDS ARROW OVER RIGHTWARDS ARROW
# &#x21E4; | `&#8676;`, `&#x21E4;` | U+21E4 | LEFTWARDS ARROW TO BAR (leftward tab)
# &#x21E5; | `&#8677;`, `&#x21E5;` | U+21E5 | RIGHTWARDS ARROW TO BAR (rightward tab)
# &#x21E7; | `&#8679;`, `&#x21E7;` | U+21E7 | UPWARDS WHITE ARROW (shift)
# &#x21EA; | `&#8682;`, `&#x21EA;` | U+21EA | UPWARDS WHITE ARROW FROM BAR (caps lock)
# &#x2303; | `&#8963;`, `&#x2303;` | U+2303 | UP ARROWHEAD
# &#x2305; | `&#8965;`, `&#x2305;` | U+2305 | PROJECTIVE
# &#x2318; | `&#8984;`, `&#x2318;` | U+2318 | PLACE OF INTEREST SIGN (command key)
# &#x2324; | `&#8996;`, `&#x2324;` | U+2324 | UP ARROWHEAD BETWEEN TWO HORIZONTAL BARS (enter key)
# &#x2325; | `&#8997;`, `&#x2325;` | U+2325 | OPTION KEY
# &#x232B; | `&#9003;`, `&#x232B;` | U+232B | ERASE TO THE LEFT (delete to the left key)
# &#x2387; | `&#9095;`, `&#x2387;` | U+2387 | ALTERNATIVE KEY SYMBOL (alt key)
# &#x238B; | `&#9099;`, `&#x238B;` | U+238B | BROKEN CIRCLE WITH NORTHWEST ARROW (escape)
# &#x23CF; | `&#9167;`, `&#x23CF;` | U+23CF | EJECT SYMBOL
# &#xF8FF; | `&#63743;`, `&#xF8FF;` | U+F8FF

# %% [markdown]
# ---

# %% [markdown]
# How many Unicode code points are there?

# %%
0x10FFFF
# Out:
# 1114111

# %%
cases = [chr(c) for c in list(range(8592, 9251)) + [
  63743,
]] + [
  '\u002D',
  '\u2013',
  '\u2014',
  '\u2060', # replaces U+FEFF qua deprecated ZERO WIDTH NO-BREAK SPACE
  '\uFEFF', # BOM
  '\uFFEF', # BOM, byte-swapped (illegal sequence that may not appear in Unicode text)
  #string.printable,
]
print_code_point_information(cases)
# Out:
# ['←', '↑', '→', '↓', '↔', '↕', '↖', '↗', '↘', '↙', '↚', '↛', '↜', '↝', '↞', '↟', '↠', '↡', '↢', '↣', '↤', '↥', '↦', '↧', '↨', '↩', '↪', '↫', '↬', '↭', '↮', '↯', '↰', '↱', '↲', '↳', '↴', '↵', '↶', '↷', '↸', '↹', '↺', '↻', '↼', '↽', '↾', '↿', '⇀', '⇁', '⇂', '⇃', '⇄', '⇅', '⇆', '⇇', '⇈', '⇉', '⇊', '⇋', '⇌', '⇍', '⇎', '⇏', '⇐', '⇑', '⇒', '⇓', '⇔', '⇕', '⇖', '⇗', '⇘', '⇙', '⇚', '⇛', '⇜', '⇝', '⇞', '⇟', '⇠', '⇡', '⇢', '⇣', '⇤', '⇥', '⇦', '⇧', '⇨', '⇩', '⇪', '⇫', '⇬', '⇭', '⇮', '⇯', '⇰', '⇱', '⇲', '⇳', '⇴', '⇵', '⇶', '⇷', '⇸', '⇹', '⇺', '⇻', '⇼', '⇽', '⇾', '⇿', '∀', '∁', '∂', '∃', '∄', '∅', '∆', '∇', '∈', '∉', '∊', '∋', '∌', '∍', '∎', '∏', '∐', '∑', '−', '∓', '∔', '∕', '∖', '∗', '∘', '∙', '√', '∛', '∜', '∝', '∞', '∟', '∠', '∡', '∢', '∣', '∤', '∥', '∦', '∧', '∨', '∩', '∪', '∫', '∬', '∭', '∮', '∯', '∰', '∱', '∲', '∳', '∴', '∵', '∶', '∷', '∸', '∹', '∺', '∻', '∼', '∽', '∾', '∿', '≀', '≁', '≂', '≃', '≄', '≅', '≆', '≇', '≈', '≉', '≊', '≋', '≌', '≍', '≎', '≏', '≐', '≑', '≒', '≓', '≔', '≕', '≖', '≗
# ...

# %% [markdown]
# #### East Asian Languages

# %% [markdown]
# * 2E80-2EFF CJK Radicals Supplement [Unicode](https://www.unicode.org/charts/PDF/U2E80.pdf)
# * 2F00-2FDF Kangxi Radicals [Unicode](https://www.unicode.org/charts/PDF/U2F00.pdf)
# * 2FE0-2FEF UNDEFINED
# * 2FF0-2FFF Ideographic Description Characters [Unicode](https://www.unicode.org/charts/PDF/U2FF0.pdf)
# * 3000-303F CJK Symbols and Punctuation [Unicode](http://www.unicode.org/charts/PDF/U3000.pdf)
# * 3040-309F Hiragana [Unicode](https://www.unicode.org/charts/PDF/U3040.pdf) [Wiki](https://en.wikipedia.org/wiki/Hiragana_(Unicode_block))
# * 30A0-30FF Katakana [Unicode](http://www.unicode.org/charts/PDF/U30A0.pdf) [Wiki](https://en.wikipedia.org/wiki/Katakana_(Unicode_block))
# * 3100-312F Bopomofo [Unicode](https://www.unicode.org/charts/PDF/U3100.pdf)
# * 3130-318F Hangul Compatibility Jamo [Unicode](https://www.unicode.org/charts/PDF/U3130.pdf)
# * 3190-319F Kanbun [Unicode](https://www.unicode.org/charts/PDF/U3190.pdf)
# * 31A0-31BF Bopomofo Extended [Unicode](https://www.unicode.org/charts/PDF/U31A0.pdf)
# * 31C0-31EF CJK Strokes [Unicode](https://www.unicode.org/charts/PDF/U31C0.pdf)
# * 31F0-31FF Katakana Phonetic Extensions [Unicode](http://www.unicode.org/charts/PDF/U31F0.pdf) [Wiki](https://en.wikipedia.org/wiki/Katakana_Phonetic_Extensions)
# * 3200-32FF Enclosed CJK Letters and Months [Unicode](http://www.unicode.org/charts/PDF/U3200.pdf)
# * 3300-33FF CJK Compatibility [Unicode](http://www.unicode.org/charts/PDF/U3300.pdf)
# * 3400-4DBF CJK Unified Ideographs Extension A [Unicode](https://www.unicode.org/charts/PDF/U3400.pdf)
# * 4DC0-
# * 4E00-9FFF CJK Unified Ideographs [Unicode](http://www.unicode.org/charts/PDF/U4E00.pdf)
# * A000-
# * F900-FAFF CJK Compatibility Ideographs [Unicode](https://www.unicode.org/charts/PDF/UF900.pdf)
# * FB00-
# * FE50-FE6F Small Form Variants [Unicode](http://www.unicode.org/charts/PDF/UFE50.pdf)
# * FE70-
# * FF00-FFEF Halfwidth and Fullwidth Forms [Unicode](http://www.unicode.org/charts/PDF/UFF00.pdf)
# * FFF0-
# * 1AFF0-1AFFF Kana Extended B [Unicode](http://www.unicode.org/charts/PDF/U1AFF0.pdf)
# * 1B000-1B0FF Kana Supplement [Unicode](http://www.unicode.org/charts/PDF/U1B000.pdf)
# * 1B130-1B16F Small Kana Extension [Unicode](http://www.unicode.org/charts/PDF/U1B130.pdf)
# * 20000-2A6DF CJK Unified Ideographs Extension B [Unicode](http://www.unicode.org/charts/PDF/U20000.pdf)

# %% [markdown]
# ##### CJK Radicals Supplement

# %%
# start  = 0x2E80
# stop   = 0x2EFF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### CJK Symbols and Punctuation

# %%
# start  = 0x3000
# stop   = 0x303F
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### Hiragana

# %%
# start  = 0x3040
# stop   = 0x309F
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### Katakana

# %%
# start  = 0x30A0
# stop   = 0x30FF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### Katakana Phonetic Extensions

# %%
# start  = 0x31F0
# stop   = 0x31FF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### Enclosed CJK Letters and Months

# %%
# start  = 0x3200
# stop   = 0x32FF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### CJK Compatibility

# %%
# start  = 0x3300
# stop   = 0x33FF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### Small Form Variants

# %%
# start  = 0xFE50
# stop   = 0xFE6F
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### Halfwidth and Fullwidth Forms

# %%
# start  = 0xFF00
# stop   = 0xFFEF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### CJK Unified Ideographs Extension A

# %%
# start  = 0x3400
# stop   = 0x4DBF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### CJK Unified Ideographs

# %%
# start  = 0x4E00
# stop   = 0x9FFF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ##### CJK Compatibility Ideographs

# %%
# start  = 0xF900
# stop   = 0xFAFF
# points = [chr(c) for c in range(start, stop)]
# print_code_point_information(points)

# %% [markdown]
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# * [ [d](http://www.unicode.org/charts/) ] Unicode Charts

# %% [markdown]
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Arrow_(symbol)) ] Arrow

# %% [markdown]
# ---
