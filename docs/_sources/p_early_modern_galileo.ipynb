# %% [markdown]
# # Galileo Galilei
# `1564-1632 (77)` [ [w](https://en.wikipedia.org/wiki/Galileo_Galilei) ][ [SEP](https://plato.stanford.edu/entries/galileo/) ]
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# ---
# ---
