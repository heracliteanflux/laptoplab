# %% [markdown]
# # Systems
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Henry_Gantt) ] `1861-1919` Gantt, Henry
# * [ [w](https://en.wikipedia.org/wiki/John_Henry_Holland) ] `1929-2015` Holland, John

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Closed_system) ] Closed System
# * [ [w](https://en.wikipedia.org/wiki/Complex_system) ] Complex System
# * [ [w](https://en.wikipedia.org/wiki/Complex_adaptive_system) ] Complex Adaptive System
# * [ [w](https://en.wikipedia.org/wiki/Conceptual_system) ] Conceptual System
# * [ [w](https://en.wikipedia.org/wiki/Control_theory) ] Control Theory
# * [ [w](https://en.wikipedia.org/wiki/Control-flow_diagram) ] Control-Flow Diagram (CFD)
# * [ [w](https://en.wikipedia.org/wiki/Deterministic_system) ] Deterministic System
# * [ [w](https://en.wikipedia.org/wiki/Dynamical_system) ] Dynamical System
# * [ [w](https://en.wikipedia.org/wiki/Hybrid_system) ] Hybrid System
# * [ [w](https://en.wikipedia.org/wiki/Linear_control) ] Linear Control
# * [ [w](https://en.wikipedia.org/wiki/Linear_system) ] Linear System
# * [ [w](https://en.wikipedia.org/wiki/Nonlinear_system) ] Nonlinear System
# * [ [w](https://en.wikipedia.org/wiki/Physical_system) ] Physical System
# * [ [w](https://en.wikipedia.org/wiki/System) ] System [ σύστημα ]
# * [ [w](https://en.wikipedia.org/wiki/System) ] System
# * [ [w](https://en.wikipedia.org/wiki/Deterministic_system) ] System, Deterministic
# * [ [w](https://en.wikipedia.org/wiki/Dynamical_system) ] System, Dynamical
# * [ [w](https://en.wikipedia.org/wiki/Linear_system) ] System, Linear
# * [ [w](https://en.wikipedia.org/wiki/Nonlinear_system) ] System, Nonlinear
# * [ [w](https://en.wikipedia.org/wiki/Systems_architecture) ] System Architecture
# * [ [w](https://en.wikipedia.org/wiki/System_context_diagram) ] System Context Diagram
# * [ [w](https://en.wikipedia.org/wiki/Systems_analysis) ] Systems Analysis
# * [ [w](https://en.wikipedia.org/wiki/Systems_development_life_cycle) ] Systems Development Life Cycle (SDLC)
# * [ [w](https://en.wikipedia.org/wiki/Systems_engineering) ] Systems Engineering
# * [ [w](https://en.wikipedia.org/wiki/Systems_modeling) ] Systems Modeling
# * [ [w](https://en.wikipedia.org/wiki/Systems_science) ] Systems Science
# * [ [w](https://en.wikipedia.org/wiki/Systems_theory) ] Systems Theory

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Business_process_modeling) ] Business Process Modeling (BPM)
# * [ [w](https://en.wikipedia.org/wiki/Flowchart) ] Flow Chart
# * [ [w](https://en.wikipedia.org/wiki/Flow_process_chart) ] Flow Process Chart
# * [ [w](https://en.wikipedia.org/wiki/Functional_flow_block_diagram) ] Functional Flow Block Diagram
# * [ [w](https://en.wikipedia.org/wiki/Gantt_chart) ] Gantt Chart
# * [ [w](https://en.wikipedia.org/wiki/Program_evaluation_and_review_technique) ] Program Evaluation and Review Technique (PERT)

# %% [markdown]
# ---
# ---
# ---
