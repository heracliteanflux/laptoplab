# %% [markdown]
# # Probability, Statistics, Stochastics
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Sections
# ```{tableofcontents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# [ [h](https://statisticaloddsandends.wordpress.com) ] Kenneth Tay's Statistical Odds & Ends
#
# `08-22-2020` Hall, Brayton. "The Reasoning Behind Bessel’s Correction: n-1: And Why it’s Not Always a Correction". Towards Data Science. <https://towardsdatascience.com/the-reasoning-behind-bessels-correction-n-1-eeea25ec9bc9>.
#
# [A concrete introduction to probability](https://nbviewer.org/url/norvig.com/ipython/Probability.ipynb)
#
# [STAT414](https://online.stat.psu.edu/stat414/)
#
# [Playing cards in unicode](https://en.wikipedia.org/wiki/Playing_cards_in_Unicode)

# %% [markdown]
# ### YouTube

# %% [markdown]
# 3Blue1Brown
# * [ [y](https://www.youtube.com/watch?v=cy8r7WSuT1I) ] `04-02-2023`. "Why π is in the normal distribution (beyond integral tricks)". YouTube.
# * [ [y](https://www.youtube.com/watch?v=HZGCoVF3YvM) ] `12-22-2019`. "Bayes theorem, the geometry of changing beliefs".
#
# Geek's Lesson
# * [ [y](https://www.youtube.com/watch?v=hjZJIVWHnPE) ] `06-21-2019` "Statistic for beginners | Statistics for Data Science".
#
# My Lesson
# * [ [y](https://www.youtube.com/watch?v=0GIwDazlUHs) ] `07-29-2021`. "Combinatorics and Probability (Complete Course) | Discrete Mathematics for Computer Science".
#
# [ [h](https://statquest.org/) ][ [y](https://www.youtube.com/c/joshstarmer) ] StatQuest with Josh Starmer
#
# more
# * [ [y](https://www.youtube.com/watch?v=6YzrVUVO9M0) ] `06-17-2023`. Primer. "A Secret Weapon for Predicting Outcomes: The Binomial Distribution".

# %% [markdown]
# [ [y](https://www.youtube.com/channel/UCtYLUTtgS3k1Fg4y5tAhLbw) ] Stat Quest
# * [ [y](https://www.youtube.com/watch?v=YCzL96nL7j0) ] StatQuest. (07 Nov 2022). "Long Short-Term Memory (LSTM), Clearly Explained".
# * [ [y](https://www.youtube.com/watch?v=khMzi6xPbuM) ] StatQuest. (19 Sep 2022). "Introduction to Coding Neural Networks with PyTorch and Lightning".
# * [ [y](https://www.youtube.com/watch?v=AsNTP8Kwu80) ] StatQuest. (11 Jul 2022). "Recurrent Neural Networks (RNNs), Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=FHdlXe1bSe4) ] StatQuest. (25 Apr 2022). "The StatQuest Introduction to PyTorch".
# * [ [y](https://www.youtube.com/watch?v=L35fFDpwIM4) ] StatQuest. (28 Feb 2022). "Tensors for Neural Networks, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=HGwBXDKFk9I) ] StatQuest. (08 Mar 2021). "Neural Networks Part 8: Image Classification with Convolutional Neural Networks (CNNs)".
# * [ [y](https://www.youtube.com/watch?v=xBEh66V9gZo) ] StatQuest. (01 Mar 2021). "Neural Networks Part 7: Cross Entropy Derivatives and Backpropagation".
# * [ [y](https://www.youtube.com/watch?v=6ArSys5qHAU) ] StatQuest. (01 Mar 2021). "Neural Networks Part 6: Cross Entropy".
# * [ [y](https://www.youtube.com/watch?v=KpKog-L9veg) ] StatQuest. (07 Feb 2021). "Neural Networks Part 5: ArgMax and SoftMax".
# * [ [y](https://www.youtube.com/watch?v=83LYR-1IcjA) ] StatQuest. (01 Feb 2021). "Neural Networks Pt. 4: Multiple Inputs and Outputs".
# * [ [y](https://www.youtube.com/watch?v=68BZ5f7P94E) ] StatQuest. (23 Nov 2020). "Neural Networks Pt. 3: ReLU In Action!!!".
# * [ [y](https://www.youtube.com/watch?v=GKZoOHXGcLo) ] StatQuest. (02 Nov 2020). "Backpropagation Details Pt. 2: Going bonkers with The Chain Rule".
# * [ [y](https://www.youtube.com/watch?v=iyn2zdALii8) ] StatQuest. (02 Nov 2020). "Backpropagation Details Pt. 1: Optimizing 3 parameters simultaneously".
# * [ [y](https://www.youtube.com/watch?v=IN2XmBhILt4) ] StatQuest. (19 Oct 2020). "Neural Networks Pt. 2: Backpropagation Main Ideas".
# * [ [y](https://www.youtube.com/watch?v=CqOfi41LfDw) ] StatQuest. (31 Aug 2020). "Neural Networks Pt. 1: Inside the Black Box".
# * [ [y](https://www.youtube.com/watch?v=GrJP9FLV3FE) ] StatQuest. (01 Aug 2020). "XGBoost in Python from Start to Finish".
# * [ [y](https://www.youtube.com/watch?v=5koKb5B_YWo) ] StatQuest. (06 Jul 2020). "Alternative Hypotheses: Main Ideas!!!".
# * [ [y](https://www.youtube.com/watch?v=0oc49DyA3hU) ] StatQuest. (06 Jul 2020). "Hypothesis Testing and The Null Hypothesis, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=8A7L0GsBiLQ) ] StatQuest. (30 Jun 2020). "Support Vector Machines in Python from Start to Finish".
# * [ [y](https://www.youtube.com/watch?v=q90UDEgYqeI) ] StatQuest. (06 Jun 2020). "Classification Trees in Python from Start to Finish".
# * [ [y](https://www.youtube.com/watch?v=HDCOUXE3HMM) ] StatQuest. (04 May 2020). "p-hacking: What it is and how to avoid it!"
# * [ [y](https://www.youtube.com/watch?v=VX_M3tIyiYk) ] StatQuest. (04 May 2020). "Power Analysis, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=Rsc5znwR5FA) ] StatQuest. (04 May 2020). "Statistical Power, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=JQc3yx0-Q9E) ] StatQuest. (23 Mar 2020). "How to calculate p-values".
# * [ [y](https://www.youtube.com/watch?v=vemZtEM63GY) ] StatQuest. (23 Mar 2020). "p-values: What they are and how to interpret them".
# * [ [y](https://www.youtube.com/watch?v=oRrKeUCEbq8) ] StatQuest. (02 Mar 2020). "XGBoost Part 4 (of 4): Crazy Cool Optimizations".
# * [ [y](https://www.youtube.com/watch?v=ZVFeW798-2I) ] StatQuest. (10 Feb 2020). "XGBoost Part 3 (of 4): Mathematical Details".
# * [ [y](https://www.youtube.com/watch?v=8b1JEDvenQU) ] StatQuest. (13 Jan 2020). "XGBoost Part 2 (of 4): Classification".
# * [ [y](https://www.youtube.com/watch?v=OtD8wVaFm6E) ] StatQuest. (16 Dec 2019). "XGBoost Part 1 (of 4): Regression".
# * [ [y](https://www.youtube.com/watch?v=Qc5IyLW_hns) ] StatQuest. (04 Nov 2019). "Support Vector Machines Part 3: The Radial (RBF) Kernel (Part 3 of 3)".
# * [ [y](https://www.youtube.com/watch?v=Toet3EiSFcM) ] StatQuest. (04 Nov 2019). "Support Vector Machines Part 2: The Polynomial Kernel (Part 2 of 3)".
# * [ [y](https://www.youtube.com/watch?v=efR1C6CvhmE) ] StatQuest. (30 Sep 2019). "Support Vector Machines Part 1 (of 3): Main Ideas!!!".
# * [ [y](https://www.youtube.com/watch?v=wl1myxrtQHQ) ] StatQuest. (13 Jul 2019). "The Chain Rule".
# * [ [y](https://www.youtube.com/watch?v=4jRBRDbJemM) ] StatQuest. (11 Jul 2019). "ROC and AUC, Clearly Explained!".
# * [ [y](https://www.youtube.com/watch?v=vMh0zPT0tLI) ] StatQuest. (13 May 2019). "Stochastic Gradient Descent, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=StWY5QWMXCw) ] StatQuest. (22 Apr 2019). "Gradient Boost Part 4 (of 4): Classification Details".
# * [ [y](https://www.youtube.com/watch?v=jxuNLH5dXCs) ] StatQuest. (08 Apr 2019). "Gradient Boost Part 3 (of 4): Classification".
# * [ [y](https://www.youtube.com/watch?v=2xudPOBz-vs) ] StatQuest. (01 Apr 2019). "Gradient Boost Part 2 (of 4): Regression Details".
# * [ [y](https://www.youtube.com/watch?v=3CC4N4z3GJc) ] StatQuest. (25 Mar 2019). "Gradient Boost Part 1 (of 4): Regression Main Ideas".
# * [ [y](https://www.youtube.com/watch?v=sDv4f4s2SB8) ] StatQuest. (05 Feb 2019). "Gradient Descent, Step-by-Step".
# * [ [y](https://www.youtube.com/watch?v=LsK-xG1cLYA) ] StatQuest. (14 Jan 2019). "AdaBoost, Clearly Explained".
# * [ [y](https://www.youtube.com/watch?v=1dKRdX9bfIo) ] StatQuest. (08 Oct 2018). "Regularization Part 3: Elastic Net Regression".
# * [ [y](https://www.youtube.com/watch?v=NGf0voTMlcs) ] StatQuest. (01 Oct 2018). "Regularization Part 2: Lasso (L1) Regression".
# * [ [y](https://www.youtube.com/watch?v=Q81RR3yKn30) ] StatQuest. (24 Sep 2018). "Regularization Part 1: Ridge (L2) Regression".
# * [ [y](https://www.youtube.com/watch?v=EuBBz3bI-aA) ] StatQuest. (17 Sep 2018). "Machine Learning Fundamentals: Bias and Variance".
# * [ [y](https://www.youtube.com/watch?v=YAlJCEDH2uY) ] StatQuest. (03 Sep 2018). "The Central Limit Theorem, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=oRvgq966yZg) ] StatQuest. (09 Apr 2018). "StatQuest: PCA - Practical Tips".
# * [ [y](https://www.youtube.com/watch?v=FgakZw6K1QQ) ] StatQuest. (02 Apr 2018). "StatQuest: Principal Component Analysis (PCA), Step-by-Step".
# * [ [y](https://www.youtube.com/watch?v=GEn-_dAyYME) ] StatQuest. (11 Dec 2017). "StatQuest: MDS and PCoA".
# * [ [y](https://www.youtube.com/watch?v=A82brFpdr9g) ] StatQuest. (20 Mar 2017). "Standard Deviation vs Standard Error, Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=VSi0Z04fWj0) ] StatQuest. (23 Feb 2017). "Logs (logarithms), Clearly Explained!!!".
# * [ [y](https://www.youtube.com/watch?v=K8LQSvtjcEo) ] StatQuest. (10 Jan 2017). "False Discovery Rates, FDR, clearly explained".
# * [ [y](https://www.youtube.com/watch?v=UFhJefdVCjE) ] StatQuest. (11 Oct 2016). "p-hacking and power calculations".
# * [ [y](https://www.youtube.com/watch?v=azXCzI57Yfc) ] StatQuest. (10 Jul 2016). "StatQuest: Linear Discriminant Analysis (LDA) clearly explained".
# * [ [y](https://www.youtube.com/watch?v=_UVHneBUBW0) ] StatQuest. (13 Aug 2015). "Principal Component Analysis (PCA) clearly explained (2015)".

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Thomas_Bayes) ] `1701-1761` Bayes, Thomas
# * [ [w](https://en.wikipedia.org/wiki/Jacob_Bernoulli) ] `1655-1705` Bernoulli, Jacob
# * [ [w](https://en.wikipedia.org/wiki/Gerolamo_Cardano) ] `1501-1576` Cardano, Gerolamo
# * [ [w](https://en.wikipedia.org/wiki/Pierre_de_Fermat) ] `1607-1665` Fermat, Pierre
# * [ [w](https://en.wikipedia.org/wiki/Ronald_Fisher) ] `1890-1962` Fisher, Ronald
# * [ [w](https://en.wikipedia.org/wiki/Christiaan_Huygens) ] `1629-1695` Huygens, Christiaan
# * [ [w](https://en.wikipedia.org/wiki/Kiyosi_Itô) ] `1915-2008` Ito, Kiyoshi
# * [ [w](https://en.wikipedia.org/wiki/Andrey_Kolmogorov) ] `1903-1987` Kolmogorov, Andrey
# * [ [w](https://en.wikipedia.org/wiki/Pierre-Simon_Laplace) ] `1749-1827` Laplace, Pierre-Simon
# * [ [w](https://en.wikipedia.org/wiki/Andrey_Markov) ] `1856-1922` Markov, Andrey
# * [ [w](https://en.wikipedia.org/wiki/Blaise_Pascal) ] `1623-1662` Pascal, Blaise
# * [ [w](https://en.wikipedia.org/wiki/Karl_Pearson) ] `1857-1936` Pearson, Karl
# * [ [w](https://en.wikipedia.org/wiki/Siméon_Denis_Poisson) ] `1781-1840` Poisson, Simeon
# * [ [w](https://en.wikipedia.org/wiki/Stanley_Smith_Stevens) ] `1906-1973` Stevens, Stanley
# * [ [w](https://en.wikipedia.org/wiki/John_Tukey) ] `1915-2000` Tukey, John
# * [ [w](https://en.wikipedia.org/wiki/John_Venn) ] `1834-1923` Venn, John
# * [ [w](https://en.wikipedia.org/wiki/Norbert_Wiener) ] `1894-1964` Wiener, Norbert

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Texts

# %% [markdown]
# * `2020` Bruce, Peter, Andrew Bruce, & Peter Gedeck. [_Practical Statistics for Data Scientists: 50+ Essential Concepts Using R and Python, 2nd Ed_](https://github.com/gedeck/practical-statistics-for-data-scientists). O'Reilly.
# * `2019` [Forsyth, David](http://luthuli.cs.uiuc.edu/~daf/). _Probability and Statistics for Computer Science_. Springer.
# * `2012` Givens, Geof H. & Jennifer A. Hoeting. _Computational Statistics, 2nd Ed_. Wiley.
# * `????` Grus, Joel. _Data Science from Scratch_ 2nd Ed. O'Reilly.
# * `????` Kneusel, Ronald T. _Math for Deep Learning_. No Starch Press.
# * `2019` Kurt, Will. _Bayesian Statistics the Fun Way: Understanding Statistics and Probability with Star Wars, LEGO, and Rubber Ducks_. No Starch Press.
# * `2017` Mitzenmacher, Michael & Eli Upfal. _Probability and Computing: Randomization and Probabilistic Techniques in Algorithms and Data Analysis, 2nd Ed_. Cambridge University Press.
# * `????` Nelson, Hala. _Essential Math for AI_. O'Reilly.
# * `????` Nield, Thomas. _Essential Math for Data Science_. O'Reilly.
# * `????` Orland, Paul. _Math for Programmers_. Manning.[GitHub](https://github.com/orlandpm/Math-for-Programmers).
# * `2015` Reinhart, Alex. _Statistics Done Wrong: The Woefully Complete Guide_. No Starch Press.
# * `2007` Rizzo, Maria L. _Statistical Computing with R_.
# * `2019` Ross, Sheldon M. _Introduction to Probability Models, 12th Ed_.
# * `2018` Ross, Sheldon M. _A First Course in Probability, 10th Ed_. Pearson.
# * `2019` Tan, Pang-Ning et al. _Introduction to Data Mining_. 2nd Ed. Pearson. [Home](https://www-users.cse.umn.edu/~kumar001/dmbook/index.php).
# * `2022` Utts, Jessica M. & Robert F. Heckard. _Mind on Statistics_ 6e. [Cengage](https://www.cengage.com/c/mind-on-statistics-6e-utts-heckard/9781337793605/).
# * `????` Wasserman, Larry. [_All of Statistics: A Concise Course in Statistical Inference_](http://www.stat.cmu.edu/~larry/all-of-statistics/index.html).

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/68–95–99.7_rule) ] 68-95-99.7 Rule
# * [ [w](https://en.wikipedia.org/wiki/Accuracy_and_precision) ] Accuracy
# * [ [w](https://en.wikipedia.org/wiki/Algebra_of_random_variables) ] Algebra of Random Variables
# * [ [w](https://en.wikipedia.org/wiki/Analysis_of_variance) ] Analysis of Variance (ANOVA)
# * [ [w](https://en.wikipedia.org/wiki/Area_chart) ] Area Plot
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic_mean) ] Arithmetic Mean
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic_mean) ] Average
# * [ [w](https://en.wikipedia.org/wiki/Average) ] Average
# * [ [w](https://en.wikipedia.org/wiki/Average_absolute_deviation) ] Average Absolute Deviation (AAD)
# * [ [w](https://en.wikipedia.org/wiki/Bar_chart) ] Bar Plot
# * [ [w](https://en.wikipedia.org/wiki/Bayes%27_theorem) ] Bayes' Theorem
# * [ [w](https://en.wikipedia.org/wiki/Bayesian_probability) ] Bayesian Probability
# * [ [w](https://en.wikipedia.org/wiki/Bayesian_statistics) ] Bayesian Statistics
# * [ [w](https://en.wikipedia.org/wiki/Bernoulli_distribution) ] Bernoulli Distribution
# * [ [w](https://en.wikipedia.org/wiki/Bernoulli_trial) ] Bernoulli Trial
# * [ [w](https://en.wikipedia.org/wiki/Bessel%27s_correction) ] Bessel's Correction
# * [ [w](https://en.wikipedia.org/wiki/Biplot) ] Bi Plot
# * [ [w](https://en.wikipedia.org/wiki/Data_binning) ] Bin
# * [ [w](https://en.wikipedia.org/wiki/Binary_data) ] Binary Data
# * [ [w](https://en.wikipedia.org/wiki/Binomial_distribution) ] Binomial Distribution
# * [ [w](https://en.wikipedia.org/wiki/Bootstrapping_(statistics)) ] Bootstrapping
# * [ [w](https://en.wikipedia.org/wiki/Box_plot) ] Box Plot
# * [ [w](https://en.wikipedia.org/wiki/Brownian_motion) ] Brownian Motion
# * [ [w](https://en.wikipedia.org/wiki/Bubble_chart) ] Bubble Plot
# * [ [w](https://en.wikipedia.org/wiki/Categorical_variable) ] Categorical Variable
# * [ [w](https://en.wikipedia.org/wiki/Centering_matrix) ] Centering Matrix
# * [ [w](https://en.wikipedia.org/wiki/Central_limit_theorem) ] Central Limit Theorem
# * [ [w](https://en.wikipedia.org/wiki/Central_moment) ] Central Moment
# * [ [w](https://en.wikipedia.org/wiki/Central_tendency) ] Central Tendency
# * [ [w](https://en.wikipedia.org/wiki/Chi-squared_distribution) ] Chi-Squared Distribution
# * [ [w](https://en.wikipedia.org/wiki/Choropleth_map) ] Choropleth Plot
# * [ [w](https://en.wikipedia.org/wiki/Confidence_interval) ] CI Confidence Interval
# * [ [w](https://en.wikipedia.org/wiki/Classical_definition_of_probability) ] Classical Probability
# * [ [w](https://en.wikipedia.org/wiki/Codebook) ] Codebook
# * [ [w](https://en.wikipedia.org/wiki/Coefficient_of_variation) ] Coefficient of Variation
# * [ [w](https://en.wikipedia.org/wiki/Combinatorics) ] Combinatorics
# * [ [w](https://en.wikipedia.org/wiki/Conditional_probability) ] Conditional Probability
# * [ [w](https://en.wikipedia.org/wiki/Confidence_interval) ] Confidence Interval
# * [ [w](https://en.wikipedia.org/wiki/Continuous-time_Markov_chain) ] Continuous-Time Markov Chain (CTMC)
# * [ [w](https://en.wikipedia.org/wiki/Correlation) ] Correlation
# * [ [w](https://en.wikipedia.org/wiki/Count_data) ] Count Data
# * [ [w](https://en.wikipedia.org/wiki/Counting_process) ] Counting Process
# * [ [w](https://en.wikipedia.org/wiki/Covariance) ] Covariance
# * [ [w](https://en.wikipedia.org/wiki/Cumulative_distribution_function) ] Cumulative Distribution Function (CDF)
# * [ [w](https://en.wikipedia.org/wiki/Data) ] Data
# * [ w ] Data, Semi Structured
# * [ w ] Data, Structured
# * [ w ] Data, Unstructured
# * [ [w](https://en.wikipedia.org/wiki/Data_analysis) ] Data Analysis
# * [ w ] Data Analytics
# * [ w ] Data Attribute
# * [ [w](https://en.wikipedia.org/wiki/Data_augmentation) ] Data Augmentation
# * [ [w](https://en.wikipedia.org/wiki/Data_cleansing) ] Data Cleaning
# * [ [w](https://en.wikipedia.org/wiki/Data_consistency) ] Data Consistency
# * [ w ] Data Engineering
# * [ [w](https://en.wikipedia.org/wiki/Data_exploration) ] Data Exploration
# * [ [w](https://en.wikipedia.org/wiki/Data_governance) ] Data Governance
# * [ [w](https://en.wikipedia.org/wiki/Data_integration) ] Data Integration
# * [ [w](https://en.wikipedia.org/wiki/Data_integrity) ] Data Integrity
# * [ [w](https://en.wikipedia.org/wiki/Data_management) ] Data Management
# * [ [w](https://en.wikipedia.org/wiki/Data_mining) ] Data Mining
# * [ [w](https://en.wikipedia.org/wiki/Mung_(computer_term)) ] Data Munging
# * [ w ] Data Object
# * [ w ] Data Observation
# * [ w ] Data Point
# * [ [w](https://en.wikipedia.org/wiki/Data_preparation) ] Data Preparation
# * [ [w](https://en.wikipedia.org/wiki/Data_profiling) ] Data Profiling
# * [ [w](https://en.wikipedia.org/wiki/Data_quality) ] Data Quality
# * [ [w](https://en.wikipedia.org/wiki/Data_redundancy) ] Data Redundancy
# * [ w ] Data Science
# * [ [w](https://en.wikipedia.org/wiki/Data_security) ] Data Security
# * [ [w](https://en.wikipedia.org/wiki/Data_set) ] Data Set
# * [ [w](https://en.wikipedia.org/wiki/Data_transformation_(statistics)) ] Data Transformation
# * [ w ] Data Type
# * [ [w](https://en.wikipedia.org/wiki/Data_validation) ] Data Validation
# * [ [w](https://en.wikipedia.org/wiki/Data_and_information_visualization) ] Data Visualization
# * [ [w](https://en.wikipedia.org/wiki/Data_wrangling) ] Data Wrangling
# * [ [w](https://en.wikipedia.org/wiki/Decile) ] Decile
# * [ [w](https://en.wikipedia.org/wiki/Degrees_of_freedom_(statistics)) ] Degrees of Freedom
# * [ [w](https://en.wikipedia.org/wiki/Deming_regression) ] Deming Regression
# * [ [w](https://en.wikipedia.org/wiki/Descriptive_statistics) ] Descriptive Statistics
# * [ [w](https://en.wikipedia.org/wiki/Deviation_(statistics)) ] Deviation
# * [ [w](https://en.wikipedia.org/wiki/Diffusion_process) ] Diffusion Process
# * [ [w](https://en.wikipedia.org/wiki/Dimensionality_reduction) ] Dimensionality Reduction
# * [ [w](https://en.wikipedia.org/wiki/Discrete-time_Markov_chain) ] Discrete-Time Markov Chain (DTMC)
# * [ [w](https://en.wikipedia.org/wiki/Discretization) ] Discretization
# * [ [w](https://en.wikipedia.org/wiki/Statistical_dispersion) ] Dispersion
# * [ [w](https://en.wikipedia.org/wiki/Distance_correlation) ] Distance Correlation
# * [ [w](https://en.wikipedia.org/wiki/Distance_correlation) ] Distance Covariance
# * [ [w](https://en.wikipedia.org/wiki/Dummy_variable_(statistics)) ] Dummy Variable
# * [ [w](https://en.wikipedia.org/wiki/Errors_and_residuals) ] Error
# * [ [w](https://en.wikipedia.org/wiki/Estimand) ] Estimand
# * [ [w](https://en.wikipedia.org/wiki/Estimation) ] Estimation
# * [ [w](https://en.wikipedia.org/wiki/Estimator) ] Estimator
# * [ [w](https://en.wikipedia.org/wiki/Event_(probability_theory)) ] Event
# * [ [w](https://en.wikipedia.org/wiki/Expected_value) ] Expectation
# * [ [w](https://en.wikipedia.org/wiki/Expectation–maximization_algorithm) ] Expectation Maximization (EM)
# * [ [w](https://en.wikipedia.org/wiki/Expected_value) ] Expected Value
# * [ [w](https://en.wikipedia.org/wiki/Experiment_(probability_theory)) ] Experiment
# * [ [w](https://en.wikipedia.org/wiki/Design_of_experiments) ] Experimental Design
# * [ [w](https://en.wikipedia.org/wiki/Exploratory_data_analysis) ] Exploratory Data Analysis (EDA)
# * [ [w](https://en.wikipedia.org/wiki/Exponential_distribution) ] Exponential Distribution
# * [ [w](https://en.wikipedia.org/wiki/Fat-tailed_distribution) ] Fat-Tailed Distribution
# * [ [w](https://en.wikipedia.org/wiki/Feature_engineering) ] Feature Engineering
# * [ [w](https://en.wikipedia.org/wiki/Feature_scaling) ] Feature Scaling
# * [ [w](https://en.wikipedia.org/wiki/Five-number_summary) ] Five-Number Summary
# * [ [w](https://en.wikipedia.org/wiki/Frequency_(statistics)) ] Frequency
# * [ [w](https://en.wikipedia.org/wiki/Frequentist_probability) ] Frequentism
# * [ [w](https://en.wikipedia.org/wiki/Frequentist_inference) ] Frequentist Inference
# * [ [w](https://en.wikipedia.org/wiki/Gambler%27s_fallacy) ] Gambler's Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Game_of_chance) ] Game of Chance
# * [ [w](https://en.wikipedia.org/wiki/Gaussian_process) ] Gaussian Process
# * [ [w](https://en.wikipedia.org/wiki/Geometric_Brownian_motion) ] Geometric Brownian Motion (GBM)
# * [ w ] Geometric Random Walk
# * [ [w](https://en.wikipedia.org/wiki/Gini_coefficient) ] Gini Coefficient
# * [ [w](https://en.wikipedia.org/wiki/Goodness_of_fit) ] Goodness of Fit
# * [ [w](https://en.wikipedia.org/wiki/Hardware_random_number_generator) ] Hardware Random Number Generator
# * [ [w](https://en.wikipedia.org/wiki/Heavy-tailed_distribution) ] Heavy-Tailed Distribution
# * [ [w](https://en.wikipedia.org/wiki/Hidden_Markov_model) ] Hidden Markov Model (HMM)
# * [ [w](https://en.wikipedia.org/wiki/Histogram) ] Histogram
# * [ [w](https://en.wikipedia.org/wiki/Statistical_hypothesis_testing) ] Hypothesis Test
# * [ [w](https://en.wikipedia.org/wiki/Independence_(probability_theory)) ] Independence
# * [ [w](https://en.wikipedia.org/wiki/Independent_and_identically_distributed_random_variables) ] Independent and Identical Distribution (IID)
# * [ [w](https://en.wikipedia.org/wiki/Independent_and_identically_distributed_random_variables) ] Independent and Identically Distributed (IID)
# * [ [w](https://en.wikipedia.org/wiki/Interquartile_mean) ] Inter Quartile Mean (IQM)
# * [ [w](https://en.wikipedia.org/wiki/Interquartile_range) ] Inter Quartile Range (IQR)
# * [ [w](https://en.wikipedia.org/wiki/Interval_estimation) ] Interval Estimation
# * [ w ] Interval Scale
# * [ [w](https://en.wikipedia.org/wiki/Itô_calculus) ] Ito Calculus
# * [ [w](https://en.wikipedia.org/wiki/Itô_calculus) ] Ito's Calculus
# * [ [w](https://en.wikipedia.org/wiki/Itô%27s_lemma) ] Ito's Lemma
# * [ [w](https://en.wikipedia.org/wiki/Jump_diffusion) ] Jump Diffusion
# * [ [w](https://en.wikipedia.org/wiki/Jump_process) ] Jump Process
# * [ [w](https://en.wikipedia.org/wiki/Probability_axioms) ] Kolmogorov Axioms
# * [ [w](https://en.wikipedia.org/wiki/Kurtosis) ] Kurtosis
# * [ [w](https://en.wikipedia.org/wiki/L-moment) ] L-Moment
# * [ [w](https://en.wikipedia.org/wiki/Law_of_large_numbers) ] Law of Large Numbers
# * [ [w](https://en.wikipedia.org/wiki/Law_of_total_expectation) ] Law of Total Expectation
# * [ [w](https://en.wikipedia.org/wiki/Law_of_total_variance) ] Law of Total Variance
# * [ [w](https://en.wikipedia.org/wiki/Least_absolute_deviations) ] Least Absolute Deviation (LAD)
# * [ [w](https://en.wikipedia.org/wiki/Level_of_measurement) ] Level of Measurement
# * [ [w](https://en.wikipedia.org/wiki/Level_of_measurement) ] Level/Scale of Measure(ment)
# * [ [w](https://en.wikipedia.org/wiki/Line_chart) ] Line Plot
# * [ [w](https://en.wikipedia.org/wiki/Log-normal_distribution) ] Log-Normal Distribution
# * [ [w](https://en.wikipedia.org/wiki/Long_tail) ] Long-Tailed Distribution
# * [ [w](https://en.wikipedia.org/wiki/Malliavin_calculus) ] Malliavin Calculus
# * [ [w](https://en.wikipedia.org/wiki/Markov_chain_Monte_Carlo) ] Markov Chain Monte Carlo (MCMC)
# * [ [w](https://en.wikipedia.org/wiki/Markov_model) ] Markov Model
# * [ [w](https://en.wikipedia.org/wiki/Markov_chain) ] Markov Process
# * [ [w](https://en.wikipedia.org/wiki/Markov_property) ] Markov Property
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_cellular_automaton) ] Markov Random Field
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_statistics) ] Mathematical Statistics (MAD)
# * [ [w](https://en.wikipedia.org/wiki/Maximum_and_minimum) ] Maximum
# * [ [w](https://en.wikipedia.org/wiki/Maximum_a_posteriori_estimation) ] Maximum A Posteriori Estimate (MAP)
# * [ [w](https://en.wikipedia.org/wiki/Maximum_likelihood_estimation) ] Maximum Likelihood Estimation (MLE)
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic_mean) ] Mean
# * [ [w](https://en.wikipedia.org/wiki/Mean) ] Mean
# * [ [w](https://en.wikipedia.org/wiki/Mean_absolute_difference) ] Mean Absolute Difference
# * [ [w](https://en.wikipedia.org/wiki/Mean_absolute_error) ] Mean Absolute Error (MAE)
# * [ [w](https://en.wikipedia.org/wiki/Mean_squared_error) ] Mean Squared Error
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic_mean) ] Mean, Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Geometric_mean) ] Mean, Geometric
# * [ [w](https://en.wikipedia.org/wiki/Harmonic_mean) ] Mean, Harmonic
# * [ [w](https://en.wikipedia.org/wiki/Pythagorean_means) ] Mean, Pythagorean
# * [ [w](https://en.wiktionary.org/wiki/measurand) ] Measurand
# * [ [w](https://en.wikipedia.org/wiki/Observational_error) ] Measurement Error
# * [ [w](https://en.wikipedia.org/wiki/Measurement_uncertainty) ] Measurement Uncertainty
# * [ [w](https://en.wikipedia.org/wiki/Median) ] Median
# * [ [w](https://en.wikipedia.org/wiki/Median_absolute_deviation) ] Median Absolute Deviation
# * [ [w](https://en.wikipedia.org/wiki/Median_absolute_deviation) ] Median Absolute Deviation (MAD)
# * [ [w](https://en.wikipedia.org/wiki/Maximum_and_minimum) ] Minimum
# * [ [w](https://en.wikipedia.org/wiki/Mode_(statistics)) ] Mode
# * [ [w](https://en.wikipedia.org/wiki/Moment_(mathematics)) ] Moment
# * [ [w](https://en.wikipedia.org/wiki/Monte_Carlo_method) ] Monte Carlo
# * [ [w](https://en.wikipedia.org/wiki/Monte_Carlo_method) ] Monte Carlo Method
# * [ [w](https://en.wikipedia.org/wiki/Monty_Hall_problem) ] Monty Hall Problem
# * [ w ] Nominal Scale
# * [ [w](https://en.wikipedia.org/wiki/Nonparametric_statistics) ] Non Parametric Statistics
# * [ [w](https://en.wikipedia.org/wiki/Normal_distribution) ] Normal Distribution
# * [ [w](https://en.wikipedia.org/wiki/Normal_distribution) ] Normal Distribution or Gaussian Distribution
# * [ [w](https://en.wikipedia.org/wiki/Normality_test) ] Normality Test
# * [ [w](https://en.wikipedia.org/wiki/Normality_test) ] Normality Testing
# * [ [w](https://en.wikipedia.org/wiki/Normalization_(statistics)) ] Normalization
# * [ [w](https://en.wikipedia.org/wiki/Null_hypothesis) ] Null Hypothesis
# * [ [w](https://en.wikipedia.org/wiki/Observational_error) ] Observational Error
# * [ [w](https://en.wikipedia.org/wiki/Odds) ] Odds
# * [ [w](https://en.wikipedia.org/wiki/Odds_ratio) ] Odds Ratio
# * [ [w](https://en.wikipedia.org/wiki/Online_analytical_processing) ] On-Line Analytical Processing (OLAP)
# * [ [w](https://en.wikipedia.org/wiki/One-hot) ] One-Hot Encoding
# * [ [w](https://en.wikipedia.org/wiki/One-_and_two-tailed_tests) ] One-Tailed Test
# * [ [w](https://en.wikipedia.org/wiki/Optimality_criterion) ] Optimality Criterion
# * [ [w](https://en.wikipedia.org/wiki/Order_statistic) ] Order Statistic
# * [ [w](https://en.wikipedia.org/wiki/Ordinal_data) ] Ordinal Data
# * [ [w](https://en.wikipedia.org/wiki/Outcome_(probability)) ] Outcome
# * [ [w](https://en.wikipedia.org/wiki/Outlier) ] Outlier
# * [ [w](https://en.wikipedia.org/wiki/P-value) ] P Value
# * [ [w](https://en.wikipedia.org/wiki/Statistical_parameter) ] Parameter
# * [ [w](https://en.wikipedia.org/wiki/Pattern_recognition) ] Pattern Recognition
# * [ [w](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient) ] Pearson Correlation Coefficient
# * [ [w](https://en.wikipedia.org/wiki/Percentile) ] Percentile
# * [ [w](https://en.wikipedia.org/wiki/Percentile) ] Percentile or Centile
# * [ [w](https://en.wikipedia.org/wiki/Philosophy_of_statistics) ] Philosophy of Statistics
# * [ [w](https://en.wikipedia.org/wiki/Pie_chart) ] Pie Plot
# * [ [w](https://en.wikipedia.org/wiki/Plot_(graphics)) ] Plot
# * [ [w](https://en.wikipedia.org/wiki/Point_estimation) ] Point Estimation
# * [ [w](https://en.wikipedia.org/wiki/Poisson_distribution) ] Poisson Distribution
# * [ [w](https://en.wikipedia.org/wiki/Poisson_point_process) ] Poisson Process
# * [ [w](https://en.wikipedia.org/wiki/Statistical_population) ] Population
# * [ [w](https://en.wikipedia.org/wiki/Possibility_theory) ] Possibility Theory
# * [ [w](https://en.wikipedia.org/wiki/Posterior_probability) ] Posterior Probability
# * [ [w](https://en.wikipedia.org/wiki/Accuracy_and_precision) ] Precision
# * [ [w](https://en.wikipedia.org/wiki/Predictive_analytics) ] Predictive Analytics
# * [ [w](https://en.wikipedia.org/wiki/Preferential_attachment) ] Preferential Attachment
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_indifference) ] Principle of Indifference
# * [ [w](https://en.wikipedia.org/wiki/Prior_probability) ] Prior Probability
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_cellular_automaton) ] Probabilistic Cellular Automaton
# * [ [w](https://en.wikipedia.org/wiki/Probability) ] Probability
# * [ [w](https://en.wikipedia.org/wiki/Probability_density_function) ] Probability Density Function (PDF)
# * [ [w](https://en.wikipedia.org/wiki/Probability_distribution) ] Probability Distribution
# * [ [w](https://en.wikipedia.org/wiki/Probability_mass_function) ] Probability Mass Function
# * [ [w](https://en.wikipedia.org/wiki/Probability_space) ] Probability Space
# * [ [w](https://en.wikipedia.org/wiki/Probability_theory) ] Probability Theory
# * [ [w](https://en.wikipedia.org/wiki/Classical_definition_of_probability) ] Probability, classical definition
# * [ [w](https://en.wikipedia.org/wiki/Pseudorandom_number_generator) ] Pseudorandom Number Generator (PNG)
# * [ [w](https://en.wikipedia.org/wiki/Pseudorandomness) ] Pseudorandomness
# * [ [w](https://en.wikipedia.org/wiki/Quantile) ] Quantile
# * [ [w](https://en.wikipedia.org/wiki/Continuous_or_discrete_variable) ] Quantitative Variable
# * [ [w](https://en.wikipedia.org/wiki/Quartile) ] Quartile
# * [ [w](https://en.wikipedia.org/wiki/Quickselect) ] Quickselect
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_cellular_automaton) ] Random Cellular Automaton
# * [ [w](https://en.wikipedia.org/wiki/Random_field) ] Random Field
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_process) ] Random Function
# * [ [w](https://en.wikipedia.org/wiki/Random_number_generation) ] Random Number Generator
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_process) ] Random Process
# * [ [w](https://en.wikipedia.org/wiki/Random_seed) ] Random Seed
# * [ [w](https://en.wikipedia.org/wiki/Random_variable) ] Random Variable
# * [ [w](https://en.wikipedia.org/wiki/Random_walk) ] Random Walk
# * [ w ] Random Walk, Geometric
# * [ [w](https://en.wikipedia.org/wiki/Randomness) ] Randomness
# * [ [w](https://en.wikipedia.org/wiki/Range_(statistics)) ] Range
# * [ [w](https://en.wikipedia.org/wiki/Ranking) ] Rank
# * [ w ] Ratio Scale
# * [ [w](https://en.wikipedia.org/wiki/Deming_regression) ] Regression, Deming
# * [ [w](https://en.wikipedia.org/wiki/Empirical_probability) ] Relative Frequency
# * [ [w](https://en.wikipedia.org/wiki/Renewal_theory) ] Renewal Theory
# * [ [w](https://en.wikipedia.org/wiki/Resampling_(statistics)) ] Resampling
# * [ [w](https://en.wikipedia.org/wiki/Errors_and_residuals) ] Residual
# * [ [w](https://en.wikipedia.org/wiki/Residual_sum_of_squares) ] Residual Sum of Squares
# * [ [w](https://en.wikipedia.org/wiki/Robust_measures_of_scale) ] Robust Measure of Scale
# * [ [w](https://en.wikipedia.org/wiki/Robust_statistics) ] Robust Statistics
# * [ [w](https://en.wikipedia.org/wiki/Sample_(statistics)) ] Sample
# * [ [w](https://en.wikipedia.org/wiki/Sampling_(statistics)) ] Sample
# * [ [w](https://en.wikipedia.org/wiki/Sample_mean_and_covariance) ] Sample Covariance
# * [ [w](https://en.wikipedia.org/wiki/Sample_maximum_and_minimum) ] Sample Maximum
# * [ [w](https://en.wikipedia.org/wiki/Sample_mean_and_covariance) ] Sample Mean
# * [ [w](https://en.wikipedia.org/wiki/Sample_maximum_and_minimum) ] Sample Minimum
# * [ [w](https://en.wikipedia.org/wiki/Sample_size_determination) ] Sample Size
# * [ [w](https://en.wikipedia.org/wiki/Sampling_(statistics)) ] Sampling
# * [ [w](https://en.wikipedia.org/wiki/Sampling_distribution) ] Sampling Distribution
# * [ [w](https://en.wikipedia.org/wiki/Scatter_plot) ] Scatter Plot
# * [ [w](https://en.wikipedia.org/wiki/Seven-number_summary) ] Seven-Number Summary
# * [ [w](https://en.wikipedia.org/wiki/Skewness) ] Skewness
# * [ [w](https://en.wikipedia.org/wiki/Spaghetti_plot) ] Spaghetti Plot
# * [ [w](https://en.wikipedia.org/wiki/Statistical_dispersion) ] Spread
# * [ [w](https://en.wikipedia.org/wiki/Squared_deviations_from_the_mean) ] Squared Deviation from the Mean (SDM)
# * [ [w](https://en.wikipedia.org/wiki/Standard_deviation) ] Standard Deviation
# * [ [w](https://en.wikipedia.org/wiki/Standard_error) ] Standard Error
# * [ [w](https://en.wikipedia.org/wiki/Standardized_moment) ] Standardized Moment
# * [ [w](https://en.wikipedia.org/wiki/Stationary_process) ] Stationary Process
# * [ [w](https://en.wikipedia.org/wiki/Statistic) ] Statistic
# * [ [w](https://en.wikipedia.org/wiki/Statistical_assumption) ] Statistical Assumptions
# * [ [w](https://en.wikipedia.org/wiki/Statistical_data_type) ] Statistical Data Type
# * [ [w](https://en.wikipedia.org/wiki/Statistical_graphics) ] Statistical Graphics
# * [ [w](https://en.wikipedia.org/wiki/Statistical_inference) ] Statistical Inference
# * [ [w](https://en.wikipedia.org/wiki/Statistical_learning_theory) ] Statistical Learning
# * [ [w](https://en.wikipedia.org/wiki/Statistical_model) ] Statistical Model
# * [ [w](https://en.wikipedia.org/wiki/Statistical_significance) ] Statistical Significance
# * [ [w](https://en.wikipedia.org/wiki/Statistical_theory) ] Statistical Theory
# * [ [w](https://en.wikipedia.org/wiki/Statistics) ] Statistics
# * [ [w](https://en.wikipedia.org/wiki/Stem-and-leaf_display) ] Stem and Leaf Plot
# * [ [w](https://en.wikipedia.org/wiki/Stochastic) ] Stochastic
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_calculus) ] Stochastic Calculus
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_cellular_automaton) ] Stochastic Cellular Automaton
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_differential_equation) ] Stochastic Differential Equation
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_differential_equation) ] Stochastic Differential Equation (SDE)
# * [ [w](https://en.wikipedia.org/wiki/Stochastic_process) ] Stochastic Process
# * [ [w](https://en.wikipedia.org/wiki/Stochastic) ] Stochasticity
# * [ [w](https://en.wikipedia.org/wiki/Summary_statistics) ] Summary Statistics
# * [ [w](https://en.wikipedia.org/wiki/Survey_methodology) ] Survey
# * [ [w](https://en.wikipedia.org/wiki/Survival_analysis) ] Survival Analysis
# * [ [w](https://en.wikipedia.org/wiki/Test_statistic) ] Test Statistic
# * [ w ] Tidy Data
# * [ [w](https://en.wikipedia.org/wiki/Truncated_mean) ] Trimmed Mean
# * [ [w](https://en.wikipedia.org/wiki/One-_and_two-tailed_tests) ] Two-Tailed Test
# * [ [w](https://en.wikipedia.org/wiki/Unbiased_estimation_of_standard_deviation) ] Unbiased Estimation of Standard Deviation
# * [ [w](https://en.wikipedia.org/wiki/Unbiased_estimation_of_standard_deviation) ] Unbiased estimation of the standard deviation
# * [ [w](https://en.wikipedia.org/wiki/Uncertainty) ] Uncertainty
# * [ [w](https://en.wikipedia.org/wiki/Unit_of_observation) ] Unit of Observation
# * [ [w](https://en.wikipedia.org/wiki/Statistical_dispersion) ] Variability
# * [ [w](https://en.wikipedia.org/wiki/Variance) ] Variance
# * [ [w](https://en.wikipedia.org/wiki/White_noise) ] White Noise
# * [ [w](https://en.wikipedia.org/wiki/Wiener_process) ] Wiener Process

# %% [markdown]
# ---
# ---
# ---
