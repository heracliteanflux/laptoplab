# %% [markdown]
# # 2.25 Shop online

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# account                    zhàng hào          账号
# bag                        bāo                包💼
# credit card                xìn   yòng  kǎ     信用卡💳
# discount                   zhé                折
# furniture                  jiā   jù           家具🪑
# hundred                    bǎi                百
# internet / the web         wǎng               网🕸️
# number                     hào                号
# order                      dìng  dān          订单
# room number                fáng  jiān  hào    房间号
# service                    fú    wù           服务
# sneakers                   yùn   dòng  xié    运动鞋👟
# watch                      shǒu  biǎo         手表⌚️
# web site                   wǎng  zhàn         网站
# Yuan ¥                     kuài               块
#
# excellent                  tài   hǎo   le     太好了🥹
# fashionable                shí   shàng        时尚
# not bad / (pretty) good    bú    cuò          不错😌
# satisfied/happy (with)     mǎn   yì           满意👍
# slow                       màn                慢
#
# altogether / in total      yí    gòng         一共
#
# to be (100-Xx10)% off/discounted    dǎ  X    zhé      打X折
# how much (is/are)?                  duō shǎo qián?    多少钱？
#
# to return (something) tuì 退    (versus 还 huán???)
#
# 910 jiǔbǎi yīshí 九百一十
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```txt
# 蓝色很时尚。(lánsè hěn shíshàng) Blue is fashionable.
# 那个包比较好看吗？(nàge bāo bǐjiào hǎokàn ma?) Is that bag relatively good-looking?
# 那个包四百四十块。(nàge bāo sìbǎisìshí kuài) That bag is ¥440.
# 那个网站只卖沙发。(nàge wǎngzhàn zhǐ mài shāfā) That web site only sells sofas.
# 那件衣服四百块吗？(nàjiàn yīfu sìbǎi kuài ma?) Is that piece of clothing four hundred yuan?
# 那条领带五百一十块。(nàtiáo lǐngdài wǔbǎiyīshí kuài) That tie is ¥510.
# 那些书一共七十三块。(nàxiē shū yígòng qīshísān kuài) Altogether those books cost ¥73.
# 那张桌子怎么样？(nàzhāng zhuōzi zěnmeyàng?) How about that table?
# 你不需要新手表。(nǐ bù xūyào xīn shǒubiǎo) You don't need a new watch.
# 你穿哪种袜子？(nǐ chuān nǎzhǒng wàzi?) Which kind of sock do you wear?
# 你满意吗？(nǐ mǎnyì ma?) Are you satisfied?
# 你喜欢穿什么鞋？(nǐ xǐhuan chuān shénme xié?) What shoes do you like to wear?
# 你需要一个新账号。(nǐ xūyào yígè xīn zhànghào) You need a new account.
# 你有三个订单对不对？(nǐ yǒu sànge dìngdān duìbúduì?) You have three orders, right?
# 你有账号吗？(nǐ yǒu zhànghào ma?) Do you have an account?
# 你们的服务太好了。(nǐmen de fúwù tàihǎole) Your service is excellent.
# 四百块。(sìbǎi kuài) Four hundred yuan.
# 网太慢了。(wǎng tài màn le) The internet is too slow.
# 我不满意。(wǒ bù mǎnyì) I'm not satisfied.
# 我不需要你的信用卡号。(wǒ bù xūyào nǐ de xìnyòngkǎ hào) I don't need your credit card number.
# 我的电脑很慢。(wǒ de diànnǎo hěn màn) My computer is slow.
# 我的网不好。(wǒ de wǎng bù hǎo) My internet isn't good.
# 我可以借你的账号吗？(wǒ kěyǐ jiè nǐ de zhànghào ma?) Can I borrow your account?
# 我可以用信用卡吗？(wǒ kěyǐ yòng xìnyòngkǎ ma?) Can I use a credit card?
# 我忘了我的信用卡号。(wǒ wàngle wǒ de xìnyòngkǎ hào) I forgot my credit card number.
# 我想退这本书。(wǒ xiǎng tuì zhèběn shū) I want to return this book.
# 我有很多家具。(wǒ yǒu hěnduō jiājù) I have a lot of furniture.
# 五个订单。(wǔge dìngdān) Five orders.
# 一双运动鞋。(yìshuāng yùndòngxié) A pair of sneakers.
# 这个包打五折。(zhège bāo dǎ wǔ zhé) This bag is 50% off.
# 这个包七百块。(zhège bāo qībǎi kuài) This bag is seven hundred yuan.
# 这个红色的沙发怎么样？(zhège hóngsè de shāfā zěnmeyàng?) How about this red sofa?
# 这个蓝色的包贵吗？(zhège lánsè de bāo guì ma?) Is this blue bag expensive?
# 这个台灯怎么样？(zhège táidēng zěnmeyàng?) How about this lamp?
# 这个游戏八十八块。(zhège yóuxì bāshíbā kuài) This game is ¥88.
# 这是我的订单号。(zhè shì wǒ de dìngdān hào) This is my order number.
# 这双鞋多少钱？(zhèshuāng xié duōshǎoqián?) How much are these shoes?
# 这双鞋挺好的，我很满意。(zhèshuāng xié tǐng hǎode, wǒ hěn mǎnyì) This pair of shoes is pretty good, I'm satisfied.
# 这双运动鞋很贵。(zhèshuāng yùndòngxié hěn guì) This pair of sneakers is expensive.
# 这双运动鞋怎么样？(zhèshuāng yùndòngxié zěnmeyàng?) How about this pair of sneakers?
# 这条裤子两百块。(zhètiáo kùzi liǎngbǎi kuài) These pants are two hundred yuan.
# 这条皮带五十块吗？(zhètiáo pídài wǔshí kuài ma?) Is this belt fifty yuan?
# 这些玩具二百一十块吗？(zhèxiē wánjù èrbǎiyìshí kuài ma?) Are these toys two hundred ten dollars?
# 这些衣服都打七折。(zhèxiē yīfu dōu dǎ qī zhé) All these clothes are 30% off.
# ```

# %% [markdown]
# ----
