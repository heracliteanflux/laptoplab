# %% [markdown]
# # Computatbility and Computational Complexity
# ```{contents}
# ```

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# * [ [w](https://en.wikipedia.org/wiki/Boolean_satisfiability_problem) ] Boolean Satisfiability Problem
# * [ [w](https://en.wikipedia.org/wiki/Counting_problem_(complexity)) ] Counting Problem
# * [ [w](https://en.wikipedia.org/wiki/Decision_problem) ] Decision Problem
# * [ [w](https://en.wikipedia.org/wiki/Function_problem) ] Function Problem
# * [ [w](https://en.wikipedia.org/wiki/Halting_problem) ] Halting Problem
# * [ [w](https://en.wikipedia.org/wiki/Boolean_satisfiability_problem) ] Problem, Boolean Satisfiability
# * [ [w](https://en.wikipedia.org/wiki/Counting_problem_(complexity)) ] Problem, Counting
# * [ [w](https://en.wikipedia.org/wiki/Decision_problem) ] Problem, Decision
# * [ [w](https://en.wikipedia.org/wiki/Function_problem) ] Problem, Function
# * [ [w](https://en.wikipedia.org/wiki/Halting_problem) ] Problem, Halting

# %% [markdown]
# ---
# ---
# ---
