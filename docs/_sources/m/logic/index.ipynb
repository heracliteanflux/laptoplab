# %% [markdown]
# # Logic

# %% [markdown]
# ---

# %% [markdown]
# ## Sections
# ```{tableofcontents}
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Resources

# %% [markdown]
# [ [Y](https://www.youtube.com/@LogicPhilosophy) ] David Agler. Logic and Philosophy.

# %% [markdown]
# Jan Reimann. Math 557, Mathematical Logic, Penn State, Spring 2021.
# * [ [y](https://www.youtube.com/watch?v=PMpW-8WCOZY) ] `01-31-2021`. "Math 557 - Cardinals and Alephs".
# * [ [y](https://www.youtube.com/watch?v=bcRg1RwzneA) ] `02-03-2021`. "Math 557 - Cardinal arithmetic and the Continuum Hypothesis".
# * [ [y](https://www.youtube.com/watch?v=i15h3s0DKcg) ] `02-06-2021`. "Math 557 – Cofinality".
# * [ [y](https://www.youtube.com/watch?v=2IYmywVEc9Y) ] `02-07-2021`. "Math 557 – First-order languages".
# * [ [y](https://www.youtube.com/watch?v=MakV6GWBDzo) ] `02-08-2021`. "Math 557 – Properties of terms and formulas".
# * [ [y](https://www.youtube.com/watch?v=gM8fQ4Gyu9o) ] `02-09-2021`. "Math 557 – Semantics of First-order Logic".
# * [ [y](https://www.youtube.com/watch?v=mmQKxdnyPbM) ] `02-23-2021`. "Math 557 – Validities".
# * [ [y](https://www.youtube.com/watch?v=CM94203SzDY) ] `02-23-2021`. "Math 557 – Substitution".
# * [ [y](https://www.youtube.com/watch?v=fs4ImYH0GRg) ] `02-23-2021`. "Math 557 – Logical Implication and Proof".
# * [ [y](https://www.youtube.com/watch?v=Y5s-dQRvpKw) ] `02-23-2021`. "Math 557 – Consistency and Completeness".
# * [ [y](https://www.youtube.com/watch?v=N4_iteekluI) ] `02-23-2021`. "Math 557 – The Completeness Theorem".
# * [ [y](https://www.youtube.com/watch?v=Sd-Avd1r64U) ] `02-28-2021`. "Math 557 – Henkin Theories".
# * [ [y](https://www.youtube.com/watch?v=LMDKdi3P1b0) ] `02-26-2021`. "Math 557 – Completing Theories".
# * [ [y](https://www.youtube.com/watch?v=kfK24K3ZXV4) ] `03-02-2021`. "Math 557 — Proving the Model Existence Theorem".
# * [ [y](https://www.youtube.com/watch?v=rXlQmgnoQbA) ] `03-06-2021`. "Math 557 - Elementary Equivalence".
# * [ [y](https://www.youtube.com/watch?v=O-TA5GFbrvU) ] `03-08-2021`. "Math 557 – Elementary Substructures".
# * [ [y](https://www.youtube.com/watch?v=RX3gMdvxLfE) ] `03-07-2021`. "Math 557 – The Löwenheim-Skolem Theorems".
# * [ [y](https://www.youtube.com/watch?v=62IeRf8s6AY) ] `03-13-2021`. "Math 557 – Quantifier Elimination".
# * [ [y](https://www.youtube.com/watch?v=aybUkZFozbg) ] `03-16-2021`. "Math 557 – Quantifier Elimination for Algebraically Closed Fields".
# * [ [y](https://www.youtube.com/watch?v=NTgfGqf9260) ] `03-20-2021`. "Math 557 – Turing Machines".
# * [ [y](https://www.youtube.com/watch?v=bFWAsmg3OMA) ] `03-22-2021`. "Math 557 – Enumerating Turing Machines".
# * [ [y](https://www.youtube.com/watch?v=BTqZVvLREnE) ] `03-23-2021`. "Math 557 – Unsolvable Problems".
# * [ [y](https://www.youtube.com/watch?v=XVdXFTA54oE) ] `03-28-2021`. "Math 557 – Primitive recursive functions".
# * [ [y](https://www.youtube.com/watch?v=FSNF3ysnMOs) ] `03-28-2021`. "Math 557 – The Ackermann function".
# * [ [y](https://www.youtube.com/watch?v=Tn3fuAQYedE) ] `03-31-2021`. "Math 557 – Recursive Functions".
# * [ [y](https://www.youtube.com/watch?v=0TeCvOCRzhU) ] `04-03-2021`. "Math 557 – Coding Formulas".
# * [ [y](https://www.youtube.com/watch?v=sJyU8Pekb9U) ] `04-05-2021`. "Math 557 – Deciding Theories".
# * [ [y](https://www.youtube.com/watch?v=oJPahtviyks) ] `04-11-2021`. "Math 557 – Peano Arithmetic".
# * [ [y](https://www.youtube.com/watch?v=zRQfSHdgV1o) ] `04-12-2021`. "Math 557 – Arithmetic Formulas".
# * [ [y](https://www.youtube.com/watch?v=NB-3MTJwzjQ) ] `04-13-2021`. "Math 557 – Defining Computable Functions in Arithmetic".
#
# Jan Reimann. MATH 574, Topics in Logic, Penn State, Spring 2014.
# * [ [y](https://www.youtube.com/watch?v=I4AqxEtohq8) ] `02-13-2015`. "Math 574, Introductory Lecture: three approaches to quantity of information".
# * [ [y](https://www.youtube.com/watch?v=ZjWHh1mAUsQ) ] `02-13-2015`. "Math 574, Lesson 1-1: Strings".
# * [ [y](https://www.youtube.com/watch?v=dUofthrSolQ) ] `02-13-2015`. "Math 574, Lesson 1-2: Sequence Spaces".
# * [ [y](https://www.youtube.com/watch?v=pxXdgoclgpk) ] `01-13-2014`. "Math 574, Lesson 1-3: Infinite paths through trees".
# * [ [y](https://www.youtube.com/watch?v=WKdy_OxdUbk) ] `02-13-2015`. "Math 574, Lesson 1-4: Measure Spaces".
# * [ [y](https://www.youtube.com/watch?v=7Sd3mHXv31I) ] `02-13-2015`. "Math 574, Lesson 1-5: Measures on Sequence Spaces".
# * [ [y](https://www.youtube.com/watch?v=UJikr32PLk4) ] `02-13-2015`. "Math 574, Lesson 1-6: Stochastic Processes".
# * [ [y](https://www.youtube.com/watch?v=ZqfLzZVhn7U) ] `02-04-2014`. "Math 574, Lesson 2-1: Finite Automata".
# * [ [y](https://www.youtube.com/watch?v=oc0kPb-Hgvk) ] `02-09-2014`. "Math 574, Lesson 2-2: Turing Machines".
# * [ [y](https://www.youtube.com/watch?v=3y1KgxdTIMI) ] `02-13-2015`. "Math 574, Lesson 2-3: Turing machines - an example".
# * [ [y](https://www.youtube.com/watch?v=qvCXYqjbPD4) ] `02-13-2015`. "Math 574, Lesson 2-4: Computable Functions".
# * [ [y](https://www.youtube.com/watch?v=47KpZvA39dA) ] `02-13-2015`. "Math 574. Lesson 2-5: The Halting Problem".
# * [ [y](https://www.youtube.com/watch?v=cCvB2MDdNBg) ] `02-13-2015`. "Math 574, Lesson 2-6: Undecidability of the Halting Problem".
# * [ [y](https://www.youtube.com/watch?v=erTYybQ5cSM) ] `02-13-2015`. "Math 574, Lesson 3-1: Subshifts".
# * [ [y](https://www.youtube.com/watch?v=cnNIVLerMeo) ] `02-13-2015`. "Math 574, Lesson 3-2: Measurable Dynamics".
# * [ [y](https://www.youtube.com/watch?v=MUGl040EVxY) ] `02-13-2015`. "Math 574, Lesson 3-3: Markov Shifts".
# * [ [y](https://www.youtube.com/watch?v=SHQcQ5Kd1kA) ] `02-13-2015`. "Math 574, Lesson 3-3: Markov Shifts".
# * [ [y](https://www.youtube.com/watch?v=P2FC-kYY-P4) ] `02-13-2015`. "Math 574, Lesson 3-4: Markov Chains".
# * [ [y](https://www.youtube.com/watch?v=B0JI593utaM) ] `02-13-2015`. "Math 574, Lesson 3-5: Ergodicity".
# * [ [y](https://www.youtube.com/watch?v=9LpAX0wBT5Q) ] `02-13-2015`. "Math 574, Lesson 3-6: The Ergodic Theorem".
# * [ [y](https://www.youtube.com/watch?v=QYA_4_drfm0) ] `02-13-2015`. "Math 574, Lesson 4-1: Information Measures".
# * [ [y](https://www.youtube.com/watch?v=96zUS8PzMvo) ] `02-13-2015`. "Math 574, Lesson 4-2: The Definition of Entropy".
# * [ [y](https://www.youtube.com/watch?v=S31CbvpZBU4) ] `02-13-2015`. "Math 574, Lesson 4-3: Kolmogorov Complexity".
# * [ [y](https://www.youtube.com/watch?v=oUpBtlKwBf0) ] `02-13-2015`. "Math 574, Lesson 4-4: Prefix-free Complexity".
# * [ [y](https://www.youtube.com/watch?v=fc5FyE41zeo) ] `02-13-2015`. "Math 574, Lesson 4-5: Mutual Information".
# * [ [y](https://www.youtube.com/watch?v=AeZdZbxMqI4) ] `02-13-2015`. "Math 574, Lesson 5-1: Optimal Codes".

# %% [markdown]
# more
# * [ [y](https://www.youtube.com/watch?v=skqB7AbR1G0) ] `01-13-2024`. UCLA Automated Reasoning Group. "Beyond Truth & Falsehood: Logic as a Calculus of Events".

# %% [markdown]
# ---

# %% [markdown]
# ## Texts

# %% [markdown]
# * [ [h](http://www.davidagler.com/) ][ [y](https://www.youtube.com/@LogicPhilosophy) ] Agler, David w. (2012). _Symbolic Logic: Syntax, Semantics, and Proof_. Rowman and Littlefield.
# * Andrews, Peter B. (2002). _An Introduction to Mathematical Logic and Type Theory: To Truth Through Proof_. Springer: Applied Logic Series.
# * Ayala-Rincón, Mauricio & Flávio L. C. de Moura. (2017). _Applied Logic for Computer Scientists: Computational Deduction and Formal Proofs_. Springer: Undergraduate Topics in Computer Science.
# * Ayer, Alfred J. (1952). _Language, Turth, and Logic_. Dover.
# * Boolos, George s.; John H. Burgess; & Richard C. Jeffrey. (2007). _Computability and Logic_. 5th Ed. Cambridge University Press.
# * Burgess, John P. (2012). _Philosophical Logic_. Princeton University Press.
# * Carroll, Lewis. (1958). _Symbolic Logic and the Game of Logic_. Dover.
# * Cellucci, Carlo. (2016). _Rethinking Logic: Logic in Relation to Mathematics, Evolution, and Method_. Springer.
# * Csirmaz, Laszlo & Zalán Gyenis. (2022). _Mathematical Logic: Exercises and Solutions_. Springer: Problem Books in Mathematics.
# * Dau, Frithjof. (2003). _The Logic System of Concept Graphs with Negation: And Its Relationship to Predicate Logic_. Springer: Lecture Notes in Computer Science.
# * De Swart, Harrie. (2018). _Philosophical and Mathematical Logic_. Springer Undergraduate Texts in Philosophy.
# * Enderton, Herbert B. (2001). _A Mathematical Introduction to Logic_. 2nd Ed. Academic Press.
# * Freund, Max A. (2019). _The Logic of Sortals: A Conceptualist Approach_. Springer: Synthese Library.
# * Gamut, L. T. F. (2020). _Logic, Language, and Meaning, Vol. I: Introduction to Logic_. University of Chicago Press.
# * Gamut, L. T. F. (2020). _Logic, Language, and Meaning, Vol. II: Intensional Logic and Logical Grammar_. University of Chicago Press.
# * Haack. Susan. (1978). _Philosophy of Logics_. Cambridge University Press.
# * Harrison, John. (2009). _Handbook of Practical Logic and Automated Reasoning_. Cambridge University Press.
# * Hitzler, Pascal & Anthony Seda. (2016). _Mathematical Aspects of Logic Programming Semantics_. CRC Press.
# * Iacona, Andrea. _LOGIC: Lecture Notes for Philosophy, Mathematics, and Computer Science_. Springer Undergraduate Texts in Philosophy.
# * Jongsma, Calvin. (2019). _Introduction to Discrete Mathematics via Logic and Proof_. Springer Undergraduate Texts in Mathematics.
# * Kac, Mark & Stanislaw M. Ulam. (1992). _Mathematics and Logic_. Dover.
# * Kripke, Saul. (1981). _Naming and Necessity_. Wiley-Blackwell.
# * [ [b](https://milneopentextbooks.org/a-friendly-introduction-to-mathematical-logic/) ] Leary, Christopher & Lars Kristiansen. (2015). _A Friendly Introduction to Mathematical Logic_. Milne Library.
# * Mates, Benson. _Stoic Logic_.
# * Mendelson, Elliot. (2015). _Introduction to Mathematical Logic_. CRC Press..
# * Milanic, Martin; Brigitte Servatius; & Herman Servatius. (2023). _Discrete Mathematics with Logic_. Acadmeic Press.
# * Nerode, Anil & Richard A. Shore. (1997). _Logic for Applications_. 2nd Ed. Springer: Graduate Texts in Computer Science.
# * Novaes, Catarina Dutilh. (2012). _Formal Languages in Logic: A Philosophical and Congitive Analysis_. Cambridge University Press.
# * Parry, William T. & Edward A. Hacker. (1991). _Aristotelian Logic_. SUNY Press.
# * Peregrin, Jaroslav. (2021). _Philosophy of Logical Systems_. Routledge Studies in Contemporary Philosophy.
# * Quine, Willard Van Orman. (1986). _Philosophy of Logic_. 2nd Ed. Harvard University Press.
# * Rini, Adriane. (2011). _Aristotle's Modal Proofs: Prior Analytics A8-22 in Predicate Logic_. Springer: The New Synthese Historical Library.
# * Sider, Theodore. (2010). _Logic for Philosophy_. Oxford University Press.
# * Soames, Scott. (2012). _Philosophy of Language_. Princeton University Press.
# * Stillwell, John. (2022). _The Story of Proof: Logic and the History of Mathematics_. Princeton University Press.
# * Suppes, Patrick & Shirley Hill. (2010). _First Course in Mathematical Logic_. Dover.
# * Vingron, Shimon Peter. (2004). _Switching Theory: Insight through Predicate Logic_. Springer.
# * Wasilewska, Anita. (2018). _Logics for Computer Science: Classical and Non-Classical_. Springer.

# %% [markdown]
# ---

# %% [markdown]
# ## Figures

# %% [markdown]
# * [ w ] Aristotle
# 	* [ [s](https://plato.stanford.edu/entries/aristotle-logic/) ] Aristotle's Logic
# 	* [ [s](https://plato.stanford.edu/entries/aristotle-noncontradiction/) ] Aristotle on Non Contradiction
# * [ w ][ [s](https://plato.stanford.edu/entries/boole/) ] Boole, George (1815-1864)
# * [ [w](https://en.wikipedia.org/wiki/Georg_Cantor) ] Cantor, Georg (1845-1918)
# 	* [ [w](https://en.wikipedia.org/wiki/Cantor%27s_first_set_theory_article) ] Cantor's First Set Theory Article
# * [ [w](https://en.wikipedia.org/wiki/Chrysippus) ] Chrysippus of Soli
# * [ [w](https://en.wikipedia.org/wiki/Haskell_Curry) ] Curry, Haskell (1900-1982)
# * [ w ] De Morgan, Augustus
# * [ [w](https://en.wikipedia.org/wiki/Ferdinand_de_Saussure) ] De Saussure, Ferdinand (1857-1913)
# * [ [w](https://en.wikipedia.org/wiki/Richard_Dedekind) ] Dedekind, Richard
# * [ [w](https://en.wikipedia.org/wiki/Michael_Dummett) ] Dummett, Michael
# * [ [w](https://en.wikipedia.org/wiki/Abraham_Fraenkel) ] Fraenkel, Abraham (1891-1965)
# * [ [w](https://en.wikipedia.org/wiki/Gottlob_Frege) ][ [s](https://plato.stanford.edu/entries/frege/) ] Frege, Gottlob (1848-1925)
# 	* [ [s](https://plato.stanford.edu/entries/frege-logic/) ] Frege's Logic
# 	* [ [s](https://plato.stanford.edu/entries/frege-theorem/) ] Frege's Theorem and Foundations for Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Gerhard_Gentzen) ] Gentzen, Gerhard (1909-1945)
# * [ w ][ [s](https://plato.stanford.edu/entries/goedel/) ] Gödel, Kurt
# * [ [w](https://en.wikipedia.org/wiki/Jaakko_Hintikka) ] Hintikka, Jaakko
# * [ [w](https://en.wikipedia.org/wiki/G%C3%A9rard_Huet) ] Huet, Gérard (1947-)
# * [ [w](https://en.wikipedia.org/wiki/Saul_Kripke) ] Kripke, Saul
# * [ w ] Leibniz
# 	* [ [s](https://plato.stanford.edu/entries/leibniz-logic-influence/) ] Leibniz' Influence on 19th Century Logic
# * [ w ][ [s](https://plato.stanford.edu/entries/lesniewski/) ] Leśniewski, Stanisław (1886-1939)
# * [ [w](https://en.wikipedia.org/wiki/C._I._Lewis) ][ [s](https://plato.stanford.edu/entries/lewis-ci/) ] Lewis, Clarence Irving (1883-1964)
# * [ [w](https://en.wikipedia.org/wiki/Jan_%C5%81ukasiewicz) ] Lukasiewicz, Jan (1878-1956)
# * [ [w](https://en.wikipedia.org/wiki/Ruth_Barcan_Marcus) ] Marcus, Ruth (1921-2012)
# * [ [w](https://en.wikipedia.org/wiki/Richard_Montague) ] Montague, Richard (1930-1971)
# * [ w ] Peano, Giuseppe
# 	* [ [w](https://en.wikipedia.org/wiki/Arithmetices_principia,_nova_methodo_exposita) ] (1889). _Arithmetices principia, nova methodo exposita_.
# * [ w ] Peirce, Charles Sanders
# * [ [w](https://en.wikipedia.org/wiki/Charles_Sanders_Peirce) ][ [s](https://plato.stanford.edu/entries/peirce/) ] Peirce, Charles Sanders
# * [ [w](https://en.wikipedia.org/wiki/Emil_Leon_Post) ] Post, Emil (1897-1954)
# * [ [w](https://en.wikipedia.org/wiki/Arthur_Prior) ] Prior, Arthur
# * [ [w](https://en.wikipedia.org/wiki/Bertrand_Russell) ] Russell, Bertrand
# 	* [ [w](https://en.wikipedia.org/wiki/On_Denoting) ] (1905). "On Denoting".
# * [ [w](https://en.wikipedia.org/wiki/Moses_Schönfinkel) ] Schonfinkel, Moses
# * [ [w](https://en.wikipedia.org/wiki/Henry_M._Sheffer) ] Sheffer, Henry (1882-1964)
# * [ w ][ [s](https://plato.stanford.edu/entries/tarski/) ] Tarski, Alfred (1901-1983)
# 	* [ [s](https://plato.stanford.edu/entries/tarski-truth/) ] Tarski's Truth Definitions
# * [ [w](https://en.wikipedia.org/wiki/John_Venn) ] Venn, John (1834-1923)
# * [ [w](https://en.wikipedia.org/wiki/Ludwig_Wittgenstein) ] Wittgenstein, Ludwig
# * [ [w](https://en.wikipedia.org/wiki/Ernst_Zermelo) ] Zermelo, Ernst (1871-1953)
# 	* [ [s](https://plato.stanford.edu/entries/zermelo-set-theory/) ] Zermelo's Axiomatization of Set Theory

# %% [markdown]
# ---

# %% [markdown]
# ## Terms

# %% [markdown]
# ### Formal Logic
#
# * [ [w](https://en.wikipedia.org/wiki/Abductive_reasoning) ] Abduction
# * [ [w](https://en.wikipedia.org/wiki/Material_nonimplication) ] Abjunction
# * [ [w](https://en.wikipedia.org/wiki/Abstract_rewriting_system) ] Abstract Rewriting System
# * [ [w](https://en.wikipedia.org/wiki/M%C3%BCnchhausen_trilemma) ] Aggrippan Trilemma
# * [ w ][ [s](https://plato.stanford.edu/entries/algebra/) ] Algebra
# * [ w ][ [s](https://plato.stanford.edu/entries/algebra-logic-tradition/) ] Algebra of Logic
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-algebraic-propositional/) ] Algebraic Propositional Logic
# * [ [w](https://en.wikipedia.org/wiki/Alphabet_(formal_languages)) ] Alphabet
# * [ [w](https://en.wikipedia.org/wiki/Ampliative) ] Ampliativity
# * [ w ][ [s](https://plato.stanford.edu/entries/analytic-synthetic/) ] Analysis
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-ancient/) ] Ancient Logic
# * [ [w](https://en.wikipedia.org/wiki/Antecedent_(logic)) ] Antecedent
# * [ [w](https://en.wikipedia.org/wiki/Argument) ] Argument
# * [ [w](https://en.wikipedia.org/wiki/Argumentation_theory) ] Argumentation Theory
# * [ [w](https://en.wikipedia.org/wiki/Term_logic) ] Aristotelian Logic
# * [ [w](https://en.wikipedia.org/wiki/Arity) ] Arity
# * [ [w](https://en.wikipedia.org/wiki/Atomic_formula) ] Atomic Formula
# * [ [w](https://en.wikipedia.org/wiki/Atomic_sentence) ] Atomic Sentence
# * [ [w](https://en.wikipedia.org/wiki/Axiom) ] Axiom
# * [ [w](https://en.wikipedia.org/wiki/Axiom_schema) ] Axiom Schema
# * [ [w](https://en.wikipedia.org/wiki/Barcan_formula) ] Barcan Formula
# * [ w ] Biconditional
# * [ [w](https://en.wikipedia.org/wiki/Boolean_algebra) ] Boolean Algebra
#    * [ [s](https://plato.stanford.edu/entries/boolalg-math/) ] Boolean Algebra, Mathematics
# * [ [w](https://en.wikipedia.org/wiki/Boolean_algebra_(structure)) ] Boolean Algebra Structure
# * [ [w](https://en.wikipedia.org/wiki/Boolean_function) ] Boolean Function
# * [ [w](https://en.wikipedia.org/wiki/Buridan_formula) ] Buridan Formula
# * [ [w](https://en.wikipedia.org/wiki/Canonical_normal_form) ] Canonical Normal Form
# * [ [w](https://en.wikipedia.org/wiki/Cardinality) ] Cardinality
# * [ [w](https://en.wikipedia.org/wiki/Categorical_proposition) ] Categorical Proposition
# * [ w ][ [s](https://plato.stanford.edu/entries/category-theory/) ] Category Theory
# * [ [w](https://en.wikipedia.org/wiki/Classical_logic) ][ [s](https://plato.stanford.edu/entries/logic-classical/) ] Classical Logic
# * [ [w](https://en.wikipedia.org/wiki/Combinational_logic) ] Combinational Logic
# * [ [w](https://en.wikipedia.org/wiki/Combinatory_logic) ][ [s](https://plato.stanford.edu/entries/logic-combinatory/) ] Combinatory Logic
# * [ [w](https://en.wikipedia.org/wiki/Compactness_theorem) ] Compactness Theorem
# * [ [w](https://en.wikipedia.org/wiki/Completeness_(logic)) ] Completeness
# * [ w ] Compound Proposition
# * [ [w](https://en.wikipedia.org/wiki/Comprehension_(logic)) ] Comprehension
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-conditionals/) ] Conditional
# * [ [w](https://en.wikipedia.org/wiki/Confluence_(abstract_rewriting)) ] Confluence
# * [ [w](https://en.wikipedia.org/wiki/Logical_conjunction) ] Conjunction
# * [ [w](https://en.wikipedia.org/wiki/Conjunctive_normal_form) ] Conjunctive Normal Form
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-connexive/) ] Connexive Logic
# * [ [w](https://en.wikipedia.org/wiki/Connotation) ] Connotation
# * [ [w](https://en.wikipedia.org/wiki/Consequent) ] Consequent
# * [ [w](https://en.wikipedia.org/wiki/Consistency) ] Consistency
# * [ [w](https://en.wikipedia.org/wiki/Logical_constant) ] Constant Symbol
# * [ [w](https://en.wikipedia.org/wiki/Constructive_dilemma) ] Constructive Dilemma
# * [ [w](https://en.wikipedia.org/wiki/Contingency_(philosophy)) ] Contingency
# * [ [w](https://en.wikipedia.org/wiki/Contradiction) ][ [s](https://plato.stanford.edu/entries/contradiction/) ] Contradiction
# * [ [w](https://en.wikipedia.org/wiki/Contraposition) ] Contraposition
# * [ [w](https://en.wikipedia.org/wiki/Converse_(logic)) ] Converse Conditional/Implication
# * [ [w](https://en.wikipedia.org/wiki/Converse_nonimplication) ] Converse Nonimplication
# * [ w ][ [s](https://plato.stanford.edu/entries/counterfactuals/) ] Counterfactual
# * [ [w](https://en.wikipedia.org/wiki/Criteria_of_truth) ] Criteria of Truth
# * [ [w](https://en.wikipedia.org/wiki/Critical_thinking) ] Critical Thinking
# * [ [w](https://en.wikipedia.org/wiki/De_dicto_and_de_re) ] De Dicto
# * [ [w](https://en.wikipedia.org/wiki/De_Morgan%27s_laws) ] De Morgan's Laws
# * [ [w](https://en.wikipedia.org/wiki/De_dicto_and_de_re) ] De Re
# * [ [w](https://en.wikipedia.org/wiki/Deductive_reasoning) ] Deductive Reasoning
# * [ [w](https://en.wikipedia.org/wiki/Defeasible_reasoning) ] Defeasible Reasoning
# * [ w ][ [s](https://plato.stanford.edu/entries/definitions/) ] Definition
# * [ [w](https://en.wikipedia.org/wiki/Denotation) ] Denotation
# * [ [w](https://en.wikipedia.org/wiki/Deontic_logic) ] Deontic Logic
# * [ [w](https://en.wikipedia.org/wiki/Destructive_dilemma) ] Destructive Dilemma
# * [ [w](https://en.wikipedia.org/wiki/Diagonal_lemma) ] Diagonal Lemma
# * [ [w](https://en.wikipedia.org/wiki/Logical_disjunction) ] Disjunction
# * [ [w](https://en.wikipedia.org/wiki/Disjunctive_normal_form) ] Disjunctive Normal Form
# * [ [w](https://en.wikipedia.org/wiki/Disjunctive_syllogism) ] Disjunctive Syllogism
# * [ [w](https://en.wikipedia.org/wiki/Domain_of_discourse) ] Domain of Discourse
# * [ [w](https://en.wikipedia.org/wiki/Enthymeme) ] Enthymeme ἐνθύμημα
# * [ [w](https://en.wikipedia.org/wiki/Enumeration) ] Enumeration
# * [ [w](https://en.wikipedia.org/wiki/Equivocation) ] Equivocation
# * [ w ] Exclusive Disjunction
# * [ [w](https://en.wikipedia.org/wiki/Existential_generalization) ] Existential Generalization
# * [ [w](https://en.wikipedia.org/wiki/Existential_instantiation) ] Existential Instantiation
# * [ [w](https://en.wikipedia.org/wiki/Existential_quantification) ] Existential Quantification
# * [ [w](https://en.wikipedia.org/wiki/Explicit_substitution) ] Explicit Substitution
# * [ [w](https://en.wikipedia.org/wiki/Extension_(predicate_logic)) ] Extension, Predicate Logic
# * [ [w](https://en.wikipedia.org/wiki/Extension_(semantics)) ] Extension, Semantics
# * [ [w](https://en.wikipedia.org/wiki/Extensionality) ] Extensionality
# * [ [w](https://en.wikipedia.org/wiki/Fallacy) ] Fallacy
# * [ [w](https://en.wikipedia.org/wiki/False_(logic)) ] Falsity
# * [ [w](https://en.wikipedia.org/wiki/Up_tack) ] Falsum
# * [ [w](https://en.wikipedia.org/wiki/Finitary) ] Finitarity
# * [ [w](https://en.wikipedia.org/wiki/First-order_logic) ] First-Order Logic
# * [ [w](https://en.wikipedia.org/wiki/Formal_language) ] Formal Language
# * [ [w](https://en.wikipedia.org/wiki/Formal_proof) ] Formal Proof
# * [ [w](https://en.wikipedia.org/wiki/Semantics_of_logic) ] Formal Semantics
# * [ [w](https://en.wikipedia.org/wiki/Formal_system) ] Formal System
# * [ [w](https://en.wikipedia.org/wiki/Formalism_(philosophy_of_mathematics)) ] Formalism
# * [ [w](https://en.wikipedia.org/wiki/Formation_rule) ] Formation Rule
# * [ [w](https://en.wikipedia.org/wiki/Sentence_(mathematical_logic)) ] Formula, Closed
# * [ [w](https://en.wikipedia.org/wiki/Well-formed_formula) ] Formula
# * [ [w](https://en.wikipedia.org/wiki/Open_formula) ] Formula, Open
# * [ [w](https://en.wikipedia.org/wiki/Free_object) ] Free Object
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_compositionality) ] Frege's Principle
# * [ [w](https://en.wikipedia.org/wiki/Uninterpreted_function) ] Function Symbol
# * [ [w](https://en.wikipedia.org/wiki/Functional_completeness) ] Functional Completeness
# * [ [w](https://en.wikipedia.org/wiki/Functional_predicate) ] Functional Predicate
# * [ w ][ [s](https://plato.stanford.edu/entries/future-contingents/) ] Future Contingent
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-fuzzy/) ] Fuzzy Logic
# * [ w ][ [s](https://plato.stanford.edu/entries/generalized-quantifiers/) ] Generalized Quantifier
# * [ [w](https://en.wikipedia.org/wiki/G%C3%B6del%27s_completeness_theorem) ] Gödel's Completeness Theorems
# * [ [w](https://en.wikipedia.org/wiki/G%C3%B6del%27s_incompleteness_theorems) ] Gödel's Incompleteness Theorems
# * [ [w](https://en.wikipedia.org/wiki/Ground_expression) ] Ground Expression
# * [ [w](https://en.wikipedia.org/wiki/Herbrand_structure) ] Herbrand Structure
# * [ [w](https://en.wikipedia.org/wiki/Heuristic) ] Heuristic
# * [ [w](https://en.wikipedia.org/wiki/Higher-order_logic) ] Higher-Order Logic
# * [ [w](https://en.wikipedia.org/wiki/History_of_logic) ] History of Logic
# * [ [w](https://en.wikipedia.org/wiki/Hypothetical_syllogism) ] Hypothetical Syllogism
# * [ w ][ [s](https://plato.stanford.edu/entries/identity-indiscernible/) ] Identity of Indiscernibles
# * [ [w](https://en.wikipedia.org/wiki/If_and_only_if) ] If and only if
# * [ w ] Implication
# * [ [w](https://en.wikipedia.org/wiki/Inclusion_(Boolean_algebra)) ] Inclusion
# * [ [w](https://en.wikipedia.org/wiki/Logical_disjunction) ] Inclusive Disjunction
# * [ [w](https://en.wikipedia.org/wiki/Indian_logic) ] Indian Logic
# * [ [w](https://en.wikipedia.org/wiki/Inductive_reasoning) ] Induction
# * [ [w](https://en.wikipedia.org/wiki/Inference) ] Inference
# * [ [w](https://en.wikipedia.org/wiki/Finitary) ] Infinitarity
# * [ [w](https://en.wikipedia.org/wiki/Infinite_regress) ] Infinite Regress
# * [ [w](https://en.wikipedia.org/wiki/Infix_notation) ] Infix Notation
# * [ [w](https://en.wikipedia.org/wiki/Informal_logic) ] Informal Logic
# * [ [w](https://en.wikipedia.org/wiki/Intension) ] Intension
# * [ [w](https://en.wikipedia.org/wiki/Intensional_logic) ] Intensional Logic
# * [ [w](https://en.wikipedia.org/wiki/Interpretation_(logic)) ] Interpretation, Logical
# * [ [w](https://en.wikipedia.org/wiki/Interpretation_(model_theory)) ] Interpretation, Model-Theoretic
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-intuitionistic/) ] Intuitionistic Logic
#   * [ [s](https://plato.stanford.edu/entries/intuitionistic-logic-development/) ] The Development of Intuitionistic Logic
# * [ [w](https://en.wikipedia.org/wiki/Inverse_(logic)) ] Inverse
# * [ [w](https://en.wikipedia.org/wiki/Logic_in_Islamic_philosophy) ] Islamic Logic
# * [ [w](https://en.wikipedia.org/wiki/Justification_(epistemology)) ] Justification
# * [ [w](https://en.wikipedia.org/wiki/Definitions_of_knowledge) ] Knowledge, definitions
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_bivalence) ] Law of Bivalence
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_explosion) ] Law of Explosion
# * [ [w](https://en.wikipedia.org/wiki/Law_of_excluded_middle) ] Law of Excluded Middle
# * [ [w](https://en.wikipedia.org/wiki/Law_of_identity) ] Law of Identity
# * [ [w](https://en.wikipedia.org/wiki/Law_of_noncontradiction) ] Law of Non Contradiction
# * [ [w](https://en.wikipedia.org/wiki/Law_of_thought) ] Law of Thought
# * [ w ][ [s](https://plato.stanford.edu/entries/liar-paradox/) ] Liar Paradox
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-linear/) ] Linear Logic
# * [ [w](https://en.wikipedia.org/wiki/Logic) ] Logic
#   * [ w ][ [s](https://plato.stanford.edu/entries/logic-games/) ] Logic and Games
#   * [ w ][ [s](https://plato.stanford.edu/entries/logic-ontology/) ] Logic and Ontology
#   * [ w ][ [s](https://plato.stanford.edu/entries/logic-belief-revision/) ] Logic of Belief Revision
# * [ [w](https://en.wikipedia.org/wiki/Logica_nova) ] Logica Nova
# * [ [w](https://en.wikipedia.org/wiki/Logical_conjunction) ] Logical AND
# * [ [w](https://en.wikipedia.org/wiki/Judgment_(mathematical_logic)) ] Logical Assertion
# * [ w ] Logical Atomism
# * [ [w](https://en.wikipedia.org/wiki/Logical_biconditional) ] Logical Biconditional
# * [ [w](https://en.wikipedia.org/wiki/Logical_connective) ] Logical Connective
# * [ [w](https://en.wikipedia.org/wiki/Logical_consequence) ][ [s](https://plato.stanford.edu/entries/logical-consequence/) ] Logical Consequence
# * [ [w](https://en.wikipedia.org/wiki/Logical_constant) ][ [s](https://plato.stanford.edu/entries/logical-constants/) ] Logical Constant
# * [ [w](https://en.wikipedia.org/wiki/Logical_equivalence) ] Logical Equivalence
# * [ [w](https://en.wikipedia.org/wiki/Formal_fallacy) ] Logical Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Logical_form) ][ [s](https://plato.stanford.edu/entries/logical-form/) ] Logical Form
# * [ [w](https://en.wikipedia.org/wiki/Interpretation_(logic)) ] Logical Interpretation
# * [ w ] Logical NAND
# * [ [w](https://en.wikipedia.org/wiki/Logical_NOR) ] Logical NOR
# * [ [w](https://en.wikipedia.org/wiki/Negation) ] Logical NOT
# * [ w ] Logical Operation
# * [ [w](https://en.wikipedia.org/wiki/Logical_disjunction) ] Logical OR
# * [ w ] Logical Positivism
# * [ [w](https://en.wikipedia.org/wiki/Structure_(mathematical_logic)) ] Logical Structure
# * [ [w](https://en.wikipedia.org/wiki/Symbol_(formal)) ] Logical Symbol
# * [ [w](https://en.wikipedia.org/wiki/Logical_truth) ][ [s](https://plato.stanford.edu/entries/logical-truth/) ] Logical Truth
# * [ w ] Logical XNOR
# * [ w ] Logical XOR
# * [ w ][ [s](https://plato.stanford.edu/entries/logicism/) ] Logicism
# * [ [w](https://en.wikipedia.org/wiki/Many-valued_logic) ][ [s](https://plato.stanford.edu/entries/logic-manyvalued/) ] Many-Valued Logic
# * [ [w](https://en.wikipedia.org/wiki/Logical_biconditional) ] Material Biconditional
# * [ [w](https://en.wikipedia.org/wiki/Material_conditional) ] Material Conditional/Implication
# * [ w ] Material Nonimplication
# * [ [w](https://en.wikipedia.org/wiki/Constant_(mathematics)) ] Mathematical Constant
# * [ [w](https://en.wikipedia.org/wiki/Expression_(mathematics)) ] Mathematical Expression
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_induction) ] Mathematical Induction
# * [ w ] Mathematical Language
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_logic) ] Mathematical Logic
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_model) ] Mathematical Model
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_structure) ] Mathematical Structure
# * [ [w](https://en.wikipedia.org/wiki/Variable_(mathematics)) ] Mathematical Variable
# * [ [w](https://en.wikipedia.org/wiki/Metalogic) ] Metalogic
# * [ [w](https://en.wikipedia.org/wiki/Metavariable) ] Metavariable
# * [ [w](https://en.wikipedia.org/wiki/Middle_term) ] Middle Term
# * [ [w](https://en.wikipedia.org/wiki/Modal_logic) ][ [s](https://plato.stanford.edu/entries/logic-modal/) ] Modal Logic
# * [ [w](https://en.wikipedia.org/wiki/Model_theory) ][ [s](https://plato.stanford.edu/entries/model-theory/) ] Model Theory
#   * [ [s](https://plato.stanford.edu/entries/modeltheory-fo/) ] First Order Model Theory
# * [ [w](https://en.wikipedia.org/wiki/Modus_ponens) ] Modus Ponens
# * [ [w](https://en.wikipedia.org/wiki/Modus_tollens) ] Modus Tollens
# * [ [w](https://en.wikipedia.org/wiki/Montague_grammar) ] Montague Grammar
# * [ w ][ [s](https://plato.stanford.edu/entries/montague-semantics/) ] Montague Semantics
# * [ [w](https://en.wikipedia.org/wiki/Natural_deduction) ] Natural Deduction
# * [ [w](https://en.wikipedia.org/wiki/Natural_number) ] Natural Number
# * [ [w](https://en.wikipedia.org/wiki/Necessity_and_sufficiency) ] Necessity
# * [ [w](https://en.wikipedia.org/wiki/Negation) ][ [s](https://plato.stanford.edu/entries/negation/) ] Negation
# * [ [w](https://en.wikipedia.org/wiki/Non-logical_symbol) ] Non Logical Symbol
# * [ [w](https://en.wikipedia.org/wiki/Normal_form_(abstract_rewriting)) ] Normal Form
# * [ [w](https://en.wikipedia.org/wiki/Operand) ] Operand
# * [ [w](https://en.wikipedia.org/wiki/Operation_(mathematics)) ] Operation
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-paraconsistent/) ] Paraconsistent Logic
# * [ [w](https://en.wikipedia.org/wiki/Paradox) ][ [s](https://plato.stanford.edu/entries/paradoxes-contemporary-logic/) ] Paradox
# * [ [w](https://en.wikipedia.org/wiki/Particular) ] Particular
# * [ [w](https://en.wikipedia.org/wiki/Philosophical_logic) ] Philosophical Logic
# * [ [w](https://en.wikipedia.org/wiki/Philosophy_of_language) ] Philosophy of Language
# * [ [w](https://en.wikipedia.org/wiki/Philosophy_of_logic) ] Philosophy of Logic
# * [ w ][ [s](https://plato.stanford.edu/entries/plural-quant/) ] Plural Quantification
# * [ [w](https://en.wikipedia.org/wiki/Polish_notation) ] Polish Notation
# * [ [w](https://en.wikipedia.org/wiki/Possible_world) ] Possible World
# * [ [w](https://en.wikipedia.org/wiki/Predicate_(mathematical_logic)) ] Predicate
# * [ [w](https://en.wikipedia.org/wiki/Predicate_(grammar)) ] Predicate, Grammatical
# * [ [w](https://en.wikipedia.org/wiki/First-order_logic) ] Predicate Logic
# * [ [w](https://en.wikipedia.org/wiki/Predicate_variable) ] Predicate Variable
# * [ [w](https://en.wikipedia.org/wiki/Predication_(philosophy)) ] Predication
# * [ [w](https://en.wikipedia.org/wiki/Premise) ] Premise
# * [ [w](https://en.wikipedia.org/wiki/Prenex_normal_form) ] Prenex Normal Form
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_compositionality) ] Principle of Compositionality
# * [ [w](https://en.wikipedia.org/wiki/Problem_of_the_criterion) ] Problem of the Criterion
# * [ [w](https://en.wikipedia.org/wiki/Problem_of_future_contingents) ] Problem of Future Contingents
# * [ [w](https://en.wikipedia.org/wiki/Problem_of_universals) ] Problem of Universals
# * [ [w](https://en.wikipedia.org/wiki/Product_term) ] Product Term
# * [ [w](https://en.wikipedia.org/wiki/Proof_calculus) ] Proof System
# * [ [w](https://en.wikipedia.org/wiki/Proof_theory) ] Proof Theory
#   * [ [s](https://plato.stanford.edu/entries/proof-theoretic-semantics/) ] Proof-Theoretic Semantics
# * [ [w](https://en.wikipedia.org/wiki/Proposition) ] Proposition
# * [ [w](https://en.wikipedia.org/wiki/Propositional_formula) ] Propositional Formula
# * [ [w](https://en.wikipedia.org/wiki/Propositional_function) ] Propositional Function
# * [ [w](https://en.wikipedia.org/wiki/Propositional_calculus) ] Propositional Logic
# * [ [w](https://en.wikipedia.org/wiki/Propositional_variable) ] Propositional Variable
# * [ [w](https://en.wikipedia.org/wiki/Quantifier_(logic)) ][ [s](https://plato.stanford.edu/entries/quantification/) ] Quantifier
# * [ [w](https://en.wikipedia.org/wiki/Reason) ] Reason
# * [ [w](https://en.wikipedia.org/wiki/Recursion) ] Recursion
# * [ [w](https://en.wikipedia.org/wiki/Recursive_definition) ] Recursive Definition
# * [ [w](https://en.wikipedia.org/wiki/Reduct) ] Reduct
# * [ [w](https://en.wikipedia.org/wiki/Reductio_ad_absurdum) ] Reductio ad absurdum
# * [ [w](https://en.wikipedia.org/wiki/Abstract_rewriting_system) ] Reduction System
# * [ w ][ [s](https://plato.stanford.edu/entries/reference/) ] Reference
# * [ [w](https://en.wikipedia.org/wiki/Regress_argument) ] Regress Argument
# * [ [w](https://en.wikipedia.org/wiki/Relations_(philosophy)) ] Relation
# * [ [w](https://en.wikipedia.org/wiki/Finitary_relation) ] Relation, Finitary
# * [ [w](https://en.wikipedia.org/wiki/Relevance) ][ [s](https://plato.stanford.edu/entries/logic-relevance/) ] Relevance
# * [ [w](https://en.wikipedia.org/wiki/Resolution_(logic)) ] Resolution
# * [ [w](https://en.wikipedia.org/wiki/Rewriting) ] Rewriting
# * [ [w](https://en.wikipedia.org/wiki/Rule_of_inference) ] Rule of Inference
# * [ w ][ [s](https://plato.stanford.edu/entries/russell-paradox/) ] Russell's Paradox
# * [ [w](https://en.wikipedia.org/wiki/Satisfiability) ] Satisfiability
# * [ [w](https://en.wikipedia.org/wiki/Scope_(logic)) ] Scope
# * [ [w](https://en.wikipedia.org/wiki/Second-order_logic) ][ [s](https://plato.stanford.edu/entries/logic-higher-order/) ] Second-Order Logic
# * [ w ][ [s](https://plato.stanford.edu/entries/self-reference/) ] Self-Reference
# * [ [w](https://en.wikipedia.org/wiki/Sentence_(mathematical_logic)) ] Sentence
# * [ [w](https://en.wikipedia.org/wiki/Sequence) ] Sequence
# * [ [w](https://en.wikipedia.org/wiki/Sequent) ] Sequent
# * [ [w](https://en.wikipedia.org/wiki/Sequent_calculus) ] Sequent Calculus
# * [ [w](https://en.wikipedia.org/wiki/Sheffer_stroke) ] Sheffer Stroke
# * [ [w](https://en.wikipedia.org/wiki/Sign_(semiotics)) ] Sign
# * [ [w](https://en.wikipedia.org/wiki/Signature_(logic)) ] Signature
# * [ w ][ [s](https://plato.stanford.edu/entries/sorites-paradox/) ] Sorites Paradox
# * [ [w](https://en.wikipedia.org/wiki/Soundness) ] Soundness
# * [ [w](https://en.wikipedia.org/wiki/Square_of_opposition) ][ [s](https://plato.stanford.edu/entries/square/) ] Square of Opposition
# * [ [w](https://en.wikipedia.org/wiki/Statement_(logic)) ] Statement
# * [ [w](https://en.wikipedia.org/wiki/Stoic_logic) ] Stoic Logic
# * [ [w](https://en.wikipedia.org/wiki/String_(computer_science)) ] String
# * [ [w](https://en.wikipedia.org/wiki/Structure_(mathematical_logic)) ] Structure
# * [ [w](https://en.wikipedia.org/wiki/Subject_(grammar)) ] Subject
# * [ [w](https://en.wikipedia.org/wiki/Subjunctive_possibility) ] Subjunctive Possibility
# * [ [w](https://en.wikipedia.org/wiki/Substitution_(logic)) ] Substitution
# * [ w ][ [s](https://plato.stanford.edu/entries/logic-substructural/) ] Substructural Logic
# * [ [w](https://en.wikipedia.org/wiki/Necessity_and_sufficiency) ] Sufficiency
# * [ [w](https://en.wikipedia.org/wiki/Syllogism) ] Syllogism
#   * [ [s](https://plato.stanford.edu/entries/medieval-syllogism/) ] Medieval Theories of the Syllogism
# * [ [w](https://en.wikipedia.org/wiki/Syntax_(logic)) ] Syntax
# * [ w ][ [s](https://plato.stanford.edu/entries/analytic-synthetic/) ] Synthesis
# * [ [w](https://en.wikipedia.org/wiki/Tautology_(logic)) ] Tautology ταυτολογία
# * [ [w](https://en.wikipedia.org/wiki/Temporal_logic) ][ [s](https://plato.stanford.edu/entries/logic-temporal/) ] Temporal Logic
# * [ [w](https://en.wikipedia.org/wiki/Term_(logic)) ] Term
# * [ [w](https://en.wikipedia.org/wiki/Term_algebra) ] Term Algebra
# * [ [w](https://en.wikipedia.org/wiki/Term_logic) ] Term Logic
# * [ [w](https://en.wikipedia.org/wiki/Three-valued_logic) ] Three-Valued Logic
# * [ [w](https://en.wikipedia.org/wiki/Transition_system) ] Transition System
# * [ [w](https://en.wikipedia.org/wiki/Truth) ] Truth
# * [ [w](https://en.wikipedia.org/wiki/Truth_table) ] Truth Table
# * [ [w](https://en.wikipedia.org/wiki/Truth_value) ][ [s](https://plato.stanford.edu/entries/truth-values/) ] Truth Value
# * [ [w](https://en.wikipedia.org/wiki/Truth_function) ] Truth Function
# * [ [w](https://en.wikipedia.org/wiki/Truth-bearer) ] Truth-Bearer
# * [ w ][ [s](https://plato.stanford.edu/entries/type-theory/) ] Type Theory
#   * [ [s](https://plato.stanford.edu/entries/type-theory-intuitionistic/) ] Intuitionistic Type Theory
# * [ [w](https://en.wikipedia.org/wiki/Unification_(computer_science)) ] Unification
# * [ [w](https://en.wikipedia.org/wiki/Uninterpreted_function) ] Uninterpreted Function
# * [ [w](https://en.wikipedia.org/wiki/Universal_(metaphysics)) ] Universal
# * [ [w](https://en.wikipedia.org/wiki/Universal_algebra) ] Universal Algebra
# * [ [w](https://en.wikipedia.org/wiki/Universal_generalization) ] Universal Generalization
# * [ [w](https://en.wikipedia.org/wiki/Universal_instantiation) ] Universal Instantiation
# * [ [w](https://en.wikipedia.org/wiki/Universal_quantification) ] Universal Quantification
# * [ [w](https://en.wikipedia.org/wiki/Vacuous_truth) ] Vacuous Truth
# * [ w ][ [s](https://plato.stanford.edu/entries/vagueness/) ] Vagueness
# * [ [w](https://en.wikipedia.org/wiki/Validity_(logic)) ] Validity
# * [ [w](https://en.wikipedia.org/wiki/Valuation_(logic)) ] Valuation
# * [ [w](https://en.wikipedia.org/wiki/Free_variables_and_bound_variables) ] Variable, Bound
# * [ [w](https://en.wikipedia.org/wiki/Free_variables_and_bound_variables) ] Variable, Free
# * [ [w](https://en.wikipedia.org/wiki/Venn_diagram) ] Venn Diagram
# * [ [w](https://en.wikipedia.org/wiki/Tee_(symbol)) ] Verum
# * [ w ][ [s](https://plato.stanford.edu/entries/vienna-circle/) ] Vienna Circle
# * [ [w](https://en.wikipedia.org/wiki/Well-formed_formula) ] Well-Formed Formula (wff)
# * [ [w](https://en.wikipedia.org/wiki/Zeroth-order_logic) ] Zeroth-Order Logic
#
# ### Informal
#
# * [ [w](https://en.wikipedia.org/wiki/Ad_hominem) ] Ad Hominem [argumentum ad hominem]
# * [ [w](https://en.wikipedia.org/wiki/Affirmative_conclusion_from_a_negative_premise) ] Affirmative Conclusion from a Negative Premise
# * [ [w](https://en.wikipedia.org/wiki/Affirming_the_consequent) ] Affirming the Consequent
# * [ [w](https://en.wikipedia.org/wiki/Affirming_a_disjunct) ] Affirming a Disjunct
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_consequences) ] Appeal to Consequences [argumentum ad consequentiam]
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_emotion) ] Appeal to Emotion [argumentum ad passiones]
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_fear) ] Appeal to Fear [argumentum ad metum, argumentum in terrorem]
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_flattery) ] Appeal to Flattery [argumentum ad superbiam]
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_pity) ] Appeal to Pity [argumentum ad misericordiam]
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_ridicule) ] Appeal to Ridicule [argumentum ad absurdo]
# * [ [w](https://en.wikipedia.org/wiki/Appeal_to_spite) ] Appeal to Spite [argumentum ad odium]
# * [ [w](https://en.wikipedia.org/wiki/Argument_from_authority) ] Argument from Authority, Appeal to Authority [argumentum ab auctoritate, argumentum ad verecundiam]
# * [ [w](https://en.wikipedia.org/wiki/Argument_from_fallacy) ] Argument from Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Argument_from_ignorance) ] Argument from Ignorance, Appeal to Ignorance [argumentum ad ignorantiam]
# * [ [w](https://en.wikipedia.org/wiki/Argument_from_silence) ] Argument from Silence [argumentum ex silentio]
# * [ [w](https://en.wikipedia.org/wiki/Begging_the_question) ] Begging the Question [petitio principii]
# * [ [w](https://en.wikipedia.org/wiki/Cherry_picking) ] Cherry Picking
# * [ [w](https://en.wikipedia.org/wiki/Circular_reasoning) ] Circular Reasoning
# * [ [w](https://en.wikipedia.org/wiki/List_of_cognitive_biases) ] Cognitive Biases (list)
# * [ [w](https://en.wikipedia.org/wiki/Confusion_of_the_inverse) ] Confusion of the Inverse
# * [ [w](https://en.wikipedia.org/wiki/Quoting_out_of_context) ] Contextomy (quoting out of context)
# * [ [w](https://en.wikipedia.org/wiki/Denying_the_antecedent) ] Denying the Antecedent
# * [ [w](https://en.wikipedia.org/wiki/Equivocation) ] Equivocation
# * [ [w](https://en.wikipedia.org/wiki/List_of_fallacies) ] Fallacies (list)
# * [ [w](https://en.wikipedia.org/wiki/Fallacy_of_composition) ] Fallacy of Composition
# * [ [w](https://en.wikipedia.org/wiki/Fallacies_of_definition) ] Fallacy of Definition
# * [ [w](https://en.wikipedia.org/wiki/Fallacy_of_division) ] Fallacy of Division
# * [ [w](https://en.wikipedia.org/wiki/Fallacy_of_four_terms) ] Fallacy of Four Terms
# * [ [w](https://en.wikipedia.org/wiki/Fallacy_of_the_single_cause) ] Fallacy of the Single Cause
# * [ [w](https://en.wikipedia.org/wiki/Fallacy_of_the_undistributed_middle) ] Fallacy of the Undistributed Middle
# * [ [w](https://en.wikipedia.org/wiki/False_dilemma) ] False Dilemma
# * [ [w](https://en.wikipedia.org/wiki/Faulty_generalization) ] Faulty Generalization
# * [ [w](https://en.wikipedia.org/wiki/Formal_fallacy) ] Formal Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Illicit_major) ] Illicit Major
# * [ [w](https://en.wikipedia.org/wiki/Illicit_minor) ] Illicit Minor
# * [ [w](https://en.wikipedia.org/wiki/Informal_fallacy) ] Informal Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Irrelevant_conclusion) ] Irrelevant Conclusion [ignoratio elenchi]
# * [ [w](https://en.wikipedia.org/wiki/Jumping_to_conclusions) ] Jumping to Conclusions
# * [ [w](https://en.wikipedia.org/wiki/Ludic_fallacy) ] Ludic Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_fallacy) ] Mathematical Fallacy
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_charity) ] Principle of Charity
# * [ [w](https://en.wikipedia.org/wiki/Principle_of_humanity) ] Principle of Humanity
# * [ [w](https://en.wikipedia.org/wiki/Procatalepsis) ] Procatalepsis
# * [ [w](https://en.wikipedia.org/wiki/Red_herring) ] Red Herring
# * [ [w](https://en.wikipedia.org/wiki/Reification_(fallacy)) ] Reification
# * [ [w](https://en.wikipedia.org/wiki/Slippery_slope) ] Slippery Slope
# * [ [w](https://en.wikipedia.org/wiki/Sorites_paradox) ] Sorites Paradox
# * [ [w](https://en.wikipedia.org/wiki/Straw_man) ] Strawman
# * [ [w](https://en.wikipedia.org/wiki/Trivial_objections) ] Trivial Objection
# * [ [w](https://en.wikipedia.org/wiki/Wishful_thinking) ] Wishful Thinking
#
# ### Sets
#
# * [ [w](https://en.wikipedia.org/wiki/Algebraic_number) ] Algebraic Number
# * [ [w](https://en.wikipedia.org/wiki/Axiom_of_choice) ][ [s](https://plato.stanford.edu/entries/axiom-choice/) ] Axiom of Choice
# * [ [w](https://en.wikipedia.org/wiki/Axiom_of_empty_set) ] Axiom of Empty Set
# * [ [w](https://en.wikipedia.org/wiki/Axiom_of_extensionality) ] Axiom of Extensionality
# * [ [w](https://en.wikipedia.org/wiki/Axiom_of_infinity) ] Axiom of Infinity
# * [ [w](https://en.wikipedia.org/wiki/Axiom_of_power_set) ] Axiom of Power Set
# * [ [w](https://en.wikipedia.org/wiki/Cantor%27s_diagonal_argument) ] Cantor's Diagonal Argument
# * [ [w](https://en.wikipedia.org/wiki/Cantor%27s_theorem) ] Cantor's Theorem
# * [ [w](https://en.wikipedia.org/wiki/Cardinal_number) ] Cardinal Number
# * [ [w](https://en.wikipedia.org/wiki/Cardinality_of_the_continuum) ] Cardinality of the Continuum
# * [ [w](https://en.wikipedia.org/wiki/Cartesian_product) ] Cartesian Product
# * [ [w](https://en.wikipedia.org/wiki/Class_(set_theory)) ] Class
# * [ [w](https://en.wikipedia.org/wiki/Continuum_(set_theory)) ] Continuum
# * [ [w](https://en.wikipedia.org/wiki/Continuum_hypothesis) ] Continuum Hypothesis
# * [ [w](https://en.wikipedia.org/wiki/Dedekind_cut) ] Dedekind Cut
# * [ [w](https://en.wikipedia.org/wiki/Element_(mathematics)) ] Element
# * [ [w](https://en.wikipedia.org/wiki/Empty_set) ] Empty Set
# * [ [w](https://en.wikipedia.org/wiki/Equinumerosity) ] Equinumerosity
# * [ [w](https://en.wikipedia.org/wiki/Family_of_sets) ] Family
# * [ [w](https://en.wikipedia.org/wiki/Intension) ] Intension
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_object) ] Mathematical Object
# * [ [w](https://en.wikipedia.org/wiki/Multiset) ] Multiset
# * [ [w](https://en.wikipedia.org/wiki/Ordinal_arithmetic) ] Ordinal Arithmetic
# * [ [w](https://en.wikipedia.org/wiki/Ordinal_number) ] Ordinal Number
# * [ [w](https://en.wikipedia.org/wiki/Power_set) ] Power Set
# * [ [w](https://en.wikipedia.org/wiki/Real_number) ] Real Number
# * [ [w](https://en.wikipedia.org/wiki/Decimal_representation) ] Real Number, Decimal Representation
# * [ [w](https://en.wikipedia.org/wiki/Set_(mathematics)) ] Set
# * [ [w](https://en.wikipedia.org/wiki/Countable_set) ] Set, Countable
# * [ [w](https://en.wikipedia.org/wiki/Infinite_set) ] Set, Infinite
# * [ [w](https://en.wikipedia.org/wiki/Uncountable_set) ] Set, Uncountable
# * [ [w](https://en.wikipedia.org/wiki/Set-builder_notation) ] Set-Builder Notation
# * [ [w](https://en.wikipedia.org/wiki/Singleton_(mathematics)) ] Singleton
# * [ [w](https://en.wikipedia.org/wiki/Subset) ] Subset
# * [ [w](https://en.wikipedia.org/wiki/Successor_cardinal) ] Successor Cardinal
# * [ [w](https://en.wikipedia.org/wiki/Successor_ordinal) ] Successor Ordinal
# * [ [w](https://en.wikipedia.org/wiki/Transcendental_number) ] Transcendental Number
# * [ [w](https://en.wikipedia.org/wiki/Union_(set_theory)) ] Union
# * [ [w](https://en.wikipedia.org/wiki/Well-order) ] Well-Order
# * [ [w](https://en.wikipedia.org/wiki/Zermelo_set_theory) ] Zermelo Set Theory
# * [ [w](https://en.wikipedia.org/wiki/Zermelo%E2%80%93Fraenkel_set_theory) ] Zermelo-Fraenkel Set Theory
#
# ### Arithmetic
#
# * [ [w](https://en.wikipedia.org/wiki/Addition) ] Addition
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic) ] Arithmetic
# * [ w ] Difference
# * [ w ] Dividend
# * [ w ] Division
# * [ w ] Divisor
# * [ w ] Exponentiation
# * [ w ] Factor
# * [ [w](https://en.wikipedia.org/wiki/Function_(mathematics)) ] Function
# * [ w ] Function Notation
# * [ w ] Logarithm
# * [ [w](https://en.wikipedia.org/wiki/Mathematical_table) ] Mathematical Table
# * [ w ] Modulation
# * [ w ] Multiplicand
# * [ w ] Multiplication
# * [ w ] Multiplier
# * [ w ] Nth Root
# * [ w ] Product
# * [ w ] Quotient
# * [ w ] Remainder
# * [ w ] Subtraction
# * [ w ] Subtrahend
# * [ w ] Sum
# * [ w ] Summand
#
# ### Automata and Computation
#
# * [ [w](https://en.wikipedia.org/wiki/Abstract_machine) ] Abstract Machine
# * [ [w](https://en.wikipedia.org/wiki/Automata_theory) ] Automata Theory
# * [ [w](https://en.wikipedia.org/wiki/Automaton) ] Automaton
# * [ [w](https://en.wikipedia.org/wiki/Computation) ] Computation
# * [ [w](https://en.wikipedia.org/wiki/Finite-state_machine) ] Finite-State Machine
# * [ [w](https://en.wikipedia.org/wiki/Hybrid_automaton) ] Hybrid Automaton
# * [ [w](https://en.wikipedia.org/wiki/Model_of_computation) ] Model of Computation
# * [ [w](https://en.wikipedia.org/wiki/State_(computer_science)) ] State
# * [ [w](https://en.wikipedia.org/wiki/Timed_automaton) ] Timed Automaton
# * [ [w](https://en.wikipedia.org/wiki/Turing_machine) ] Turing Machine
#
# ### Programming Languages
#
# * [ [w](https://en.wikipedia.org/wiki/Axiomatic_semantics) ] Axiomatic Semantics
# * [ [w](https://en.wikipedia.org/wiki/Correctness_(computer_science)) ] Correctness
# * [ [w](https://en.wikipedia.org/wiki/Denotational_semantics) ] Denotational Semantics
# * [ [w](https://en.wikipedia.org/wiki/Formal_specification) ] Formal Specification
# * [ [w](https://en.wikipedia.org/wiki/Formal_verification) ] Formal Verification
# * [ [w](https://en.wikipedia.org/wiki/Hoare_logic) ] Hoare Logic
# * [ [w](https://en.wikipedia.org/wiki/Logic_programming) ] Logic Programming
# * [ [w](https://en.wikipedia.org/wiki/Operational_semantics) ] Operational Semantics
# * [ [w](https://en.wikipedia.org/wiki/Programming_language_theory) ] Programming Language Theory
# * [ [w](https://en.wikipedia.org/wiki/Prolog) ] Prolog
# * [ [w](https://en.wikipedia.org/wiki/Pure_function) ] Pure Function
# * [ [w](https://en.wikipedia.org/wiki/Semantics_(computer_science)) ] Semantics
#
# ### Digital Logic
#
# Figures
# * [ [w](https://en.wikipedia.org/wiki/Frank_Gray_(researcher)) ] Gray, Frank (1887-1969)
# * [ [w](https://en.wikipedia.org/wiki/Maurice_Karnaugh) ] Karnaugh, Maurice (1924-2022)
#
# Terms
# * [ [w](https://en.wikipedia.org/wiki/Adder_(electronics)) ] Adder
# * [ [w](https://en.wikipedia.org/wiki/Arithmetic_logic_unit) ] Arithmetic Logic Unit
# * [ [w](https://en.wikipedia.org/wiki/Boolean_circuit) ] Boolean Circuit
# * [ [w](https://en.wikipedia.org/wiki/Circuit_complexity) ] Circuit Complexity
# * [ [w](https://en.wikipedia.org/wiki/Coincidence_circuit) ] Coincidence Circuit
# * [ [w](https://en.wikipedia.org/wiki/Combinational_logic) ] Combinational Logic
# * [ [w](https://en.wikipedia.org/wiki/Digital_electronics) ] Digital Electronics
# * [ [w](https://en.wikipedia.org/wiki/Encoder_(digital)) ] Encoder
# * [ [w](https://en.wikipedia.org/wiki/Flip-flop_(electronics)) ] Flip-Flop
# * [ [w](https://en.wikipedia.org/wiki/Gray_code) ] Gray Code
# * [ [w](https://en.wikipedia.org/wiki/Hazard_(logic)) ] Hazard
# * [ [w](https://en.wikipedia.org/wiki/Karnaugh_map) ] Karnaugh Map
# * [ [w](https://en.wikipedia.org/wiki/Ladder_logic) ] Ladder Logic
# * [ [w](https://en.wikipedia.org/wiki/Logic_gate) ] Logic Gate
# * [ [w](https://en.wikipedia.org/wiki/Logic_optimization) ] Logic Optimization
# * [ [w](https://en.wikipedia.org/wiki/Multiplexer) ] Multiplexer
# * [ [w](https://en.wikipedia.org/wiki/One-hot) ] One-Hot
# * [ w ] Product of Sums (POS) Expression
# * [ [w](https://en.wikipedia.org/wiki/Relay_logic) ] Relay Logic
# * [ [w](https://en.wikipedia.org/wiki/Sequential_logic) ] Sequential Logic
# * [ [w](https://en.wikipedia.org/wiki/Signal_propagation_delay) ] Signal Propagation Delay
# * [ [w](https://en.wikipedia.org/wiki/Signalling_block_system) ] Signalling Block System
# * [ [w](https://en.wikipedia.org/wiki/Subtractor) ] Subtractor
# * [ w ] Sum of Products (SOP) Expression
# * [ [w](https://en.wikipedia.org/wiki/Switching_circuit_theory) ] Switching Circuit Theory

# %% [markdown]
# ---
